# %%
import pandas as pd
df = pd.read_csv("베트남_새로 발행된 문서.csv")

# %%
df.head()
# Out:
#          date                                               link  \
# 0  2022-07-01  https://www.customs.gov.vn//index.jsp?pageId=2...
# 1  2022-06-27  https://www.customs.gov.vn//index.jsp?pageId=2...
# 2  2022-06-13  https://www.customs.gov.vn//index.jsp?pageId=2...
# 3  2022-06-01  https://www.customs.gov.vn//index.jsp?pageId=2...
# 4  2022-05-23  https://www.customs.gov.vn//index.jsp?pageId=2...
#
#                                                title  \
# 0  Tăng cường quản lý, đấu tranh chống buôn lậu, ...
# 1  Quy định mới về cung cấp thông tin và dịch vụ ...
# 2  Một số chính sách xuất nhập khẩu hàng hóa thán...
# 3  Ngành Hải quan: Tháng hàng động phòng, chống m...
# 4        7 mục tiêu phát triển Hải quan đến năm 2030
#
#                                                 text
# 0  Tăng cường quản lý, đấu tranh chống buôn lậu, ...
# 1  Quy định mới về cung cấp thông tin và dịch vụ ...
# 2  Một số chính sách xuất nhập khẩu hàng hóa thán...
# ...

# %%
df.tail()
# Out:
#            date                                               link  \
# 994  2010-09-13  https://www.customs.gov.vn//index.jsp?pageId=2...
# 995  2010-08-18  https://www.customs.gov.vn//index.jsp?pageId=2...
# 996  2010-08-12  https://www.customs.gov.vn//index.jsp?pageId=2...
# 997  2010-08-10  https://www.customs.gov.vn//index.jsp?pageId=2...
# 998  2010-08-10  https://www.customs.gov.vn//index.jsp?pageId=2...
#
#                                                  title  \
# 994  Quy trình phúc tập hồ sơ hải quan thực hiện th...
# 995  Thuế nhập khẩu ưu đãi đối với vật tư sản xuất ...
# 996  Thông tư của Bộ Tài chính về bổ sung chính sác...
# 997  Quy trình nghiệp vụ quản lý hải quan đối với h...
# 998  Thông tư của Bộ Tài chính hướng dẫn việc miễn ...
#
#                                                   text
# 994  Quy trình phúc tập hồ sơ hải quan thực hiện th...
# 995  Thuế nhập khẩu ưu đãi đối với vật tư sản xuất ...
# 996  Thông tư của Bộ Tài chính về bổ sung chính sác...
# ...

# %%
df = df[::-1]
df.head()
# Out:
#            date                                               link  \
# 998  2010-08-10  https://www.customs.gov.vn//index.jsp?pageId=2...
# 997  2010-08-10  https://www.customs.gov.vn//index.jsp?pageId=2...
# 996  2010-08-12  https://www.customs.gov.vn//index.jsp?pageId=2...
# 995  2010-08-18  https://www.customs.gov.vn//index.jsp?pageId=2...
# 994  2010-09-13  https://www.customs.gov.vn//index.jsp?pageId=2...
#
#                                                  title  \
# 998  Thông tư của Bộ Tài chính hướng dẫn việc miễn ...
# 997  Quy trình nghiệp vụ quản lý hải quan đối với h...
# 996  Thông tư của Bộ Tài chính về bổ sung chính sác...
# 995  Thuế nhập khẩu ưu đãi đối với vật tư sản xuất ...
# 994  Quy trình phúc tập hồ sơ hải quan thực hiện th...
#
#                                                   text
# 998  Thông tư của Bộ Tài chính hướng dẫn việc miễn ...
# 997  Quy trình nghiệp vụ quản lý hải quan đối với h...
# 996  Thông tư của Bộ Tài chính về bổ sung chính sác...
# ...

# %%
df.tail()
# Out:
#          date                                               link  \
# 4  2022-05-23  https://www.customs.gov.vn//index.jsp?pageId=2...
# 3  2022-06-01  https://www.customs.gov.vn//index.jsp?pageId=2...
# 2  2022-06-13  https://www.customs.gov.vn//index.jsp?pageId=2...
# 1  2022-06-27  https://www.customs.gov.vn//index.jsp?pageId=2...
# 0  2022-07-01  https://www.customs.gov.vn//index.jsp?pageId=2...
#
#                                                title  \
# 4        7 mục tiêu phát triển Hải quan đến năm 2030
# 3  Ngành Hải quan: Tháng hàng động phòng, chống m...
# 2  Một số chính sách xuất nhập khẩu hàng hóa thán...
# 1  Quy định mới về cung cấp thông tin và dịch vụ ...
# 0  Tăng cường quản lý, đấu tranh chống buôn lậu, ...
#
#                                                 text
# 4  7 mục tiêu phát triển Hải quan đến năm 2030\nM...
# 3  Ngành Hải quan: Tháng hàng động phòng, chống m...
# 2  Một số chính sách xuất nhập khẩu hàng hóa thán...
# ...

# %%
df
