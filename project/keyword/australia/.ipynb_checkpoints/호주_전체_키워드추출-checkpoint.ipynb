# %%
import pandas as pd
import re

#df : 스크래핑한 호주 문서
df = pd.read_csv("호주_세관_전체.csv")

df_title = list(df['title'])
df_text = list(df['text'])
df_add = []

for i in range(len(df)):
    df_add.append(df_title[i]+""+df_text[i])

print(len(df_add))

#df_keyword : 선정한 호주 키워드 101개
df_keyword = pd.read_csv("호주_번역_100.csv", index_col = False)
print(len(df_keyword))
# Out:
# 1684
# 102

# %%
import numpy as np
import itertools
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer

# SentenceTransformer : 모델 훈련 위한 라이브러리
# 'distiluse-base-multilingual-cased-v1' : 사용할 모델
model = SentenceTransformer('distiluse-base-multilingual-cased-v1')

# %%
#keyword : 불러온 호주 키워드 중 번역 Column 추출
keyword = list(df_keyword["번역"])
print(len(keyword))
# Out:
# 102

# %%
#키워드 벡터화
keyword_embedding = []

for ele in keyword:
    keyword_embedding.append(model.encode(ele))

print(len(keyword_embedding))
# Out:
# 102

# %%
#호주 문서 10개 embedding
import nltk
import string
from nltk.tag import pos_tag
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords 
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

doc_embedding = []
doc_words = []
cnt = 0

for doc in df_add:
    result = []
    sentence = ''
    stop_words = set(stopwords.words('english'))

    doc = doc.replace("\n", "").strip()


    word_tokens = pos_tag(word_tokenize(doc))

    word_tokens = [t[0] for t in word_tokens if t[1] == "NN" and len(t[0]) > 2]
    for w in word_tokens:  
        if w not in stop_words:
            result.append(w)
    result = [word.lower() for word in result]
    doc_words.append(result)
    doc_embedding.append(model.encode(result))
    
    #카운트 추가
    print(cnt, "번 문서 진행 중")
    cnt += 1
# Out:
# 0 번 문서 진행 중
# ['notice', 'guide', 'trade', 'theoperation', 'seizure', 'effect', 'legislation', 'greateruniformity', 'field', 'trade', 'mark', 'law', 'principlesprescribed', 'trade', 'language', 'thelaw', 'number', 'legislation', 'owner', 'place', 'proprietor', 'trade', 'mark', 'difference', 'meaning', 'simpler', 'notice', 'outline', 'action', 'section', 'nature', 'section', 'lodgement', 'thematter', 'scheme', 'owner', 'incertain', 'user', 'trade', 'mark', 'importation', 'trademark', 'trade', 'mark', 'section', 'resolution', 'action', 'importation', 'trade', 'mark.2', 'seizure', 'control', 'importation', 'trade', 'mark', 'respect', 'respect', 'trade', 'mark', 'opinion', 'trade', 'mark', 'trade', 'mark', 'importation', 'infringement', 'trade', 'mark', 'view', 'security', 'thecommonwealth', 'respect', 'relation', 'seizure', 'scheme', 'seizure', 'use', 'ofthe', 'importer', 'course', 'scheme', 'seizure', 'action', 'action', 'behalf', '.it', 'seizure', 'theauthority', 'seizure', 'relatingto', 'search', 'seizure']
# 1 번 문서 진행 중
# ['woolpack', 'amp', 'transfer', 'responsibility', 'themanagement', 'woolpack', 'quality', 'assurance', 'importation', 'woolpack', 'permission', 'person', 'subregulation', 'certificate', 'respect', 'refer', 'transfer', 'responsibility', 'woolpack', 'certificate', 'provision', 'importation', 'conform', 'standard', 'andpromotion', 'time', 'respect', 'c95/02449']
# 2 번 문서 진행 중
# ['tariff', 'date.the', 'purpose', 'place', 'tariff', 'standard', 'signatory', 'trade', 'aim', 'round', 'developments.in', 'tariff', 'duty', 'force', 'tariff', 'addition', 'attempt', 'duty', 'rate', 'duty', 'tariff', 'cocoa', 'basis', 'cocoa', 'powder', 'consequence', 'change', 'cocoa', 'toretain', 'rate', 'duty', 'food', 'cocoa', 'cord', 'glass', 'glass', 'rate', 'pearl', 'practice', 'strung', 'word', 'description', 'effect', 'change', 'transport', 'totransfer', 'rate', 'duty', 'in7101', 'tariff', 'regime', 'output', 'example', 'co-ordinate', 'input', 'subheading8471.60.00', 'duty', 'advise', 'subheading8424.89.90', 'classification', 'rate', 'duty', 'trade', 'waste', 'scrap', 'duty', 'number', 'constituent', 'material.in', 'addition', 'definition', 'chapter', 'chapter', 'consultation', 'industry', 'tariff', 'classification', 'duty', 'implementation', 'place', 'context', 'duty', 'period', 'year', 'thecommencement', 'instance', 'review', 'newstructure', 'duty', 'policy', 'aspects.the', 'costis', 'documentation', 'tabling']
# 3 번 문서 진행 중
# ['origin', 'preference', 'claim', 'origin', 'manufacture', 'acountry', 'country', 'qualifying', 'area', 'process', 'manufacture', 'factory', 'cost', 'percentage.for', 'manufacture', 'preference', 'country', 'area', 'percentage', '.unless', 'process', 'manufacture', 'preference', 'claim', 'qualifyingarea', 'assessment', 'area', 'percentage', 'origin.in', 'process', 'manufacture', 'criterion', 'criterion', 'process', 'packaging', 'export', 'packaging', 'set', 'process', 'process', 'manufacture', 'criterion', 'area', 'area', 'area', 'theorigin', 'country', 'packaging', 'example', 'set', 'origin', 'theorigin', 'origin', 'duty', 'boxed', 'origin', 'good', 'documentation', 'rate', 'duty', 'packaging', 'c96/20052']
# 4 번 문서 진행 중
# ['act', 'amp', 'commencement', 'review', 'course', 'review', 'need', 'account', 'assistance', 'layout', 'regard', 'structure', 'countervailing', 'andspain', 'number', 'i.e', 'grams/', 'method', 'duty', 'rate', 'weight', 'rate', 'account', 'duty', 'rate', 'duty', 'measures.any', 'matter', 'simplification', 'telephone', 'facsimile']
# 5 번 문서 진행 중
# ['indexation', 'excise', 'tariff', 'diesel', 'fuel', 'rebateaustralian', 'accordance', 'indexation', 'beer', 'tobacco', 'andpetroleum', 'rates.for', 'indexation', 'index', 'number', 'statistician', 'factor', 'index', 'duty', 'index', 'number', 'quarter', 'theindexation', 'factor', 'diesel', 'fuel', 'rebate', 'accordance', 'sub-section', 'diesel', 'fuel', 'rebate', 'diesel', 'fuel', 'rebate', 'change', 'rate', 'rebate', 'rate', 'respect', 'diesel', 'fuel', 'rate', 'average', 'rebate', 'force', 'day', 'month', 'application', 'rebate', 'rate', 'month', 'month', 'rate', 'claim', 'payment', 'advice', 'amp']
# 6 번 문서 진행 중
# ['cargo', 'automation', 'transhipment', 'transhipment', 'electronic', 'movement', 'transhipment', 'cargo', 'proposal', 'system', 'transhipment', 'cargo', 'discharge', 'port', 'information', 'message', 'code', 'underbondmovement', 'transhipment', 'cargo', 'port', 'export', 'cargo', 'movements.it', 'sea', 'cargo', 'transhipment', 'sca', 'available.exemption', 'export', 'entry', 'exemption', 'transhipment', 'cargo', 'export', 'cargo', 'system', 'release', 'information', 'message', 'code', 'export', 'copy', 'printout', 'information', 'messagecode', 'system', 'evidence', 'transhipment', 'status', 'paper', 'export', 'copy', 'message', 'code299', 'export', 'clerk', 'copy', 'code', 'audit', 'purposes.regardless', 'paper', 'exemptioncode', 'authority', 'transhipment', 'cargo', 'respect', 'formalities.reconciliation', 'transhipment', 'transhipment', 'cargo', 'compliance', 'audit', 'arrangements.transhipment', 'sea', 'cargo', 'completion', 'automation', 'transhipment', 'export', 'conjunction', 'currentevaluation', 'export', 'system.further', 'information', 'orfacsimile']
# 7 번 문서 진행 중
# ['section', 'operation', 'seizure', 'organisation', 'owner', 'material', 'section', 'action', 'organisation', 'itsobjection', 'importation', 'copyright.unless', 'force', 'end', 'period', 'flash', 'logo', 'grotesque', 'city', 'state', 'information', 'control', 'regime', 'range', 'material', 'regard', 'number', 'border', 'copyright', 'logodescribed', 'authorisation', 'seizure', 'court', 'action', 'person', 'c96/02298']
# 8 번 문서 진행 중
# ['preparation', 'export', 'cargo', 'postponement', 'commencement', 'industry', 'requirement', 'consolidationof', 'cargo', 'exportation', 'ship', 'aircraft', 'prepare', 'submanifest', 'respect', 'amendment', 'period', 'grace', 'time', 'submanifest', 'requirementswould', 'freight', 'slot', 'export', 'cargo', 'submanifest', 'system', 'acceptance', 'processing', 'number', 'matter', 'freight', 'forwarding', 'courier', 'industry', 'itsdesire', 'reporting', 'system', 'concern', 'ability', 'system', 'export', 'requirements.the', 'number', 'software', 'software', 'industry', 'initiative', 'industry', 'compliance', 'reporting', 'implementation', 'decision', 'basis', 'uptake', 'system', 'industry', 'electronicreporting.it', 'initiative', 'legislation', 'person', 'carrier', 'submanifest', 'consolidator', 'export', 'cargo', 'submanifest', 'export', 'consolidations.the', 'number', 'export', 'cargo', 'consolidationthroughout', 'process', 'anticipation', 'export', 'cargo', 'consolidationsin', 'accordance', 'position', 'assistance', 'section', 'region', 'phone', 'assistance']
# 9 번 문서 진행 중
# ['management', 'project', 'team', 'consultation', 'industry', 'relevantgovernment', 'advice', 'reference', 'cross-section', 'industry', 'reference', 'future', 'information', 'relation', 'cargo', 'example', 'scope', 'issue', 'report', 'movement', 'carriage', 'storage', 'entry', 'payment', 'clearance', 'flow', 'information', 'movement', 'cargo', 'impact', 'internationaltrade', 'commerce', 'process', 'business', 'import', 'andexport', 'cargo', 'management', 'management', 'shipping/airline', 'freight', 'air', 'express', 'cargo', 'depot', 'software', 'industry', 'associations.the', 'staff', 'information', 'information', 'contactingthe', 'c=au', 'a=attmail', 'o=email', 'g=david']
# 10 번 문서 진행 중
# ['suspension', 'amendments', 'trade', 'regulation', 'result', 'decision.in', 'accordance', 'result', 'decision', 'regulation', 'importation', 'goodsfrom', 'permission', 'person', 'exportation', 'finaldestination', 'permission', 'forforeign', 'person.in', 'accordance', 'party', 'resolution', 'suspension', 'termination', 'tocertain', 'measure', 'form', 'amendment', 'utility', 'resolution', 'successor', 'issue', 'succession', 'property', 'separation', 'suspension', 'effect', 'suspension', 'removal', 'import', 'retention', 'exportation', 'utility', 'permission', 'person']
# 11 번 문서 진행 중
# ['section', 'trade', 'section', 'action', 'objection', 'importation', 'listed.unless', 'force', 'end', 'period', 'device', 'incomplete', 'circle', 'jewellery', 'paper', 'paper', 'clothing', 'and25', 'class', 'apparatus', 'class', 'class', 'class', 'lace', 'embroidery', 'etc', 'class', 'class', 'date', 'file', 'c94/15088guess', 'amp', 'jewellery', 'class', 'class18', 'clothing', 'class', 'date', 'file', 'amp', 'device', 'paper', 'paper', 'class', 'tobacco', 'class', 'class', 'cigarette', 'amp', 'class', 'clothing', 'class', 'class', 'class', 'date', 'file', 'amp', 'device']
# 12 번 문서 진행 중
# ['contingency', 'reporting', 'export', 'cargo', 'industry', 'requirement', 'consolidationof', 'cargo', 'exportation', 'ship', 'aircraft', 'prepare', 'submanifest', 'respect', 'slot', 'reporting', 'export', 'paper', 'submanifest', 'theexport', 'system', 'requirement', 'export', 'cargo', 'system', 'input', 'staff', 'paper', 'exit', 'introduction', 'arrangements.introduction', 'system', 'network', 'software', 'result', 'processing', 'issuing', 'ofcontingency', 'reply', 'submanifest', 'message', 'system', 'paper', 'submanifest.paper', 'paper', 'processing', 'accordance', 'system', 'paper', 'submanifest', 'contingency', 'paper', 'submanifestprovider', 'submanifest', 'message', 'system', 'reply', 'delivery', 'cargo', 'carrier', 'agent', 'nextconsolidator', 'client', 'section', 'themessage', 'system', 'officer', 'client', 'submanifest', 'message', 'system', 'delivery', 'cargo', 'section', 'contingency', 'client', 'client', 'system', 'problem', 'client', 'problem', 'submanifest', 'client', 'willthen', 'section', 'thesubmanifest', 'system.information', 'contingency', 'client', 'officer', 'contingency']
# 13 번 문서 진행 중
# ['year', 'industry', 'export', 'facilitation', 'year', 'part', 'year', 'duty', 'review', 'point', 'contact', 'period', 'point', 'contact', 'amp', 'responsibility', 'calculation', 'value', 'theadministration', "'eligibility", 'criterion', 'thedepartment', 'reference', 'policy', 'industry', 'officer', 'anddist', 'information', 'organisation', 'information', 'access', 'information', 'policy', 'issue.the', 'officer', 'region', 'information', 'state', 'name', 'notice', 'industry', 'amp']
# 14 번 문서 진행 중
# ['section', 'operation', 'seizure', 'copyright', 'material', 'identifiedbelow', 'section', 'action', 'objection', 'importation', 'copyright.unless', 'force', 'end', 'period', 'date', 'file', 'amp', 'software', 'date', 'file', 'amp', 'date', 'file', 'date', 'file', 'city', 'state', 'information', 'control', 'regime', 'import', 'material', 'regardshould', 'border', 'copyright', 'material', 'authorisation', 'uponseizure', 'court', 'action', 'importer/sof']
# 15 번 문서 진행 중
# ['warehouse', 'payment', 'part', 'warehouse', 'submission', 'anapplication', 'payment', 'office', 'warehouse', 'licence', 'increase', 'period', 'transaction', 'fee', 'schedule', 'effect', 'renewal', 'warehouse', 'form', 'remittance', 'relevantoffice', 'licence', 'case', 'purpose', 'control.further', 'information', 'warehouse', 'licensing', 'fee', 'structure', 'please', 'region', 'warehouse', 'period', 'year', 'fee', 'grant', 'renewal', 'warehouse', 'licence', 'sum', 'deduction', 'section']
# 16 번 문서 진행 중
# ['removal', 'export', 'export', 'regulationsaustralian', 'exportation', 'cover', 'alumina', 'bauxite', 'coal', 'ilmenite', 'rutile', 'leucoxene', 'monazite', 'rutile', 'xenotime', 'zircon', 'gas', 'exportation', 'permission', 'person.statutory', 'export', 'licensing', 'monazite', 'xenotime', 'level', 'alumina', 'bauxite', 'coal', 'exportdocumentation', 'permit', 'number', 'export', 'entries.any', 'andenergy', 'c96/05122']
# 17 번 문서 진행 중
# ['section', 'operation', 'seizure', 'licensee', 'material', 'section', 'action', 'company', 'objection', 'importation', 'copyright.unless', 'force', 'end', 'period', 'identified.objector', 'amp', 'packaging', 'instruction', 'order', 'kit', 'date', 'file', 'c96/05688objector', 'amp', 'date', 'file', 'city', 'state', 'information', 'control', 'regime', 'company', 'material', 'regardshould', 'company', 'representative', 'number', 'border', 'copyright', 'material', 'authorisation', 'uponseizure', 'court', 'action', 'importer/sof']
# 18 번 문서 진행 중
# ['controlsaustralian', 'tragedy', 'meeting', 'number', 'firearm', 'controls.the', 'ban', 'importation', 'importation', 'importation', 'havebeen', 'accordance', 'addition', 'importation', 'consequence', 'importation', 'self-loading', 'action', 'circumstances.the', 'centre', 'fire', 'action', 'magazine', 'capacity', 'rimfire', 'magazine', 'capacity', 'rounds.the', 'importer', 'statement', 'form', 'effect', 'theimporter', 'licence', 'authorisation', 'accordance', 'law', 'firearmof', 'kind', 'state', 'form', 'thefirearm', 'rimfire', 'magazine', 'capacity', 'action', 'magazine', 'capacity', 'nogreater', 'addition', 'amendment', 'importation', 'capacity', 'rimfire', 'purposes.further', 'information', 'territory', 'mascottelephone', 'inspector', 'melbournetelephone']
# 19 번 문서 진행 중
# ['import', 'commodity', 'commodity', 'classification', 'attention', 'above.this', 'system', 'basis', 'code', 'level.acn', 'comment', 'code', 'level', 'process', 'information', 'paper', 'catalogue', 'forchange.the', 'number', 'result', 'list', 'c96/05899']
# 20 번 문서 진행 중
# ['number', 'coverage', 'purpose', 'treatment', 'codes/reference', 'tariff', 'by-law', 'itemshave', 'force', 'number', 'by-law', 'item', 'lapsing', 'by-laws', 'by-laws', 'application.a', 'concordance', 'concession', 'force', 'asat', 'by-law', 'effect', 'reference', 'file', 'system', 'time', 'distribution', 'text', 'concordance', 'conjunction', 'concession', 'instance', 'administration', 'amp', 'c96/1123', 'item', 'amalgation', 'tax-deduction', 's.78', 'wording', 'item', 'item', 'item', 'use', 'family', 'concession', 'item', 'item', 'item', 'concession', 'paragraph', 'item', 'government', 'country', 'paragraph', 'item', 'item', 'amalgamation', 'revenue', 'motor', 'sea', 'air', 'craft', 'wordingof', 'item', 'item', 'item', 'subparagraph', 'insubparagraph', 'item', 'part', 'agreement', 'government', 'country', 'coverageof', 'item', 'change', 'item', 'item', 'change', 'item', 'inclusion', 'by-law', 'hasbeen', 'item', 'concession', 'item', 'item', 'item', 'by-law', 'coverage', 'item', 'word', 'item']
# 21 번 문서 진행 중
# ['release', 'tariff', 'conjunction', 'implementation', 'effect', 'document', 'tariff', 'duty', 'rate', 'duty', 'symbol', 'symbol', 'list', 'rate', 'rate', 'rate', 'rate', 'duty', 'rate', 'rate', 'duty', 'applies.preference', 'system', 'number', 'effect', 'administrativenature', 'description', 'section', 'chapter', 'duty', 'substance', 're-enactment', 'duty', 'beer', 'chapter', 'tobacco', 'tobacco', 'chapter', 'chapter', 'effect', 'duty', 'tariff', 'newsprint', 'interpretation', 'representationsfrom', 'structure', 'mechanicalprocess', 'weight', 'fibre', 'content', 'weight', 'fibre', 'content', 'process4801.00.3of', 'weight', 'fibre', 'content', 'g/m2', 'ash', 'content', 'weight', 'reprint', 'change.5', 'alteration', 'chapter', 'note', 'kind', 'material', 'part', 'example', 'chapter']
# 22 번 문서 진행 중
# ['re-instatement', 'export', '24re-instatement', 'removal', 'export', 'alumina', 'bauxite', 'coal', 'ilmenite', 'rutile', 'leucoxene', 'monazite', 'rutile', 'xenotime', 'zircon', 'gas', 'exportation', 'permission', 'person.on', 'disallowance', 'export', 'alumina', 'bauxite', 'coal', 'number', 'export', 'number', 'inclusive.any', 'andenergy', 'authority', 'thebasis', 'law', 'exportation', 'place', 'requirement', 'forfurther', 'respect', 'export', 'permission', 'unlessexportation', 'place', 'date', 'export', 'ofthe', 'authority', 'permit', 'toexport', 'number', 'subject', 'authority', 'to24', 'basis', 'permission']
# 23 번 문서 진행 중
# ['control', 'structure', 'announcement', 'totalban', 'import', 'effect', 'day.in', 'thatthe', 'set', 'effect', 'outline', 'newregulation', 'importation', 'firearm', 'firearm', 'item', 'importation', 'accordance', 'test2', 'test3', 'person', 'test', 'and4', 'authorisation', 'testthe', 'test', 'number', 'effectiveimplementation', 'registration', 'schemedefinition', 'definition', 'firearm', 'firearm', 'device', 'firearm', 'increasinguse', 'activities.warfare']
# 24 번 문서 진행 중
# ['tariff', 'cheese', 'allocation', 'cheese', 'allocation', 'cheese', 'tariff', 'month', 'performance', 'period', 'allocation', 'quota', 'end', 'year', 'import', 'performance', 'allocation', 'entitlement', 'consumption', 'period', 'allocation', 'periodbeginning', 'quota', 'transfer', 'form', 'industry', 'transfer', 'order', 'time', 'form', 'application', 'advance', 'use.care', 'processing', 'notice', 'telephone']
# 25 번 문서 진행 중
# ['service', 'year', 'periodaustralian', 'year', 'tariff', 'document', 'document', 'forother', 'amp', 'pervolume', 'volume', 'volume', 'volume', 're-order', 'price', 'calendar', 'month', 'subscription', 'calendar', 'month', 'issuing', 'become', 'subscription', 'date', 'month', 'year', 'month', 'payment', 'credit', 'cheque.the', 'cheque', 'credit', 'card', 'order', 'collector', 'card', 'form']
# 26 번 문서 진행 중
# ['tariff', 'concession', 'system', 'duty', 'tariff', 'concession', 'tariff', 'concession', 'caa', 'ctaa', 'effect', 'duty', 'rate', 'introduction', 'duty', 'rate', 'tariff', 'tariff', 'jointdepartment', 'evaluation', 'duty', 'provision', 'duty', 'entry', 'consumption', 'alist', 'tariff', 'consumption', 'election', 'campaign', 'round', 'industry', 'note', 'task', 'force', 'toconsider', 'round', 'table', 'discussions.the', 'revenue', 'budget', 'deficit', 'reduction', 'programmeand', 'administration', 'burden', 'application', 'reform', 'paragraph', 'core', 'criterion', 'provision', 'market', 'test', 'element', 'application', 'core', 'day', 'tcoapplication', 'course', 'definition', 'subsection', 'defactomarket', 'test', 'definition.new', 'ss269b', 'beingput', 'use', 'use', 'subject', 'application', 'noaccount', 'market', 'goods.the', 'focus', 'definition', 'correspondence', 'use', 'capability', 'evidence', 'competition', 'market', 'core', 's269c']
# 27 번 문서 진행 중
# ['year', 'industry', 'export', 'facilitation', 'year', 'part', 'year', 'manufacture', 'export', 'productsin', 'passenger', 'motor', 'automotivemachine', 'tooling', 'design', 'development', 'production', 'result', 'government', 'decision', 'eligibility', 'eligibility', 'year', 'inclusion', 'part', 'technology', 'use', 'potential', 'laterapplication', 'eligibility', 'export', 'manner', 'machine', 'machine', 'machine', 'tooling', 'eligible', 'export', 'product', 'machine', 'tool', 'tooling', 'status', 'principal', 'use', 'machine', 'tool', 'tooling', 'manufacture', 'ofpmvs', 'type', 'andb', 'production', 'bulk', 'tolength', 'shape', 'eligibility', 'design', 'development', 'production', 'service', 'service', 'outcome', 'andevidence', 'bona', 'fide', 'contract', 'provision', 'service', 'design', 'development', 'production', 'service', 'activity', 'export', 'credits.b', 'articulation', 'link', 'use', 'product', 'use', 'rationale', 'vehicle', 'market', 'product', 'time', 'frame', 'product', 'intentof', 'provision', 'development', 'advancement', 'technology', 'incorporation']
# 28 번 문서 진행 중
# ['policy', 'by-law', 'system', 'note', 'information', 'format', 'amp', 'requeststhis', 'advice', 'operation', 'accordance', 'thecommonwealth', 'amendment', 'andthe', 'policy', 'policy', 'date', 'date.1', 'tariff', 'rate', 'duty', 'objective', 'assistance', 'structure', 'duty', 'collection', 'fullduty', 'authority', 'rate', 'ofduty', 'basis', 'concessionalentry', 'example', 'provide', 'entry', 'subject', 'tariff', 'provide', 'entry', 'range', 'relevance', 'number', 'duty', 'entry', 'industry', 'policy', 'reduction', 'business', 'input', 'circumstances.this', 'category', 'ambit', 'system', 'ofschedule', 'guide', 'operation', 'system', 'policy', 'advice', 'entry', 'policy', 'include', 'revocation', 'policy', 'by-laws', 'treatment', 'by-law', 'determination', 'request', 'subject', 'policy', 'item', 'introduction', 'item', 'thecaa', 'iii', 'retention', 'duty', 'rate', 'item', 'rate', 'rate', 'good', 'amendment', 'item', 'equipment', 'use', 'mining', 'resource', 'by-law', 'amendment', 'item', 'equipment', 'use', 'food', 'processing', 'foodpackaging', 'by-law']
# 29 번 문서 진행 중
# ['eligibility', 'bounty', 'computer', 'payment', 'bounty', 'computer', 'manufacturer', 'basis', 'value', 'production', 'rate', 'bounty', 'time', 'manufacture', 'ofthe', 'bounty', 'cost', 'software', 'opinion', 'interpretation', 'term', 'notice', 'attempt', 'meaning', 'term', 'operating', 'software', 'approach', 'application', 'term', 'bounty', 'claims.backgroundit', 'research', 'development', 'expenditure', 'factory', 'amendment', 'bounty', 'development', 'productionof', 'computer', 'operating', 'software', "'research", 'development', 'change', 'asmany', 'software', 'work', 'research', 'developmentnature.it', 'dialogue', 'industry', 'question', 'definition', 'computer', 'operating', 'software', 'contribution', 'advice', 'formulation', 'payment', 'bounty', 'value', 'production', 'computersand', 'operating', 'software', 'software', 'hardware', 'software', 'software', 'bounty.subsection', 'software', 'meaning', 'system', 'software', 'force', 'time', 'definition', 'administration', 'eligibilty', 'criterion', 'operatingsoftware', 'definition', 'operating', 'system', 'ascertaineligibility', 'computer', 'software', 'bounty', 'operating', 'system', 'software', 'execution', 'resource', 'allocation', 'scheduling', 'input/output', 'control', 'issue', 'definition', 'system', 'software', 'term', 'operating', 'system', 'meaning', 'system', 'software', 'software', 'running', 'application', 'part', 'application', 'software', 'software', 'program', 'solution', 'application', 'problem.without', 'terminology', 'application', 'problem', 'end', 'user', 'information', 'processing', 'solution', 'definition', 'operating', 'system', 'system', 'software', 'operating', 'system', 'software', 'application', 'software', 'software', 'application', 'software', 'need', 'distinction', 'eligibility', 'forbounty', 'application', 'software', 'eligibility']
# 30 번 문서 진행 중
# ['indexation', 'excise', 'tariff', 'diesel', 'fuel', 'rebateaustralian', 'accordance', 'indexation', 'beer', 'tobacco', 'andpetroleum', 'rates.for', 'indexation', 'index', 'number', 'statistician', 'index', 'number', 'factor', 'index', 'duty', 'index', 'number', 'quarter', 'theindexation', 'factor', 'diesel', 'fuel', 'rebate', 'accordance', 'sub-section', 'diesel', 'fuel', 'rebate', 'diesel', 'fuel', 'rebate', 'change', 'rate', 'rebate', 'rate', 'respect', 'diesel', 'fuel', 'rate', 'average', 'rebate', 'force', 'day', 'month', 'application', 'rebate', 'rate', 'month', 'month', 'rate', 'claim', 'payment', 'advice', 'amp']
# 31 번 문서 진행 중
# ['tariff', 'concession', 'system', 'incorrect', 'use', 'treatment', 'code', 'thechange', 'duty', 'rate', 'consumption', 'facility', 'tariff', 'classification', 'rectified.analysis', 'import', 'misuse', 'treatment', 'code506', 'treatment', 'code', 'rate', 'duty', 'class', 'consumption', 'rate', 'duty', 'question', 'list', 'consumption', 'tariff.the', 'audit', 'treatmentcode', 'usage', 'view', 'recovery', 'penalty', 'action', 'action', 'meantime', 'treatment', 'code', 'viewto', 'tariff', 'classification', 'consumption', 'error', 'amending', 'entry', 'correcttreatment', 'code', 'treatment', 'code', 'subject', 'treatment', 'code', 'subject', 'no.96/28and', 'rate', 'duty.the', 'date', 'treatment', 'code', 'rate', 'treatment', 'code', 'applies.compile', 'advice', 'detection', 'notice', 'proposedaudit', 'action']
# 32 번 문서 진행 중
# ['branch', 'name', 'advice', 'name', 'compliance', 'title', 'branch', 'complianceimprovement', 'philosophy', 'title', 'border', 'activity', 'focus', 'staff', 'management', 'identify', 'response', 'passivecontrol', 'approach.structure']
# 33 번 문서 진행 중
# ['subscription', 'service', 'volume', 'compliance', 'volume', 'company', 'methodology', 'volume', 'public', 'volume', 'compliance', 'company', 'philosophy', 'strategy', 'audit', 'volume', 'methodology', 'auditors.please', 'note', 'discount', 'issue', 'amendment', 'subscription', 'year', '1996-97', 'amp', 'volume', 'volume', 'volume', 'volume', 'note', 'conjunction', 'period', 'form', 'payment', 'issue', 'subscription.']
# 34 번 문서 진행 중
# ['response', 'party', 'concept', 'audit', 'audit', 'audit', 'company', 'level', 'compliance', 'statutory', 'conclusion', 'regard', 'course', 'exercise', 'view', 'option', 'arrangement', 'underwhich', 'company', 'commission', 'audit', 'level', 'compliance', 'legislation', 'industry', 'value', 'money', 'account', 'realitiesof', 'industry', 'account', 'risk', 'company.in', 'context', 'industry', 'audit', 'tool', 'compliance', 'mechanism', 'audit.the', 'objective', 'audit', 'company', 'level', 'compliance', 'emphasis', 'evaluation', 'acompany', 'information', 'regard', 'company', 'audit', 'philosophy', 'methodology', 'forpurchase', 'methodology', 'application', 'need', 'industry', 'light', 'commission', 'audit', 'assurance', 'compliance', 'legislation', 'audit', 'risk', 'extent', 'audit', 'account', 'extent', 'audit', 'accordance']
# 35 번 문서 진행 중
# ['importation', 'review', 'administration', 'and162a', 'policy', 'importation.the', 'review', 'operation', 'relation', 'theimportation', 'section', 'assembly', 'outcome', 'review', 'decision', 'approval', 'importation', 'basis', 'work', 'approval', 'work', 'example', 'approval', 'stand', 'machinery', 'equipment', 'excavatorunless', 'work', 'approval', 'respect', 'machinery', 'equipment', 'approval', 'information', 'c96/09092']
# 36 번 문서 진행 중
# ['management', 'strategy', 'report', 'cargo', 'management', 'strategy', 'theminister', 'report', 'strategy', 'management', 'cargo', 'information', 'focus', 'report', 'exposure', 'draft', 'address', 'consideration', 'finalisation', 'report', 'contactingthe', 'telephone']
# 37 번 문서 진행 중
# ['objection', 'erratum', 'section', 'importation', 'relation', 'sign', 'trade', 'mark/s', 'force', 'period', 'commencementdate', 'trade', 'mark.the', 'schedule', 'goodsrefer', 'thetrade', 'trade', 'mark', 'specific', 'regard', 'trade', 'mark/s', 'question', 'regardto', 'variety', 'trade', 'diversity', 'ithas', 'asterisk.in', 'case', 'advice', 'regardingthe', 'coverage', 'accordance', 'paragraph', 'kind', 'andare', 'sign', 'withor', 'trade', 'mark', 'trade', 'sale', 'lease', 'hire', 'relevanttrade', 'mark', 'circumstancesin', 'use', 'trade', 'mark', 'amount', 'aninfringement', 'example', 'trade', 'mark', 'wherethe', 'mark', 'question', 'relation', 'consent', 'owner', 'trade', 'mark.people', 'advice', 'practitioner', 'legislation', 'meaning', 'aninfringement', 'trade', 'mark', 'trade', 'mark', 'owner', 'assist', 'importerswho', 'use', 'office', 'capital', 'city', 'role', 'regardto']
# 38 번 문서 진행 중
# ['transit', 'capital', 'equipment', 'firm', 'order', 'date', 'firm', 'order', 'field', 'intransit', 'provision', 'subsection', 'theoperation', 'field', 'account', 'field', 'transit', 'item', 'capitalequipment', 'firm', 'date', 'instrument', 'intoforce', 'date', 'field', 'equipment', 'instrument', 'revocation', 'comply', 'instrument', 'item', 'duty', 'rate', 'rate', 'relevantitem', 'time', 'home', 'consumption', 'duty', 'rate', 'instrument', 'date', 'instrument', 'instrument', 'force', 'definition', 'capital', 'equipment', 'item', 'equipment', 'basis', 'order', 'subject', 'intermittentproduction', 'production', 'transit', 'example', 'subsection', 'field', 'example', 'user', 'entry', 'error', 'entry', 'comply', 'capital', 'equipment', 'instrumentand', 'item', 'user', 'user', 'field', 'information', 'field', 'line', 'date', 'firm', 'order', 'form', 'example', 'firm', 'entries.the', 'below.1', 'nature', 'date.3', 'valuation', 'instrument', 'transit', 'report', 'code', 'report', 'tariff', 'classification', 'capital', 'equipment', 'transit', 'instrument']
# 39 번 문서 진행 중
# ['excise', 'duty', 'aviation', 'gasoline', 'aviation', 'keroseneaustralian', 'release', 'areduction', 'litre', 'duty', 'aviation', 'gasoline', 'aviation', 'duty', 'rate', 'reduction', 'recovery', 'aviation', 'industry', 'contribution', 'industry', 'contribution', 'alevy', 'duty', 'aviation', 'detail', 'ratesof', 'duty', 'aviation', 'gasoline', 'litre', 'aviation', 'kerosene', 'litre', 'operate', 'tariff', 'connection', 'ande65', 'chapter', 'duty', 'duty', 'c96/09784', 'c96/10006']
# 40 번 문서 진행 중
# ['cost', 'recovery', 'import', 'cost', 'recovery', 'toprocess', 'passage', 'legislation', 'recovery', 'cargo', 'reporting', 'sea', 'air', 'import', 'entry', 'sea', 'air', 'processing', 'export', 'community', 'protection', 'detection', 'interception', 'activity', 'costing', 'import', 'costing', 'structure', 'amendmentsare', 'revenue', 'structure', 'entry', 'line', 'refund', 'application', 'fee', 'rate', 'ofappropriate', 'collection', 'mechanism', 'implementation', 'phase', 'series', 'industry', 'briefing', 'sea', 'line', 'line', 'importer', 'entry', 'home', 'consumption', 'sea', 'line', 'linethe', 'importer', 'entry', 'air', 'post', 'line', 'line', 'importer', 'entry', 'charge', 'air', 'line', 'linethe', 'importer', 'entry', 'charge', 'sea', 'linethe', 'cargo', 'handler', 'charge', 'air', 'house', 'airway', 'billthe', 'cargo', 'handler', 'charge', 'air', 'import', 'house', 'airway', 'billthe', 'cargo', 'handler', 'ex-warehouse', 'line', 'line', 'owner', 'removal', 'ex-warehouse', 'line', 'linethe', 'owner', 'removal', 'warehouse']
# 41 번 문서 진행 중
# ['section', 'operation', 'seizure', 'organisation', 'owner', 'material', 'section', 'action', 'organisation', 'objection', 'importation', 'copyright.unless', 'force', 'end', 'period', 'logo', 'person', 'outline', 'atop', 'grotesque', 'city', 'state', 'information', 'control', 'regime', 'range', 'material', 'regard', 'number', 'border', 'copyright', 'logodescribed', 'authorisation', 'seizure', 'court', 'action', 'person', 'c96/02298']
# 42 번 문서 진행 중
# ['objection', 'schedule', 'section', 'importation', 'relation', 'tothem', 'sign', 'trade', 'mark/s', 'forcefor', 'period', 'commencement', 'date', 'trade', 'mark.the', 'schedule', 'trademark', 'regard', 'trade', 'mark/s', 'question', 'regard', 'variety', 'trade', 'diversity', 'ithas', 'schedule', 'asterisk', 'case', 'coverage', 'office', 'accordance', 'finalparagraph', 'kind', 'sign', 'trade', 'mark', 'trade', 'sale', 'lease', 'hire', 'trade', 'use', 'trade', 'mark', 'amount', 'infringement', 'example', 'trade', 'mark', 'mark', 'question', 'relation', 'consent', 'owner', 'trade', 'mark.people', 'provisionsof', 'advice', 'legalpractitioner', 'trade', 'legislation', 'meaning', 'infringement', 'trade', 'mark', 'trade', 'mark', 'owner', 'regardinguse', 'trade', 'office', 'capital', 'city', 'eachstate', 'information', 'rolein', 'regard', 'capital', 'city.', 'trademark', 'enforcement', '.description', 'perfumery', 'toilet', 'hair', 'soap', 'class', 'starch', 'blue', 'class']
# 43 번 문서 진행 중
# ['section', 'operation', 'seizure', 'company', 'owner', 'material', 'section', 'action', 'thecompany', 'objection', 'importation', 'copyright.unless', 'force', 'end', 'period', 'consultantstelephone', 'footwear', 'side', 'heel', 'logo', 'logo', 'logo', 'information', 'tag', 'footwear.the', 'company', 'range', 'material', 'regard', 'company', 'representative', 'number', 'border', 'copyright', 'logo', 'authorisation', 'seizure', 'objector', 'court', 'action', 'person', 'capital', 'city', 'state', 'control', 'regime', 'c96/10090']
# 44 번 문서 진행 중
# ['section', 'operation', 'seizure', 'licensee', 'material', 'section', 'ofthe', 'action', 'company', 'objection', 'importation', 'copyright.unless', 'inforce', 'end', 'period', 'logos/labels.contactconner', 'date', 'file', 'packaging', 'brand', 'cosmetics.effective', 'date', 'file']
# 45 번 문서 진행 중
# ['agent', 'issue', 'expire', 'renewal', 'licences.as', 'licence', 'corporate', 'nominee', 'licence', 'writtenapplication', 'failure', 'licence', 'c.o.b', 'licence', 'invalid', 'date', 'application', 'receipt', 'newapplication', 'pursuant', 'application', 'report', 'applicant', 'order', 'processing', 'licence', 'form', 'concert', 'thencalac', 'review', 'part', 'thereview', 'review', 'team', 'possibility', 'c.o.b', 'threeor', 'reason', 'confusion', 'year', 'majority', 'holiday', 'industry', 'swing.an', 'review', 'date.corporate', 'application', 'list', 'list', 'authority', 'relation', 'request', 'accordance', 'theact', 'condition', 'licence', 'thirty', 'changeof', 'composition', 'partnership.payment', 'respect', 'renewal', 'licence', 'day', 'renewal', 'ofthe', 'licence', 'force', '.in', 'order', 'renewal', 'process', 'payment', 'time', 'fee', 'respect', 'grant', 'renewal', 'person', 'time', 'licence', 'or2', 'case']
# 46 번 문서 진행 중
# ['compliance', 'review', 'compliance', 'compliance', 'restructure', 'rationalisation', 'industry', 'sector', 'establishment', 'industry', 'relevance', 'role', 'risk', 'analysis', 'compliance', 'activity', 'industry', 'group']
# 47 번 문서 진행 중
# ['objection', 'schedule', 'section', 'importation', 'relation', 'tothem', 'sign', 'trade', 'mark/s', 'forcefor', 'period', 'commencement', 'date', 'trade', 'mark.the', 'schedule', 'trademark', 'regard', 'trade', 'mark/s', 'question', 'regard', 'variety', 'trade', 'diversity', 'ithas', 'schedule', 'asterisk', 'case', 'coverage', 'office', 'accordance', 'finalparagraph', 'kind', 'sign', 'trade', 'mark', 'trade', 'sale', 'lease', 'hire', 'trade', 'use', 'trade', 'mark', 'amount', 'infringement', 'example', 'trade', 'mark', 'mark', 'question', 'relation', 'consent', 'owner', 'trade', 'mark.people', 'provisionsof', 'advice', 'legalpractitioner', 'trade', 'legislation', 'meaning', 'infringement', 'trade', 'mark', 'trade', 'mark', 'owner', 'regardinguse', 'trade', 'office', 'capital', 'city', 'eachstate', 'information', 'rolein', 'regard', 'capital', 'city.', 'company']
# 48 번 문서 진행 중
# ['introduction', 'drug', 'fantasy', 'amendment', 'abuse', 'substance', 'attention', 'incident', 'inqueensland', 'mixture', 'substance', 'safety', 'immediateintroduction', 'drug', 'purpose', 'use', 'anaesthetic.regulation', 'importation', 'byoperation', 'to10f', 'exportation', 'operation', 'importation', 'exportation', 'class', 'acid', 'substance', '.section', 'prescribes', 'imprisonment', 'relation', 'class', 'acid', 'substance', 'refers.should', 'ofhealth', 'c94/09008']
# 49 번 문서 진행 중
# ['port', 'payment', 'cash', 'policy', 'payment', 'time', 'distinction', 'thepayment', 'site', 'number', 'treatment', 'port', 'payment', 'clearance', 'entrieswill', 'line', 'practices.as', 'allcompile', 'port', 'wide.if', 'information', 'c96/09754']
# 50 번 문서 진행 중
# ['objection', 'company', 'importation', 'relation', 'tothem', 'sign', 'trade', 'mark/s', 'forcefor', 'period', 'commencement', 'date', 'trade', 'mark.the', 'schedule', 'trademark', 'regard', 'trade', 'mark/s', 'question', 'regard', 'variety', 'trade', 'diversity', 'ithas', 'schedule', 'asterisk', 'case', 'coverage', 'office', 'accordance', 'finalparagraph', 'kind', 'sign', 'trade', 'mark', 'trade', 'sale', 'lease', 'hire', 'trade', 'use', 'trade', 'mark', 'amount', 'infringement', 'example', 'trade', 'mark', 'mark', 'question', 'relation', 'consent', 'owner', 'trade', 'mark.people', 'provisionsof', 'advice', 'legalpractitioner', 'trade', 'legislation', 'meaning', 'infringement', 'trade', 'mark', 'trade', 'mark', 'owner', 'regardinguse', 'trade', 'office', 'capital', 'city', 'eachstate', 'information', 'role', 'regard', 'capital', 'city.', 'corporationcontact', 'disc', 'computer', 'computersoftware', 'computer', 'hardware', 'memory', 'use', 'embodyingcomputer', 'computer', 'software', 'firmware', 'therewith', 'class']
# 51 번 문서 진행 중
# ['cost', 'recovery', 'import', 'import', 'package', 'cost', 'recovery', 'import', 'debate', 'consequence', 'implementation', 'implementation', 'date']
# 52 번 문서 진행 중
# ['removal', 'margin', 'preference', 'decision', 'margin', 'preference', 'frompolystyrene', 'chloride', 'origin', 'rate', 'duty.tariff', 'reprint', 'change', 'instance', 'c95/7226']
# 53 번 문서 진행 중
# ['convention', 'import', 'treaty', 'development', 'production', 'use', 'reporting', 'verification', 'internationalinspectorate', 'force', 'implementation', 'place', 'session', 'member', 'action', 'nomenclatures.on', 'number', 'request', 'response', 'survey', 'course', 'action', 'bearing', 'mind', 'extent', 'cost', 'amongst', 'acid', 'acid', 'list', 'survey', 'status', 'attachment']
# 54 번 문서 진행 중
# ['amendment', 'export', 'regulation', 'export', 'republic', 'order', 'rule', 'refers.in', 'exportation', 'destination', 'whichwas', 'permission', 'person.in', 'accordance', 'relation', 'tothe', 'party', 'suspension', 'permission', 'regulationswhich', 'exportation', 'destination', 'area', 'andherzegovina', 'utility', 'hadwithdrawn', 'separation', 'suspension', 'obligation', 'suspension', 'exportation', 'utility', 'regulation', 'outcome', 'rule', 'effect', 'amendment', 'amendment']
# 55 번 문서 진행 중
# ['sydney', 'guide', 'operation', 'seizure', 'indicia', 'effect', 'scheme', 'owner', 'material', 'licensee', 'importation', 'and/or', 'matter', 'purpose', 'integrity', 'andparalympic', 'raising', 'licensing', 'revenue', 'protection', 'indicia', 'revenue', 'outcome', 'whilst', 'ensuringa', 'call', 'purse', 'event', 'royalty', 'sale', 'merchandise', 'after1', 'licence', 'import', 'merchandise', 'markings.1', 'scheme', 'respect', 'goodsand', 'section', 'resolution', 'action', 'theobjector', 'importation', 'and/or', 'images.2', 'seizure', 'control', 'and/or', 'importation', 'and/or', 'respect', 'opinion', 'and/or', 'owner', 'relation', 'tothe', 'believing', 'and/or', 'section', 'theuse', 'owner', 'indicia', 'and/or', 'security', 'thecommonwealth', 'respect', 'scheme', 'seizure', 'use', 'theimporter', 'section', 'seizure', 'action', 'behalf']
# 56 번 문서 진행 중
# ['by-law', 'system', 'change', 'delegation', 'effect', 'responsibility', 'administration', 'delegate', 'concession', 'future', 'c96/01195']
# 57 번 문서 진행 중
# ['input', 'project', 'committee', 'development', 'andimplementation', 'front-end', 'system.the', 'system', 'application', 'process', 'anefficient', 'secure', 'procedure', 'drawback', 'theintroduction', 'access', 'drawback', 'reliance', 'paper', 'correspondence', 'response', 'status', 'turnaround', 'time', 'payment', 'peak', 'industry', 'information', 'technology', 'service', 'drawback', 'clientswill', 'input', 'development', 'trial', 'system', 'flexibility', 'drawback', 'module', 'inhouse', 'system', 'range', 'software', 'opportunity', 'project', 'date.any']
# 58 번 문서 진행 중
# ['oil', 'gas', 'search', 'concession', 'item', 'item', 'purpose', 'concession', 'petroleum', 'industry', 'connection', 'exploration', 'discovery', 'oil', 'gas', 'pre-productiondevelopment', 'manufacture.the', 'provide', 'duty', 'entry', 'by-law', 'use', 'connection', 'exploration', 'petroleum', 'gas', 'use', 'connection', 'development', 'petroleum', 'gas', 'stage', 'awell-head', 'assembly', 'use', 'connection', 'petroleum', 'gas', 'assembly', 'respect', 'personin', 'course', 'business', '.development', 'restrictionsthe', 'restriction', 'development', 'petroleum', 'gas', 'stage', 'assembly', 'point', 'time', 'attachment', 'lastflange', 'christmas', 'tree', 'location', 'well', 'head', 'wellas', 'exploration', 'development', 'activity', 'well', 'policy', 'concession', 'inexploration', 'pre-production', 'development', 'entryunder', 'well', 'use', 'connection', 'development', 'petroleum', 'gas', 'use', 'connection', 'petroleum', 'gas', 'assembly', 'item.page', 'evidence', 'time', 'entry', 'home', 'consumption', 'person', 'course', 'business', 'form', 'tariff', 'force', 'time', 'entry', 'home', 'consumption', 'letter', 'organisation', 'letter', 'industry', 'association', 'letter', 'body', 'effect.this', 'course', 'business', 'case', 'matter', 'time', 'evidence', 'take', 'manufacture', 'addition', 'concession', 'by-law', 'prescribed', 'by-law', 'connection', 'exploration', 'development', 'example']
# 59 번 문서 진행 중
# ['part', 'withdrawal', 'application', 'act', 'part', 'initiation', 'aninvestigation', 'dumping', 'phthalate', 'investigation', 'consideration', 'application', 'application', 'accordance', 'regard', 'telephone', 'number', 'c96/11972']
# 60 번 문서 진행 중
# ['circumstance', 'notice', 'change', 'policy', 'relating', 'r.126', 'decision', 'onappeal', 'applicant', 'application', 'refund', 'r.128', 'confusion', 'procedure', 'refund', 'dutyin', 'result', 'decision', 'appeal', 'application', 'dispute', 'facility', 'system', 'refund', 'application.a', 'refund', 'dispute', 'accordance', 'refundapplication.any', 'relation', 'matter', 'c90/6254']
# 61 번 문서 진행 중
# ['objection', 'schedule', 'importation', 'theschedule', 'relation', 'sign', 'trade', 'mark/s', 'force', 'period', 'commencement', 'date', 'trade', 'mark.the', 'schedule', 'trade', 'regard', 'trade', 'mark/s', 'question', 'regard', 'variety', 'trade', 'diversity', 'asterisk', 'case', 'advice', 'coverage', 'objection', 'office', 'accordance', 'paragraph', 'kind', 'sign', 'relevanttrade', 'trade', 'sale', 'lease', 'hire', 'trade', 'use', 'trade', 'mark', 'amount', 'infringement', 'example', 'trade', 'mark', 'isnot', 'mark', 'question', 'relation', 'consent', 'owner', 'trade', 'mark.people', 'seekingadvice', 'practitioner', 'trade', 'legislation', 'meaning', 'infringement', 'trade', 'mark', 'trade', 'mark', 'owner', 'contact', 'use', 'trade', 'office', 'capital', 'city', 'information', 'role', 'regard', 'capital', 'city.', 'c96/13034contact', 'perfumery', 'cleaning', 'use', 'perfumery', 'jewellery', 'neck', 'bracelet', 'material', 'materialall', 'thread', 'needlework', 'yarn', 'needlework', 'silk', 'press', 'use', 'needlework', 'clothing', 'classchildren', 'classall', 'class']
# 62 번 문서 진행 중
# ['section', 'operation', 'seizure', 'material', 'section', 'action', 'objection', 'importation', 'copyright.unless', 'force', 'end', 'period', 'date', 'specified.objectorcontacta', 'amp', 'model', 'limitation', 'packaging', 'information', 'commencement', 'amp', 'packaging', 'contact', 'lensescommencement', 'c96/12326objectorcontactrocket', 'design', 'logo', 'commencement', 'c96/13067the', 'range', 'material', 'regard', 'company', 'representative', 'number', 'border', 'copyright', 'logo', 'authorisation', 'willbe', 'seizure', 'objector', 'court', 'action', 'person', 'capital', 'city', 'state', 'furtherinformation', 'control', 'regime', 'contacting']
# 63 번 문서 진행 중
# ['indexation', 'excise', 'tariff', 'diesel', 'fuel', 'rebateaustralian', 'accordance', 'indexation', 'beer', 'petroleum', 'rates.for', 'indexation', 'index', 'number', 'statistician', 'index', 'number', 'factor', 'index', 'duty', 'number', 'number', 'indexation', 'factor', 'diesel', 'fuel', 'rebate', 'accordance', 'sub-section', 'diesel', 'fuel', 'rebate', 'diesel', 'fuel', 'rebate', 'change', 'rate', 'rebate', 'rate', 'respect', 'diesel', 'fuel', 'rate', 'average', 'ratesof', 'rebate', 'force', 'day', 'month', 'application', 'rebate', 'rate', 'month', 'month', 'rate', 'claim', 'payment', 'advice', 'amp', 'amp', 'amp', 'tariff', 'reprint', 'connection', 'reprint', 'connection', 'date', 'amp', 'schedule', 'tariff', 'item', 'rate', 'duty1', 'litre', 'alcohol', 'alcohol', 'content', 'percentage', 'volume', 'alcohol']
# 64 번 문서 진행 중
# ['cost', 'recovery', 'implementation', 'framework', 'debate', 'commencement', 'notice', 'information', 'relation', 'entry', 'limit', 'cost', 'recovery', 'regime', 'import', 'depot', 'licensing', 'regime', 's.17', 'introduction', 'amendmentto', 'licence', 'fee', 'system', 'fee', 'system', 'number', 'licence', 'charge', 'volume', 'fee', 'fee', 'licensing', 'system', 'need', 'line', 'cargo', 'determination', 'volume', 'cargo', 'depot', 'consequent', 'fee', 'definition', 'cargo', 'part', 'report', 'reference', 'air', 'waybill', 'document', 'bill', 'document', 'relation', 'depot', 'period', 'cargo', 'thatplace', 'period.the', 'licensing', 'system', 'period', 'cargo', 'adepot', 'year', 's.17', 'theperiod', 'record', 'cargo', 'depot', 'month', 'date', 'effect', 'licence', '-ie', 'cargo', 'period', 'period', 'licence', 'fee', 'acombination', 'fee', 'fee', 'period', 'cargo', 'period', 'licence', 'fee', 'quarter', 'operation', 'period', 'rataapportionment', 'calculation', 'number', 'fee', 'fee', 'licence', 'fee', 'forthe', 'year', 'operation', 'basis', 'volume', 'fee', 'operation', 'transactionthroughput.4', 'entry', 'post']
# 65 번 문서 진행 중
# ['objection', 'schedule', 'section', 'importation', 'theschedule', 'relation', 'sign', 'trade', 'mark/s', 'force', 'period', 'commencement', 'date', 'trade', 'mark.the', 'schedule', 'trade', 'mark', 'regard', 'trade', 'mark/s', 'question', 'regard', 'variety', 'trade', 'diversity', 'asterisk', 'case', 'advice', 'coverage', 'office', 'accordance', 'paragraph', 'kind', 'sign', 'relevanttrade', 'mark', 'trade', 'sale', 'lease', 'hire', 'trade', 'use', 'trade', 'mark', 'amount', 'infringement', 'example', 'trade', 'mark', 'isnot', 'mark', 'question', 'relation', 'consent', 'owner', 'trade', 'mark.people', 'seekingadvice', 'practitioner', 'trade', 'legislation', 'meaning', 'infringement', 'trade', 'mark', 'trade', 'mark', 'owner', 'contact', 'use', 'trade', 'office', 'capital', 'city', 'information', 'role', 'regard', 'capital', 'city.', 'amp', 'mark', 'class', 'headwear', 'eye', 'wear', 'date', 'amp', 'class', 'writing', 'gift', 'desk', 'class.commencement', 'date', 'c96/12503country', 'class', 'class.class', 'class.class', 'class.class', 'classclass', 'class']
# 66 번 문서 진행 중
# ['section', 'operation', 'seizure', 'material', 'section', 'action', 'objection', 'importation', 'copyright.unless', 'force', 'end', 'period', 'date', 'specified.objectorcontacttdk', 'amp', 'amp', 'notariestelephone', 'diamond', 'logo', 'withoutlimitation', 'packaging', 'and/or', 'limitation', 'technicalinformation', 'information', 'packaging', 'products.commencement', 'amp', 'c96/11262the', 'range', 'material', 'regard', 'company', 'representative', 'number', 'border', 'copyright', 'logo', 'authorisation', 'seizure', 'objector', 'court', 'action', 'person', 'capital', 'city', 'state', 'furtherinformation', 'control', 'regime', 'contacting']
# 67 번 문서 진행 중
# ['objection', 'company', 'importation', 'relation', 'sign', 'trade', 'mark/s', 'force', 'period', 'thecommencement', 'date', 'trade', 'mark.the', 'schedule', 'trade', 'regard', 'trade', 'mark/s', 'question', 'regardto', 'variety', 'trade', 'diversity', 'asterisk', 'case', 'advice', 'coverage', 'office', 'accordancewith', 'paragraph', 'kind', 'sign', 'trade', 'trade', 'sale', 'lease', 'hire', 'trade', 'use', 'trade', 'mark', 'amount', 'infringement', 'example', 'trade', 'mark', 'mark', 'question', 'relation', 'consent', 'owner', 'trade', 'mark.people', 'advice', 'practitioner', 'trade', 'legislation', 'meaning', 'aninfringement', 'trade', 'mark', 'trade', 'mark', 'owner', 'contact', 'use', 'thetrade', 'office', 'capital', 'city', 'furtherinformation', 'role', 'regard', 'capital', 'city', 'contacting']
# 68 번 문서 진행 중
# ['objection', 'company', 'importation', 'relation', 'sign', 'trade', 'mark/s', 'force', 'period', 'thecommencement', 'date', 'trade', 'mark.the', 'schedule', 'trade', 'regard', 'trade', 'mark/s', 'question', 'regardto', 'variety', 'trade', 'diversity', 'asterisk', 'case', 'advice', 'coverage', 'office', 'accordancewith', 'paragraph', 'kind', 'sign', 'trade', 'trade', 'sale', 'lease', 'hire', 'trade', 'use', 'trade', 'mark', 'amount', 'infringement', 'example', 'trade', 'mark', 'mark', 'question', 'relation', 'consent', 'owner', 'trade', 'mark.people', 'advice', 'practitioner', 'trade', 'legislation', 'meaning', 'aninfringement', 'trade', 'mark', 'trade', 'mark', 'owner', 'contact', 'use', 'thetrade', 'office', 'capital', 'city', 'furtherinformation', 'role', 'regard', 'capital', 'city', 'contacting']
# 69 번 문서 진행 중
# ...
# 1647 번 문서 진행 중
# ['guidance', 'tariff', 'information', 'implementation', 'page', 'abf.gov.au', 'tariff', 'concession', 'review', 'implementation', 'concordance', 'page', 'concordance', 'classification', 'tariff', 'tariff', 'list', 'tariff', 'page', 'application', 'system', 'tariff', 'tariff', 'advice', 'time', 'by-law', 'tariff', 'by-law', 'text', 'by-law', 'tariff', 'page', 'service']
# 1648 번 문서 진행 중
# ['tariff', 'result', 'information', 'page', 'trade', 'list', 'transposition', 'respect', 'commencement', 'documentation', 'version', 'classification', 'one', 'version', 'product', 'origin', 'webpage', 'agreement', 'version', 'use', 'agreement', 'time', 'publication', 'origin', 'documentation', 'version', 'classification', 'importer', 'import', 'declaration', 'service']
# 1649 번 문서 진행 중
# ['application', 'application', 'individual', 'company', 'broker', 'licence', 'corporate', 'unit', 'trading', 'person', 'representation', 'respect', 'correspondence', 'email', 'brokers.licensing', 'fairness', 'respect', 'information', 'applicant', 'information', 'applicant', 'substance', 'representation', 'opportunity', 'representation']
# 1650 번 문서 진행 중
# ['force', 'force', 'subsection', 'instrument', 'day', 'agreement', 'force', 'code', 'table', 'use', 'table', 'force', 'information', 'please', 'refer', 'web', 'page', 'service']
# 1651 번 문서 진행 중
# ['application', 'application', 'broker', 'licence', 'individuals', 'person', 'representation', 'respect', 'correspondence', 'email', 'brokers.licensing', 'fairness', 'respect', 'information', 'applicant', 'information', 'applicant', 'substance', 'representation', 'opportunity', 'representation']
# 1652 번 문서 진행 중
# ['application', 'application', 'company', 'broker', 'licence', 'corporate', 'person', 'representation', 'respect', 'applicant', 'correspondence', 'email', 'brokers.licensing', 'fairness', 'respect', 'information', 'applicant', 'information', 'applicant', 'substance', 'representation', 'opportunity', 'representation']
# 1653 번 문서 진행 중
# ['indexation', 'duty', 'indexation', 'duty', 'notice', 'duty', 'fuel', 'section', 'duty', 'application', 'indexation', 'factor', 'indexation', 'factor', 'number', 'number', 'figure', 'indexation', 'factor', 'duty', 'rate', 'increase', 'figure', 'refer', 'figure', 'indexation', 'factor', 'table', 'number', 'indexation', 'factor', 'duty', 'application', 'factor', 'duty', 'indexation', 'schedule', 'service']
# 1654 번 문서 진행 중
# ['importation', 'schedule', 'amendment', 'community', 'place', 'need', 'permit', 'fine', 'penalty', 'imprisonment', 'entry', 'permission', 'accordance', 'schedule', 'schedule', 'list', 'import', 'device', 'substance', 'force', 'damage', 'property', 'part', 'schedule', 'order', 'amendment', 'control', 'warfare', 'item', 'schedule', 'information', 'please', 'legislation', 'statement', 'http', '//www.legislation.gov.au/details/f2022l00113', 'service']
# 1655 번 문서 진행 중
# ['application', 'application', 'broker', 'licence', 'individuals', 'person', 'representation', 'respect', 'correspondence', 'email', 'brokers.licensing', 'fairness', 'respect', 'information', 'applicant', 'information', 'applicant', 'substance', 'representation', 'opportunity', 'representation']
# 1656 번 문서 진행 중
# ['duty', 'tobacco', 'tobacco', 'duty', 'tobacco', 'tobacco', 'notice', 'duty', 'tobacco', 'tobacco', 'result', 'number', 'tobacco', 'rate', 'duty', 'tobacco', 'amount', 'duty', 'stick', 'basis', 'application', 'indexation', 'factor', 'factor', 'figure', 'figure', 'quarter', 'indexation', 'factor', 'duty', 'application', 'indexation', 'factor', 'indexation', 'factor', 'change', 'duty', 'indexation', 'factor', 'table', 'factor', 'conversion', 'factor', 'indexation', 'factor', 'amount', 'duty', 'stick', 'basis', 'tobacco', 'application', 'indexation', 'factor', 'tobacco', 'kilogram', 'kilogram', 'tobacco', 'rate', 'duty', 'amount', 'duty', 'kilogram', 'kilogram', 'tobacco', 'content', 'basis', 'rate', 'rate', 'weight', 'conversion', 'factor', 'rate', 'rate', 'weight', 'conversion', 'factor', 'service']
# 1657 번 문서 진행 중
# ['force', 'subsection', 'instrument', 'day', 'agreement', 'force', 'code', 'table', 'use', 'table', 'force', 'information', 'please', 'refer', 'web', 'page', 'service']
# 1658 번 문서 진행 중
# ['importation', 'exportation', 'importation', 'exportation', 'mercury', 'permission', 'mercury', 'importation', 'mercury', 'exportation', 'mercury', 'part', 'convention', 'mercury', 'mercury', 'mercury', 'mercury', 'concentration', 'weight', 'mercury', 'legislation', 'trade', 'manufacture', 'mercury', 'mercury', 'mercury', 'range', 'permission', 'mercury', 'officer', 'use', 'mercury', 'permission', 'legislation', 'agency']
# 1659 번 문서 진행 중
# ['repair', 'alteration', 'renovation', 'repair', 'alteration', 'renovation', 're-importation', 'sale', 'trade', 'code', 'export', 'declaration', 'quality', 'trade', 'merchandise', 'trade', 'burden', 'result', 'activity', 'merchandise', 'trade', 'status', 'repair', 'alteration', 'renovation', 're-importation', 'line', 'commodity', 'classification', 'code', 'table', 'website', 'sale', 'merchandise', 'trade', 'sale', 'maintenance', 'etc', 'trade', 'export', 'permit', 'law', 'export', 'permit', 'export', 'permit', 'prefix', 'export', 'permit', 'permit', 'contravention', 'section', 'export', 'penalty', 'penalty', 'imprisonment', 'plain', 'language', 'description', 'field', 'sufficient', 'nature', 'level', 'transport', 'banking', 'border', 'classification', 'copy', 'paste', 'description', 'field', 'description', 'way', 'invoice', 'documentation']
# 1660 번 문서 진행 중
# ['application', 'application', 'broker', 'person', 'representation', 'respect', 'correspondence', 'email', 'brokers.licensing', 'fairness', 'respect', 'information', 'applicant', 'information', 'applicant', 'substance', 'representation', 'opportunity', 'representation']
# 1661 번 문서 진행 중
# ['expansion', 'benefit', 'expansion', 'benefit', 'benefit', 'expansion', 'benefit', 'benefit', 'declaration', 'order', 'duty', 'trader', 'evidence', 'period', 'day', 'importation', 'comply', 'origin', 'present', 'evidence', 'evidence', 'proof', 'place', 'manufacture', 'documentation', 'relation', 'manufacturing', 'process', 'compliance', 'cost', 'evidence', 'origin', 'request', 'evidence', 'origin', 'producer', 'exporter', 'importer', 'duty', 'refund', 'benefit', 'application', 'refund', 'evidence', 'origin', 'documentation', 'manufacturer', 'service']
# 1662 번 문서 진행 중
# ['force', 'force', 'subsection', 'instrument', 'day', 'agreement', 'force', 'code', 'table', 'use', 'table', 'force', 'information', 'please', 'refer', 'page', 'service']
# 1663 번 문서 진행 중
# ['application', 'application', 'broker', 'individuals', 'person', 'representation', 'respect', 'correspondence', 'email', 'brokers.licensing', 'fairness', 'respect', 'information', 'applicant', 'information', 'applicant', 'substance', 'representation', 'opportunity', 'representation']
# 1664 번 문서 진행 중
# ['import', 'unit', 'timber', 'unit', 'import', 'tariff', 'grade', 'urea', 'diesel', 'exhaust', 'fluid', 'import', 'saxitoxin', 'ricin', 'tariff', 'tariff', 'classification', 'tariff', 'commencement', 'saxitoxin', 'ricin', 'date', 'unit', 'timber', 'timber', 'timber', 'timber', 'import', 'export', 'tariff', 'notice', 'abf.gov.au', 'service']
# 1665 번 문서 진행 중
# ['cent', 'reduction', 'component', 'fuel', 'duty', 'reduction', 'period', 'reduction', 'home', 'consumption', 'time', 'refund', 'circumstance', 'section', 'table', 'cent', 'reduction', 'valorem', 'rate', 'duty', 'tariff', 'section', 'indexation', 'accordance', 'indexation', 'factor', 'section', 'table', 'replacement', 'date', 'table', 'rate', 'replacement', 'date', 'section', 'table', 'cent', 'reduction', 'valorem', 'rate', 'duty', 'tariff', 'indexation', 'litre', 'kilogram', 'table', 'service']
# 1666 번 문서 진행 중
# ['importation', 'flag', 'seal', 'representation', 'importation', 'process', 'flag', 'seal', 'burden', 'importation', 'process', 'flag', 'seal', 'representation', 'importation', 'process', 'flag', 'seal', 'design', 'approval', 'state', 'territory', 'design', 'approval', 'import', 'permission', 'requirement', 'import', 'permit', 'flag', 'seal', 'post', 'importation', 'permission', 'scheme', 'amendment', 'place', 'need', 'flag', 'seal', 'representation', 'permit', 'fine', 'penalty', 'value', 'whichever', 'information', 'please', 'legislation', 'statement', 'http', '//www.legislation.gov.au/details/f2022l00512', 'information', 'please', 'see', 'http', 'service']
# 1667 번 문서 진행 중
# ['application', 'application', 'company', 'broker', 'licence', 'corporate', 'level', 'person', 'representation', 'respect', 'applicant', 'correspondence', 'email', 'brokers.licensing', 'fairness', 'respect', 'information', 'applicant', 'information', 'applicant', 'substance', 'representation', 'opportunity', 'representation']
# 1668 번 문서 진행 중
# ['calculation', 'importer', 'allocation', 'importer', 'usage', 'quota', 'home', 'consumption', 'year', 'quota', 'enter', 'home', 'consumption', 'cheese', 'curd', 'end', 'year', 'allocation', 'year', 'cheese', 'origin', 'rate', 'duty', 'quota', 'preference', 'apply', 'quota', 'cheese', 'curd', 'home', 'consumption', 'latter', 'date', 'lodgment', 'date', 'arrival', 'vessel', 'aircraft', 'port', 'airport', 'cargo', 'note', 'calculation', 'part', 'quota', 'importer', 'period', 'allocation', 'period', 'allocation', 'sum', 'quota', 'home', 'consumption', 'quota', 'home', 'consumption', 'home', 'consumption', 'allocation', 'year', 'home', 'consumption', 'year', 'time', 'year', 'stock', 'view', 'usage', 'allocation', 'service']
# 1669 번 문서 진행 중
# ['duty', 'goodsaustralian', 'duty', 'nation', 'treatment', 'duty', 'produce', 'manufacture', 'increase', 'duty', 'line', 'measure', 'response', 'invasion', 'protection', 'security', 'violation', 'law', 'sovereignty', 'integrity', 'order', 'stability', 'security', 'produce', 'manufacture', 'shipment', 'place', 'manufacture', 'warehouse', 'country', 'home', 'consumption', 'period', 'rate', 'duty', 'measure', 'accordance', 'section', 'produce', 'manufacture', 'meaning', 'process', 'manufacture', 'produce', 'manufacture', 'country', 'changing', 'packaging', 'condition', 'transport', 'storage', 'disassembly', 'packaging', 'packaging', 'sifting', 'screening', 'simple', 'note', 'list', 'list', 'produce', 'manufacture', 'service']
# 1670 번 문서 진행 중
# ['application', 'application', 'broker', 'person', 'representation', 'respect', 'correspondence', 'email', 'brokers.licensing', 'fairness', 'respect', 'information', 'applicant', 'information', 'applicant', 'substance', 'representation', 'opportunity', 'representation']
# 1671 번 문서 진행 중
# ['application', 'application', 'company', 'broker', 'corporate', 'person', 'representation', 'respect', 'correspondence', 'email', 'brokers.licensing', 'fairness', 'respect', 'information', 'applicant', 'information', 'applicant', 'substance', 'representation', 'opportunity', 'representation']
# 1672 번 문서 진행 중
# ['application', 'application', 'company', 'broker', 'individuals', 'person', 'representation', 'respect', 'correspondence', 'email', 'brokers.licensing', 'fairness', 'respect', 'information', 'applicant', 'information', 'applicant', 'substance', 'representation', 'opportunity', 'representation']
# 1673 번 문서 진행 중
# ['luxury', 'car', 'tax', 'car', 'tax', 'luxury', 'car', 'tax', 'year', 'effect', 'efficient', 'information', 'information', 'website', 'car', 'tax', 'rate', 'ato.qov.au', 'service']
# 1674 번 문서 진행 중
# ['application', 'application', 'company', 'broker', 'person', 'representation', 'respect', 'correspondence', 'email', 'brokers.licensing', 'fairness', 'respect', 'information', 'applicant', 'information', 'applicant', 'substance', 'representation', 'opportunity', 'representation']
# 1675 번 문서 진행 중
# ['commencement', 'phase', 'commencement', 'phase', 'effect', 'waste', 'plastic', 'export', 'waste', 'resin', 'polymer', 'type', 're-manufacture', 'processing', 'fuel', 'waste', 'export', 'licence', 'waste', 'plastic', 'waste', 'export', 'licence', 'plastic', 'export', 'consignment', 'waste', 'plastic', 'intent', 'measure', 'export', 'waste', 'plastic', 'impact', 'health', 'environment', 'country', 'ability', 'waste', 'sector', 'recycle', 'reuse', 'waste', 'plastic', 'waste', 'plastic', 'export', 'order', 'waste', 'export', 'licence', 'information', 'export', 'regulation', 'waste', 'environment.gov.au', 'service']
# 1676 번 문서 진행 중
# ['tariff', 'item', 'concession', 'scope', 'text', 'by-law', 'hygiene', 'apply', 'production', 'chapter', 'apply', 'chapter', 'treatment', 'item', 'by-law', 'item', 'treatment', 'treatment', 'code', 'by-law', 'number', 'item', 'by-law', 'notice', 'hygiene', 'use', 'droplet', 'spread', 'service']
# 1677 번 문서 진행 중
# ['disposal', 'disposal', 'period', 'disposal', 'importer', 'date', 'permission', 'time', 'i.e', 'home', 'consumption', 'day', 'importation', 'i.e', 'owner', 'home', 'consumption', 'place', 'disposal', 'month', 'period', 'evidence', 'timeframe', 'response', 'industry', 'feedback', 'consultation', 'reform', 'simpler', 'timeframe', 'period', 'depot', 'reduction', 'timeframe', 'warehouse', 'section', 'period', 'industry', 'charity', 'destroy', 'recycle', 'information']
# 1678 번 문서 진행 중
# ['reporting', 'mail', 'business', 'reporting', 'mail', 'business', 'notice', 'cargo', 'reporting', 'airline', 'mail', 'review', 'cargo', 'reporting', 'mail', 'behalf', 'business', 'cargo', 'mail', 'business', 'compliance', 'reporting', 'mail', 'section', 'ship', 'aircraft', 'port', 'airport', 'port', 'cargo', 'reporter1', 'cargo', 'reporter', 'ship', 'aircraft', 'voyage', 'flight', 'ship', 'aircraft', 'port', 'airport', 'port', 'airport', 'port', 'airport', 'voyage', 'flight', 'passenger', 'member', 'crew', 'aircraft', 'reporter', 'relation', 'ship', 'aircraft', 'relation', 'voyage', 'flight', 'operator', 'charterer', 'ship', 'aircraft', 'slot', 'charterer', 'respect', 'ship', 'forwarder', 'respect', 'ship', 'aircraft', 'voyage', 'flight', 'reference', 's.4', 'service']
# 1679 번 문서 진행 중
# ['application', 'application', 'company', 'broker', 'corporate', 'corporate', 'person', 'representation', 'respect', 'correspondence', 'email', 'brokers.licensing', 'fairness', 'respect', 'information', 'applicant', 'information', 'applicant', 'substance', 'representation', 'opportunity', 'representation']
# 1680 번 문서 진행 중
# ['duty', 'reduction', 'duty', 'reduction', 'month', 'period', 'produce', 'manufacture', 'rate', 'duty', 'arrangement', 'produce', 'manufacture', 'status', 'region', 'status', 'region', 'rate', 'duty', 'produce', 'manufacture', 'origin', 'registration', 'home', 'consumption', 'time', 'refund', 'circumstance', 'import', 'declaration', 'field', 'country', 'code', 'field', 'country', 'code', 'field', 'click', 'drop', 'button', 'field', 'click', 'drop', 'button', 'rule', 'origin', 'content', 'accumulation', 'product', 'service']
# 1681 번 문서 진행 중
# ['application', 'application', 'company', 'broker', 'individuals', 'person', 'representation', 'respect', 'correspondence', 'email', 'brokers.licensing', 'fairness', 'respect', 'information', 'applicant', 'information', 'applicant', 'substance', 'representation', 'opportunity', 'representation']
# 1682 번 문서 진행 중
# ['removal', 'duty', 'vehiclesaustralian', 'removal', 'duty', 'duty', 'value', 'fuel', 'luxury', 'car', 'tax', 'threshold', 'rate', 'duty', 'rate', 'duty', 'requirement', 'duty', 'cent', 'measure', 'text', 'note', 'tariff', 'home', 'consumption', 'year', 'threshold', 'fuel', 'efficient', 'publication', 'home', 'consumption', 'time', 'refund', 'circumstance', 'tariff', 'abf.gov.au', 'publication', 'issue', 'abf.gov.au', 'service']
# 1683 번 문서 진행 중
# ['indexation', 'duty', 'indexation', 'duty', 'notice', 'duty', 'fuel', 'section', 'duty', 'application', 'indexation', 'factor', 'indexation', 'factor', 'number', 'number', 'figure', 'indexation', 'factor', 'duty', 'rate', 'increase', 'figure', 'refer', 'figure', 'indexation', 'factor', 'table', 'number', 'indexation', 'factor', 'duty', 'application', 'factor', 'duty', 'indexation', 'schedule', 'service']

# %%
#키워드와 문서 유사도 비교 0.9
doc_keywords_9 = []
for index, doc in enumerate(doc_embedding):
    final_result = []
    for i in range(len(doc)):
        for j in range(len(keyword_embedding)):
            distances = cosine_similarity([doc[i]], [keyword_embedding[j]])
            if distances[0][0]>0.9:
                final_result.append(doc_words[index][i])
# distances = cosine_similarity([doc_embedding[0]], candidate_embeddings)
    print(set(final_result))
    doc_keywords_9.append(set(final_result))
# Out:
# set()
# set()
# set()
# set()
# set()
# set()
# {'paper'}
# set()
# set()
# set()
# set()
# {'paper'}
# {'paper'}
# set()
# set()
# set()
# {'alumina'}
# set()
# set()
# {'paper'}
# set()
# set()
# {'alumina'}
# set()
# {'cheese'}
# set()
# set()
# {'vehicle', 'machine'}
# set()
# {'computersand', 'computer'}
# set()
# set()
# set()
# set()
# set()
# {'machinery'}
# set()
# set()
# set()
# set()
# set()
# set()
# {'perfumery'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'computer'}
# set()
# set()
# set()
# set()
# set()
# set()
# {'paper'}
# {'oil'}
# set()
# set()
# {'perfumery'}
# set()
# {'alcohol'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'beverage', 'alcohol', 'wine'}
# set()
# set()
# set()
# set()
# {'alumina'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'oil', 'chemical'}
# set()
# set()
# {'cheese'}
# set()
# set()
# set()
# set()
# {'computer'}
# {'paper'}
# set()
# {'vehicle'}
# set()
# set()
# {'paper'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'alcohol'}
# set()
# set()
# set()
# {'machinery', 'computer'}
# set()
# {'vehicle'}
# set()
# {'computer'}
# {'computer', 'potato'}
# set()
# set()
# set()
# set()
# set()
# set()
# {'paper'}
# set()
# set()
# {'chemical', 'oil'}
# set()
# {'vehicle'}
# set()
# set()
# set()
# set()
# {'wine'}
# set()
# {'oil', 'chemical'}
# {'paper'}
# set()
# {'oil'}
# set()
# set()
# set()
# set()
# {'machinery'}
# {'machine'}
# set()
# set()
# set()
# {'machinery', "machinery'machinery"}
# set()
# set()
# set()
# set()
# set()
# {'machinery'}
# {'machinery'}
# {'chemical', 'paper'}
# {'computer'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'milk', 'grain'}
# set()
# {'computer'}
# {'plasticiser'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'cheese'}
# set()
# set()
# set()
# set()
# set()
# set()
# {'paper'}
# set()
# {'paper'}
# set()
# set()
# set()
# set()
# set()
# set()
# {'paper'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'medical'}
# {'oil', 'chemical', 'naphtha'}
# set()
# {'vehicle'}
# set()
# {'machinery', 'vehicle'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'paper'}
# set()
# set()
# {'lead', 'paper'}
# set()
# set()
# set()
# set()
# {'paper'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'machine'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'paper'}
# set()
# set()
# set()
# set()
# {'cheese'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'alcoholpng', 'alcohol', 'alcoholfi', 'alcoholnz'}
# set()
# set()
# {'machinery'}
# set()
# set()
# set()
# set()
# set()
# {'aluminium'}
# {'oil', 'aluminium'}
# set()
# set()
# set()
# set()
# {'computer'}
# set()
# set()
# set()
# set()
# set()
# set()
# {'paper'}
# {'computer', 'paperwork'}
# set()
# set()
# set()
# {'computer'}
# set()
# {'computer'}
# {'computer'}
# set()
# set()
# set()
# set()
# set()
# {'plastic'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'computer'}
# {'computer'}
# set()
# {'vehicle'}
# set()
# {'computer'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'benzene'}
# {'benzene'}
# set()
# set()
# set()
# {'computer'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'cheese'}
# set()
# set()
# set()
# set()
# set()
# set()
# {'vehicle'}
# set()
# set()
# set()
# set()
# set()
# set()
# {'anincrease'}
# {'alcohol'}
# set()
# set()
# set()
# {'aluminium'}
# set()
# set()
# set()
# {'computer'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'computer'}
# set()
# set()
# set()
# {'oil'}
# set()
# set()
# set()
# set()
# set()
# set()
# {'lead-up', 'vehicle'}
# set()
# set()
# set()
# {'alcohol'}
# set()
# {'vehicle'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'car', 'machinery'}
# set()
# set()
# set()
# {'alcohol'}
# set()
# set()
# set()
# set()
# set()
# {'cheese'}
# set()
# set()
# {'grape', 'alcohol', 'wine'}
# {'car'}
# set()
# set()
# set()
# set()
# {'oil'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'paper'}
# set()
# set()
# set()
# {'car'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'paper'}
# set()
# set()
# {'alcohol'}
# {'weaponsand'}
# set()
# set()
# set()
# set()
# set()
# set()
# {'aluminium', 'grain', 'pigment'}
# {'paper', 'aluminium', 'nickel', 'plastic', 'oil', 'vehicle'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'machinery'}
# set()
# set()
# set()
# set()
# set()
# {'machinery'}
# {'machine'}
# set()
# set()
# {'computer'}
# {'computer'}
# {'cheese'}
# set()
# {'computer'}
# set()
# set()
# {'car', 'vehicle'}
# set()
# set()
# {'alcohol'}
# set()
# {'sauce'}
# set()
# set()
# set()
# set()
# set()
# set()
# {'computer'}
# set()
# set()
# set()
# set()
# {'alcohol'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'paper'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'paper'}
# set()
# set()
# set()
# {'chemical'}
# set()
# set()
# set()
# {'lead'}
# set()
# {'computer'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'cheese'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'oil'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'oil'}
# {'computer'}
# set()
# set()
# set()
# {'vehicle'}
# set()
# set()
# set()
# set()
# set()
# set()
# {'vehicle', 'machine'}
# {'vehicle', 'machine'}
# set()
# set()
# set()
# set()
# set()
# set()
# {'computer'}
# set()
# set()
# set()
# set()
# set()
# {'machine'}
# set()
# set()
# set()
# set()
# set()
# {'oil', 'perfumery'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'chemical'}
# set()
# set()
# set()
# set()
# set()
# {'fish'}
# set()
# {'computer'}
# set()
# set()
# set()
# set()
# set()
# {'fish'}
# set()
# {'chemical', 'alcohol', 'oil'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'cheese'}
# set()
# {'grape', 'alcohol', 'wine'}
# {'paper'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'paper'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'weapon'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'machine'}
# set()
# set()
# set()
# set()
# {'vehicle'}
# {'machinery', 'vehicle'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'drink'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'drink'}
# set()
# set()
# {'beverage'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'benomyl'}
# set()
# set()
# {'oil', 'alcohol'}
# set()
# {'alcohol', 'wine'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'paper'}
# {'weapon'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'weapon'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'car', 'vehicle'}
# set()
# {'chemical'}
# {'plastic'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'alcoholic', 'liquor'}
# set()
# {'computer'}
# set()
# set()
# set()
# {'paper'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'cardboard'}
# {'alcohol'}
# set()
# set()
# set()
# set()
# set()
# set()
# {'cheese'}
# set()
# set()
# set()
# set()
# {'car', 'vehicle'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'alcoholic', 'liquor'}
# set()
# set()
# set()
# set()
# set()
# {'car', 'vehicle'}
# {'car'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'alcohol'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'oil'}
# set()
# {'machinery'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'car', 'vehicle'}
# set()
# set()
# {'grape', 'wine'}
# set()
# {'car', 'vehicle'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'vehicle'}
# set()
# set()
# set()
# set()
# set()
# {'computer'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'alcohol'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'car', 'vehicle'}
# set()
# set()
# {'cheese'}
# {'vehicle'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'computer', 'paper'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'machinery'}
# set()
# set()
# set()
# {'cheese'}
# set()
# set()
# {'paper'}
# set()
# set()
# set()
# {'computer'}
# set()
# {'cheese'}
# set()
# set()
# set()
# set()
# {'vehicle'}
# set()
# set()
# {'paper'}
# set()
# set()
# {'computer'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'paper'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'cheese'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'alcohol'}
# set()
# {'aluminium'}
# set()
# set()
# set()
# {'car', 'vehicle'}
# set()
# set()
# set()
# {'cheese'}
# set()
# {'paper'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'chemical', 'alcohol'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'wheat'}
# set()
# set()
# set()
# set()
# set()
# {'wheat'}
# set()
# set()
# set()
# set()
# {'paper'}
# set()
# set()
# set()
# {'cheese'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'cheese'}
# set()
# set()
# {'plastic'}
# set()
# set()
# {'cheese'}
# set()
# set()
# {'car', 'vehicle'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'vehicle'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'alcohol'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'cheese'}
# set()
# set()
# set()
# {'plastic'}
# set()
# set()
# set()
# set()
# set()
# set()
# {'car'}
# {'oil'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'cheese'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'paper'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'paper'}
# set()
# {'alcohol'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'cheese'}
# set()
# {'machinery', 'plastic'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'cheese'}
# set()
# set()
# set()
# {'paper'}
# set()
# set()
# {'chemical'}
# set()
# {'vehicle'}
# set()
# {'plastic'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'machinery', 'plastic'}
# set()
# set()
# {'cheese'}
# {'paper'}
# set()
# set()
# set()
# set()
# set()
# {'car'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'cheese'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'machinery', 'plastic'}
# {'cheese'}
# set()
# set()
# set()
# set()
# set()
# {'car'}
# set()
# set()
# set()
# set()
# set()
# set()
# {'alcohol'}
# set()
# set()
# set()
# {'cheese'}
# {'vehicle'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'aluminium'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'car'}
# set()
# set()
# set()
# set()
# set()
# {'machinery', 'plastic'}
# {'cheese'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'oil', 'seed'}
# {'car'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'cheese'}
# {'chemicalsaust'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'chemical'}
# set()
# set()
# set()
# set()
# set()
# set()
# {'paper'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'cheese'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'milk'}
# set()
# set()
# set()
# set()
# {'cheese'}
# set()
# set()
# set()
# set()
# set()
# {'car', 'vehicle'}
# set()
# set()
# set()
# set()
# set()
# set()
# {'beverage'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'alcohol'}
# set()
# {'vehicle'}
# set()
# set()
# set()
# set()
# {'alcohol'}
# set()
# {'cheese'}
# set()
# set()
# set()
# set()
# set()
# {'chemical'}
# set()
# {'car'}
# set()
# set()
# set()
# {'chemical'}
# set()
# set()
# set()
# {'cheese'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'cardboard', 'paper'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'cheese'}
# {'vehicle'}
# set()
# set()
# set()
# set()
# set()
# {'alcohol'}
# set()
# {'car'}
# set()
# set()
# {'cardboard', 'plastic', 'paper'}
# set()
# set()
# set()
# set()
# set()
# {'cheese'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'cardboard', 'plastic', 'paper'}
# set()
# {'beverage'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# {'cheese'}
# set()
# set()
# set()
# set()
# {'car'}
# set()
# {'plastic'}
# set()
# set()
# set()
# set()
# set()
# set()
# {'car'}
# set()

# %%
#키워드와 문서 유사도 비교 0.8
doc_keywords_8 = []
for index, doc in enumerate(doc_embedding):
    final_result = []
    for i in range(len(doc)):
        for j in range(len(keyword_embedding)):
            distances = cosine_similarity([doc[i]], [keyword_embedding[j]])
            if distances[0][0]>0.8:
                final_result.append(doc_words[index][i])
    doc_keywords_8.append(set(final_result))

# %%
#키워드와 문서 유사도 비교 0.75
doc_keywords_75 = []
for index, doc in enumerate(doc_embedding):
    print(index)
    final_result = []
    for i in range(len(doc)):
        for j in range(len(keyword_embedding)):
            distances = cosine_similarity([doc[i]], [keyword_embedding[j]])
            if distances[0][0]>0.75:
                final_result.append(doc_words[index][i])
    doc_keywords_75.append(set(final_result))

# %%
df_check = pd.DataFrame()
df_check['cosine 0.9'] = doc_keywords_9
df_check['cosine 0.8'] = doc_keywords_8
df_check['cosine 0.75'] = doc_keywords_75

df_check.head(30)

# %%
df['cosine 0.9'] = doc_keywords_9
df['cosine 0.8'] = doc_keywords_8
df['cosine 0.75'] = doc_keywords_75

df

# %%
# df.to_csv("호주_세관_최근10_유사도, 번역 추가.csv")
