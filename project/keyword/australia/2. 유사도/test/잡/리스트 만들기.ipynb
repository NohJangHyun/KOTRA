# %%
import pandas as pd
df = pd.read_csv("호주_세관고시_번역_mti_정렬1.csv")

# %%
A = str(df["4단위 MTI 코드"])
B = str(df["6단위 MTI 코드"])

# %%
B = df["6단위 MTI 코드"]

# %%
for b in range(len(B)):
    if len(str(B[b]))<6:
        B[b] = "0"+str(B[b])
# Out:
# C:\Users\water\AppData\Local\Temp\ipykernel_4856\1501219817.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   B[b] = "0"+str(B[b])

# %%
list = []
for b in B:
    list.append(str(b))
list
# Out:
# ['011110',
#  '011120',
#  '011130',
#  '011140',
#  '011160',
#  '011210',
#  '011220',
#  '011230',
#  '011310',
#  '011320',
#  '011330',
#  '011340',
#  '011350',
#  '011410',
#  '011420',
#  '011430',
#  '011440',
#  '011510',
#  '011520',
#  '011530',
#  '011540',
#  '011601',
#  '011602',
#  '011603',
#  '011604',
#  '011605',
#  '011606',
#  '011607',
#  '011608',
#  '011609',
#  '011610',
#  '011611',
#  '011612',
#  '011613',
#  '011614',
#  '011615',
#  '011616',
#  '011617',
#  '011618',
#  '011619',
#  '011620',
#  '011621',
#  '011622',
#  '011623',
#  '011624',
#  '012510',
#  '012520',
#  '012530',
#  '012550',
#  '012560',
#  '013110',
#  '013120',
#  '013130',
#  '013140',
#  '013210',
#  '014310',
#  '014320',
#  '014330',
#  '014340',
#  '014350',
#  '014360',
#  '014370',
#  '015110',
#  '015120',
#  '015210',
#  '015220',
#  '015710',
#  '015720',
#  '015730',
#  '015740',
#  '015750',
#  '015760',
#  '015810',
#  '015820',
#  '015830',
#  '015910',
# ...

# %%
X= " 011520,  011530,  011540,  011601,  011602,  011603,  011604,  011605,  011606,  011607,  011608,  011609,  011610,  011611,  011612,  011613,  011614,  011615,  011616,  011617,  011618,  011619,  011620,  011621,  011622,  011623,  011624,  012510,  012520,  012530,  012550,  012560,  013110,  013120,  013130,  013140,  013210,  014310,  014320,  014330,  014340,  014350,  014360,  014370,  015110,  015120,  015210,  015220,  015710,  015720,  015730,  015740,  015750,  015760,  015810,  015820,  015830,  015910,  015920,  015940,  016110,  016120,  016130,  019120,  019130,  022110,  022120,  022130,  022910,  023110,  023120,  024110,  024210,  024220,  024310,  024320,  024330,  024340,  024350,  119010,  134010,  134020,  135010,  135020,  211010,  211020,  211030,  211040,  211050,  211060,  214001,  214002,  214003,  214004,  214005,  214006,  214007,  214008,  214009,  214010,  214011,  214012,  214013,  214014,  214015,  227310,  227310,  227320,  227320,  227330,  227340,  227350,  227360,  227370,  441201,  441202,  441203,  441205,  441206,  441207,  441208,  441209,  441210,  441211,  441212,  441213,  441214,  441215,  441216,  441217,  441220,  449001,  449002,  449002,  449003,  449004,  449005,  449005,  449006,  449007,  449009,  449010,  449013,  511610,  511620,  511630,  511640,  511650,  511660,  511670,  617210,  617220,  621110,  621120,  621210,  621220,  621230,  621240,  621250,  621260,  622110,  622120,  622130,  623110,  623120,  623130,  623210,  623220,  623230,  623240,  623250,  623260,  625110,  625120,  625210,  625220,  625230,  625240,  626110,  626120,  711210,  711220,  711230,  721610,  721620,  725110,  725120,  725130,  729010,  729020,  742000,  742010,  790110,  813110,  813120,  813220,  813230,  813240,  813250,  813260,  814710,  814720,  814730,  814740,  814750,  814760,  814770,  814780,  815110,  815120,  815130,  815140,  815150,  815160,  815170,  815180,  822610"
Y=""
print(len(X))
for x in X:
    Y += x.strip()
print(len(Y))
print(Y)
# Out:
# 1951
# 1518
# ...
