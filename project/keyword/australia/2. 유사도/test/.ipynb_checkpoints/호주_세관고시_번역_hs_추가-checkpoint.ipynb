# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver

options = webdriver.ChromeOptions()
options.add_argument('window-size=1920x1080')
options.add_experimental_option("excludeSwitches", ["enable-logging"])
driver = webdriver.Chrome(options=options)

# %%
import time

driver.get('https://www.abf.gov.au/help-and-support/notices/australian-customs-notices')
time.sleep(2)

# %%
soup = BeautifulSoup(driver.page_source, 'lxml')

# %%
temp = soup.find('ul', attrs={'class' : 'pagination'}).find_all("li")

# %%
from selenium.webdriver.common.by import By
import re

# %%
dates = []
titles = []
links = []
last_page = len(temp)

for i in range(2,last_page):
    soup = BeautifulSoup(driver.page_source, 'lxml')
    
    date_rows = soup.select('div.col-sm-3 span')
    title_rows = soup.find('tbody').find_all('tr', attrs = {'class' : re.compile('^accordion-header')})
    link_rows = soup.find('tbody').find_all('tr', attrs = {'class' : re.compile('^accordion-content')})
    
    for row in date_rows:
        date = row.text
        dates.append(date)

    for row in title_rows:
        tds = row.find_all('td')
        title = tds[1].get_text().replace('Press Enter to show more details.', '')  
        titles.append(title)

    for row in link_rows:
        link = 'https://www.abf.gov.au' + row.a['href']
        links.append(link)
    
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
    time.sleep(2)
    
    elem = driver.find_element(By.LINK_TEXT,str(i))
    elem.click()
    time.sleep(1)

# %%
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.layout import LAParams
from pdfminer.converter import TextConverter
from pdfminer.pdfpage import PDFPage
import io
import urllib.request
import requests

# %%
def pdf_to_text(pdf_file):
    text_memory_file = io.StringIO()

    rsrcmgr = PDFResourceManager()
    device = TextConverter(rsrcmgr, text_memory_file, laparams=LAParams())
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    
    for page in PDFPage.get_pages(pdf_file):
        interpreter.process_page(page)
    text = text_memory_file.getvalue()
    text_memory_file.close()
   
    return text

# %%
texts = []
hscodes = []
start = 0
finish = len(links)

for i in range(start, finish): 
    split_texts = []
    
    url = links[i]
    response = requests.get(url)
    my_raw_data = response.content
    
    # online pdf to text by requests
    response = requests.get(url)
    pdf_memory_file = io.BytesIO()
    pdf_memory_file.write(response.content)
    
    pdf_text = pdf_to_text(pdf_memory_file)
    pdf_text = pdf_text.lower()

    # HS CODE 가져오기
    hscode = re.findall('\d{4}\.\d{2}', pdf_text)
    hscodes.append(list(set(hscode)))

    #[signed] 찾기 위해 단어 단위로 쪼개기
    split_words = pdf_text.split()
    
    sentence = ""
    for word in range(len(split_words)):
        
        #[signed]가 있는 경우
        if split_words[word] == "[signed]":
            texts.append(sentence)
            break
                  
        #assistant secretary가 있는 경우
        elif split_words[word] == "assistant" and len(split_words) > word+1:
            if split_words[word+1] == "secretary":
                texts.append(sentence)
                break
            else:
                sentence = sentence + " " + split_words[word]
                
        #customs and trade policy branch가 있는 경우
        elif split_words[word]== "customs" and len(split_words) > word+4:
            if split_words[word+1]=="and" and split_words[word+2]=="trade" and split_words[word+3]=="policy" and split_words[word+4]=="branch":
                texts.append(sentence)
                break
            else:
                sentence = sentence + " " + split_words[word]
             
        elif len(split_words) == word+1:
            sentence = sentence + " " + split_words[word]
            texts.append(sentence)

        else:
            sentence = sentence + " " + split_words[word]
          
    if len(texts)<i+1:
        texts.append("NONE")
        print(i+1, "번 문서 종료 / 총 길이는 : ", len(texts[i]))
    else:
        print(i+1, "번 문서 종료 / 총 길이는 : ", len(texts[i]))
# Out:
# 1 번 문서 종료 / 총 길이는 :  4077
# 2 번 문서 종료 / 총 길이는 :  1873
# 3 번 문서 종료 / 총 길이는 :  856
# 4 번 문서 종료 / 총 길이는 :  4378
# 5 번 문서 종료 / 총 길이는 :  1237
# 6 번 문서 종료 / 총 길이는 :  10651
# 7 번 문서 종료 / 총 길이는 :  2066
# 8 번 문서 종료 / 총 길이는 :  3523
# 9 번 문서 종료 / 총 길이는 :  1964
# 10 번 문서 종료 / 총 길이는 :  1024
# 11 번 문서 종료 / 총 길이는 :  668
# 12 번 문서 종료 / 총 길이는 :  1014
# 13 번 문서 종료 / 총 길이는 :  1037
# 14 번 문서 종료 / 총 길이는 :  844
# 15 번 문서 종료 / 총 길이는 :  9108
# 16 번 문서 종료 / 총 길이는 :  3549
# 17 번 문서 종료 / 총 길이는 :  1004
# 18 번 문서 종료 / 총 길이는 :  2275
# 19 번 문서 종료 / 총 길이는 :  4279
# 20 번 문서 종료 / 총 길이는 :  2318
# 21 번 문서 종료 / 총 길이는 :  847
# 22 번 문서 종료 / 총 길이는 :  1272
# 23 번 문서 종료 / 총 길이는 :  2159
# 24 번 문서 종료 / 총 길이는 :  841
# 25 번 문서 종료 / 총 길이는 :  4311
# 26 번 문서 종료 / 총 길이는 :  2646
# 27 번 문서 종료 / 총 길이는 :  1145
# 28 번 문서 종료 / 총 길이는 :  3345
# 29 번 문서 종료 / 총 길이는 :  867
# 30 번 문서 종료 / 총 길이는 :  2159
# 31 번 문서 종료 / 총 길이는 :  3532
# 32 번 문서 종료 / 총 길이는 :  935
# 33 번 문서 종료 / 총 길이는 :  828
# 34 번 문서 종료 / 총 길이는 :  1304
# 35 번 문서 종료 / 총 길이는 :  1176
# 36 번 문서 종료 / 총 길이는 :  4268
# 37 번 문서 종료 / 총 길이는 :  4979
# 38 번 문서 종료 / 총 길이는 :  4791
# 39 번 문서 종료 / 총 길이는 :  1006
# 40 번 문서 종료 / 총 길이는 :  2518
# 41 번 문서 종료 / 총 길이는 :  3709
# 42 번 문서 종료 / 총 길이는 :  1211
# 43 번 문서 종료 / 총 길이는 :  1815
# 44 번 문서 종료 / 총 길이는 :  1235
# 45 번 문서 종료 / 총 길이는 :  2619
# 46 번 문서 종료 / 총 길이는 :  1028
# 47 번 문서 종료 / 총 길이는 :  2571
# 48 번 문서 종료 / 총 길이는 :  2549
# 49 번 문서 종료 / 총 길이는 :  8247
# 50 번 문서 종료 / 총 길이는 :  2908
# 51 번 문서 종료 / 총 길이는 :  1259
# 52 번 문서 종료 / 총 길이는 :  3652
# 53 번 문서 종료 / 총 길이는 :  3078
# 54 번 문서 종료 / 총 길이는 :  1551
# 55 번 문서 종료 / 총 길이는 :  2394
# 56 번 문서 종료 / 총 길이는 :  1858
# 57 번 문서 종료 / 총 길이는 :  3439
# 58 번 문서 종료 / 총 길이는 :  1766
# 59 번 문서 종료 / 총 길이는 :  2163
# 60 번 문서 종료 / 총 길이는 :  1896
# 61 번 문서 종료 / 총 길이는 :  1957
# 62 번 문서 종료 / 총 길이는 :  2343
# 63 번 문서 종료 / 총 길이는 :  1227
# 64 번 문서 종료 / 총 길이는 :  3356
# 65 번 문서 종료 / 총 길이는 :  653
# 66 번 문서 종료 / 총 길이는 :  840
# 67 번 문서 종료 / 총 길이는 :  6768
# 68 번 문서 종료 / 총 길이는 :  1272
# 69 번 문서 종료 / 총 길이는 :  2504
# 70 번 문서 종료 / 총 길이는 :  2391
# 71 번 문서 종료 / 총 길이는 :  844
# 72 번 문서 종료 / 총 길이는 :  906
# 73 번 문서 종료 / 총 길이는 :  2612
# 74 번 문서 종료 / 총 길이는 :  3548
# 75 번 문서 종료 / 총 길이는 :  5960
# 76 번 문서 종료 / 총 길이는 :  834
# 77 번 문서 종료 / 총 길이는 :  1936
# 78 번 문서 종료 / 총 길이는 :  3251
# 79 번 문서 종료 / 총 길이는 :  965
# 80 번 문서 종료 / 총 길이는 :  11883
# 81 번 문서 종료 / 총 길이는 :  3441
# 82 번 문서 종료 / 총 길이는 :  847
# 83 번 문서 종료 / 총 길이는 :  839
# 84 번 문서 종료 / 총 길이는 :  2476
# 85 번 문서 종료 / 총 길이는 :  1625
# 86 번 문서 종료 / 총 길이는 :  6728
# 87 번 문서 종료 / 총 길이는 :  1231
# 88 번 문서 종료 / 총 길이는 :  1697
# 89 번 문서 종료 / 총 길이는 :  1612
# 90 번 문서 종료 / 총 길이는 :  1647
# 91 번 문서 종료 / 총 길이는 :  831
# 92 번 문서 종료 / 총 길이는 :  3352
# 93 번 문서 종료 / 총 길이는 :  1877
# 94 번 문서 종료 / 총 길이는 :  2934
# 95 번 문서 종료 / 총 길이는 :  854
# 96 번 문서 종료 / 총 길이는 :  851
# 97 번 문서 종료 / 총 길이는 :  3941
# 98 번 문서 종료 / 총 길이는 :  2286
# 99 번 문서 종료 / 총 길이는 :  1001
# 100 번 문서 종료 / 총 길이는 :  1100
# 101 번 문서 종료 / 총 길이는 :  852
# 102 번 문서 종료 / 총 길이는 :  1048
# 103 번 문서 종료 / 총 길이는 :  1575
# 104 번 문서 종료 / 총 길이는 :  1644
# 105 번 문서 종료 / 총 길이는 :  5000
# 106 번 문서 종료 / 총 길이는 :  1099
# 107 번 문서 종료 / 총 길이는 :  3364
# 108 번 문서 종료 / 총 길이는 :  1859
# 109 번 문서 종료 / 총 길이는 :  1038
# 110 번 문서 종료 / 총 길이는 :  2291
# 111 번 문서 종료 / 총 길이는 :  1447
# 112 번 문서 종료 / 총 길이는 :  1948
# 113 번 문서 종료 / 총 길이는 :  1091
# 114 번 문서 종료 / 총 길이는 :  4115
# 115 번 문서 종료 / 총 길이는 :  2059
# 116 번 문서 종료 / 총 길이는 :  632
# 117 번 문서 종료 / 총 길이는 :  1053
# 118 번 문서 종료 / 총 길이는 :  1659
# 119 번 문서 종료 / 총 길이는 :  2605
# 120 번 문서 종료 / 총 길이는 :  1399
# 121 번 문서 종료 / 총 길이는 :  4148
# 122 번 문서 종료 / 총 길이는 :  1013
# 123 번 문서 종료 / 총 길이는 :  2406
# 124 번 문서 종료 / 총 길이는 :  3540
# 125 번 문서 종료 / 총 길이는 :  2196
# 126 번 문서 종료 / 총 길이는 :  3052
# 127 번 문서 종료 / 총 길이는 :  3812
# 128 번 문서 종료 / 총 길이는 :  1102
# 129 번 문서 종료 / 총 길이는 :  1335
# 130 번 문서 종료 / 총 길이는 :  5090
# 131 번 문서 종료 / 총 길이는 :  3181
# 132 번 문서 종료 / 총 길이는 :  7036
# 133 번 문서 종료 / 총 길이는 :  3494
# 134 번 문서 종료 / 총 길이는 :  1089
# 135 번 문서 종료 / 총 길이는 :  3058
# 136 번 문서 종료 / 총 길이는 :  1144
# 137 번 문서 종료 / 총 길이는 :  33089
# 138 번 문서 종료 / 총 길이는 :  851
# 139 번 문서 종료 / 총 길이는 :  6921
# 140 번 문서 종료 / 총 길이는 :  3450
# 141 번 문서 종료 / 총 길이는 :  1893
# 142 번 문서 종료 / 총 길이는 :  5512
# 143 번 문서 종료 / 총 길이는 :  1094
# 144 번 문서 종료 / 총 길이는 :  3829
# 145 번 문서 종료 / 총 길이는 :  4100
# 146 번 문서 종료 / 총 길이는 :  1295
# 147 번 문서 종료 / 총 길이는 :  1130
# 148 번 문서 종료 / 총 길이는 :  2798
# 149 번 문서 종료 / 총 길이는 :  1477
# 150 번 문서 종료 / 총 길이는 :  1374
# 151 번 문서 종료 / 총 길이는 :  876
# 152 번 문서 종료 / 총 길이는 :  1891
# 153 번 문서 종료 / 총 길이는 :  4837
# 154 번 문서 종료 / 총 길이는 :  2925
# 155 번 문서 종료 / 총 길이는 :  1832
# 156 번 문서 종료 / 총 길이는 :  3005
# 157 번 문서 종료 / 총 길이는 :  878
# 158 번 문서 종료 / 총 길이는 :  3306
# 159 번 문서 종료 / 총 길이는 :  861
# 160 번 문서 종료 / 총 길이는 :  2891
# 161 번 문서 종료 / 총 길이는 :  1572
# 162 번 문서 종료 / 총 길이는 :  2498
# 163 번 문서 종료 / 총 길이는 :  1119
# 164 번 문서 종료 / 총 길이는 :  11203
# 165 번 문서 종료 / 총 길이는 :  5411
# 166 번 문서 종료 / 총 길이는 :  3935
# 167 번 문서 종료 / 총 길이는 :  1418
# 168 번 문서 종료 / 총 길이는 :  899
# 169 번 문서 종료 / 총 길이는 :  3584
# 170 번 문서 종료 / 총 길이는 :  1119
# 171 번 문서 종료 / 총 길이는 :  3812
# 172 번 문서 종료 / 총 길이는 :  1781
# 173 번 문서 종료 / 총 길이는 :  4123
# 174 번 문서 종료 / 총 길이는 :  3439
# 175 번 문서 종료 / 총 길이는 :  3152
# 176 번 문서 종료 / 총 길이는 :  1073
# 177 번 문서 종료 / 총 길이는 :  4814
# 178 번 문서 종료 / 총 길이는 :  1060
# 179 번 문서 종료 / 총 길이는 :  1059
# 180 번 문서 종료 / 총 길이는 :  2044
# 181 번 문서 종료 / 총 길이는 :  3067
# 182 번 문서 종료 / 총 길이는 :  884
# 183 번 문서 종료 / 총 길이는 :  1247
# 184 번 문서 종료 / 총 길이는 :  1931
# 185 번 문서 종료 / 총 길이는 :  3654
# 186 번 문서 종료 / 총 길이는 :  2087
# 187 번 문서 종료 / 총 길이는 :  6312
# 188 번 문서 종료 / 총 길이는 :  915
# 189 번 문서 종료 / 총 길이는 :  4022
# 190 번 문서 종료 / 총 길이는 :  1608
# 191 번 문서 종료 / 총 길이는 :  893
# 192 번 문서 종료 / 총 길이는 :  3274
# 193 번 문서 종료 / 총 길이는 :  901
# 194 번 문서 종료 / 총 길이는 :  1918
# 195 번 문서 종료 / 총 길이는 :  1297
# 196 번 문서 종료 / 총 길이는 :  4785
# 197 번 문서 종료 / 총 길이는 :  2292
# 198 번 문서 종료 / 총 길이는 :  2837
# The PDF <_io.BytesIO object at 0x00000280940CAA90> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. Use the check_extractable if you want to raise an error in this case
# 199 번 문서 종료 / 총 길이는 :  4769
# 200 번 문서 종료 / 총 길이는 :  2980
# 201 번 문서 종료 / 총 길이는 :  2212
# 202 번 문서 종료 / 총 길이는 :  1111
# 203 번 문서 종료 / 총 길이는 :  1327
# 204 번 문서 종료 / 총 길이는 :  1765
# 205 번 문서 종료 / 총 길이는 :  1286
# 206 번 문서 종료 / 총 길이는 :  920
# 207 번 문서 종료 / 총 길이는 :  1775
# 208 번 문서 종료 / 총 길이는 :  1497
# 209 번 문서 종료 / 총 길이는 :  1779
# 210 번 문서 종료 / 총 길이는 :  3932
# 211 번 문서 종료 / 총 길이는 :  4609
# 212 번 문서 종료 / 총 길이는 :  1298
# 213 번 문서 종료 / 총 길이는 :  1231
# 214 번 문서 종료 / 총 길이는 :  2039
# 215 번 문서 종료 / 총 길이는 :  1788
# 216 번 문서 종료 / 총 길이는 :  1130
# 217 번 문서 종료 / 총 길이는 :  3529
# 218 번 문서 종료 / 총 길이는 :  1686
# 219 번 문서 종료 / 총 길이는 :  4864
# 220 번 문서 종료 / 총 길이는 :  919
# 221 번 문서 종료 / 총 길이는 :  3083
# 222 번 문서 종료 / 총 길이는 :  2931
# 223 번 문서 종료 / 총 길이는 :  2785
# 224 번 문서 종료 / 총 길이는 :  1153
# 225 번 문서 종료 / 총 길이는 :  1230
# 226 번 문서 종료 / 총 길이는 :  3536
# 227 번 문서 종료 / 총 길이는 :  1862
# 228 번 문서 종료 / 총 길이는 :  2736
# 229 번 문서 종료 / 총 길이는 :  3435
# 230 번 문서 종료 / 총 길이는 :  3691
# 231 번 문서 종료 / 총 길이는 :  2446
# 232 번 문서 종료 / 총 길이는 :  2546
# 233 번 문서 종료 / 총 길이는 :  1429
# 234 번 문서 종료 / 총 길이는 :  1625
# 235 번 문서 종료 / 총 길이는 :  9332
# 236 번 문서 종료 / 총 길이는 :  2273
# 237 번 문서 종료 / 총 길이는 :  1696
# 238 번 문서 종료 / 총 길이는 :  1942
# 239 번 문서 종료 / 총 길이는 :  1981
# 240 번 문서 종료 / 총 길이는 :  2510
# 241 번 문서 종료 / 총 길이는 :  5624
# 242 번 문서 종료 / 총 길이는 :  2096
# 243 번 문서 종료 / 총 길이는 :  5459
# 244 번 문서 종료 / 총 길이는 :  886
# 245 번 문서 종료 / 총 길이는 :  997
# 246 번 문서 종료 / 총 길이는 :  2127
# 247 번 문서 종료 / 총 길이는 :  5878
# 248 번 문서 종료 / 총 길이는 :  3037
# 249 번 문서 종료 / 총 길이는 :  3039
# 250 번 문서 종료 / 총 길이는 :  3113
# 251 번 문서 종료 / 총 길이는 :  7631
# 252 번 문서 종료 / 총 길이는 :  5758
# 253 번 문서 종료 / 총 길이는 :  940
# 254 번 문서 종료 / 총 길이는 :  5122
# 255 번 문서 종료 / 총 길이는 :  744
# 256 번 문서 종료 / 총 길이는 :  3884
# 257 번 문서 종료 / 총 길이는 :  1675
# 258 번 문서 종료 / 총 길이는 :  964
# 259 번 문서 종료 / 총 길이는 :  3309
# 260 번 문서 종료 / 총 길이는 :  1797
# 261 번 문서 종료 / 총 길이는 :  2058
# 262 번 문서 종료 / 총 길이는 :  3221
# 263 번 문서 종료 / 총 길이는 :  1468
# 264 번 문서 종료 / 총 길이는 :  1846
# 265 번 문서 종료 / 총 길이는 :  4595
# 266 번 문서 종료 / 총 길이는 :  1103
# 267 번 문서 종료 / 총 길이는 :  4668
# 268 번 문서 종료 / 총 길이는 :  4433
# 269 번 문서 종료 / 총 길이는 :  7691
# 270 번 문서 종료 / 총 길이는 :  2525
# 271 번 문서 종료 / 총 길이는 :  1614
# 272 번 문서 종료 / 총 길이는 :  4934
# 273 번 문서 종료 / 총 길이는 :  3703
# 274 번 문서 종료 / 총 길이는 :  8066
# 275 번 문서 종료 / 총 길이는 :  7965
# 276 번 문서 종료 / 총 길이는 :  1171
# 277 번 문서 종료 / 총 길이는 :  1839
# 278 번 문서 종료 / 총 길이는 :  4678
# 279 번 문서 종료 / 총 길이는 :  998
# 280 번 문서 종료 / 총 길이는 :  6487
# 281 번 문서 종료 / 총 길이는 :  4065
# 282 번 문서 종료 / 총 길이는 :  1799
# 283 번 문서 종료 / 총 길이는 :  4056
# 284 번 문서 종료 / 총 길이는 :  2925
# 285 번 문서 종료 / 총 길이는 :  2483
# 286 번 문서 종료 / 총 길이는 :  987
# 287 번 문서 종료 / 총 길이는 :  1145
# 288 번 문서 종료 / 총 길이는 :  1057
# 289 번 문서 종료 / 총 길이는 :  1546
# 290 번 문서 종료 / 총 길이는 :  1182
# 291 번 문서 종료 / 총 길이는 :  3081
# 292 번 문서 종료 / 총 길이는 :  1980
# 293 번 문서 종료 / 총 길이는 :  1159
# 294 번 문서 종료 / 총 길이는 :  1611
# 295 번 문서 종료 / 총 길이는 :  3355
# 296 번 문서 종료 / 총 길이는 :  2166
# 297 번 문서 종료 / 총 길이는 :  1004
# 298 번 문서 종료 / 총 길이는 :  1785
# 299 번 문서 종료 / 총 길이는 :  1187
# 300 번 문서 종료 / 총 길이는 :  3147
# 301 번 문서 종료 / 총 길이는 :  1217
# 302 번 문서 종료 / 총 길이는 :  3980
# 303 번 문서 종료 / 총 길이는 :  1531
# 304 번 문서 종료 / 총 길이는 :  1486
# 305 번 문서 종료 / 총 길이는 :  1682
# 306 번 문서 종료 / 총 길이는 :  1551
# 307 번 문서 종료 / 총 길이는 :  15676
# 308 번 문서 종료 / 총 길이는 :  4103
# 309 번 문서 종료 / 총 길이는 :  1830
# 310 번 문서 종료 / 총 길이는 :  3553
# 311 번 문서 종료 / 총 길이는 :  2134
# 312 번 문서 종료 / 총 길이는 :  1331
# 313 번 문서 종료 / 총 길이는 :  2735
# 314 번 문서 종료 / 총 길이는 :  1224
# 315 번 문서 종료 / 총 길이는 :  1703
# 316 번 문서 종료 / 총 길이는 :  1192
# 317 번 문서 종료 / 총 길이는 :  2181
# 318 번 문서 종료 / 총 길이는 :  3804
# 319 번 문서 종료 / 총 길이는 :  3247
# 320 번 문서 종료 / 총 길이는 :  1833
# 321 번 문서 종료 / 총 길이는 :  3822
# 322 번 문서 종료 / 총 길이는 :  976
# 323 번 문서 종료 / 총 길이는 :  1192
# 324 번 문서 종료 / 총 길이는 :  2970
# 325 번 문서 종료 / 총 길이는 :  4
# 326 번 문서 종료 / 총 길이는 :  2436
# 327 번 문서 종료 / 총 길이는 :  4776
# 328 번 문서 종료 / 총 길이는 :  1076
# 329 번 문서 종료 / 총 길이는 :  5677
# 330 번 문서 종료 / 총 길이는 :  945
# 331 번 문서 종료 / 총 길이는 :  1532
# 332 번 문서 종료 / 총 길이는 :  1155
# 333 번 문서 종료 / 총 길이는 :  3331
# 334 번 문서 종료 / 총 길이는 :  5570
# 335 번 문서 종료 / 총 길이는 :  3437
# 336 번 문서 종료 / 총 길이는 :  1897
# 337 번 문서 종료 / 총 길이는 :  948
# 338 번 문서 종료 / 총 길이는 :  2371
# 339 번 문서 종료 / 총 길이는 :  4068
# 340 번 문서 종료 / 총 길이는 :  970
# 341 번 문서 종료 / 총 길이는 :  1753
# 342 번 문서 종료 / 총 길이는 :  2636
# 343 번 문서 종료 / 총 길이는 :  1192
# 344 번 문서 종료 / 총 길이는 :  17333
# 345 번 문서 종료 / 총 길이는 :  16480
# 346 번 문서 종료 / 총 길이는 :  1547
# 347 번 문서 종료 / 총 길이는 :  4435
# 348 번 문서 종료 / 총 길이는 :  1270
# 349 번 문서 종료 / 총 길이는 :  2214
# 350 번 문서 종료 / 총 길이는 :  1955
# 351 번 문서 종료 / 총 길이는 :  2608
# 352 번 문서 종료 / 총 길이는 :  1323
# 353 번 문서 종료 / 총 길이는 :  1472
# 354 번 문서 종료 / 총 길이는 :  1044
# 355 번 문서 종료 / 총 길이는 :  7377
# 356 번 문서 종료 / 총 길이는 :  4398
# 357 번 문서 종료 / 총 길이는 :  1368
# 358 번 문서 종료 / 총 길이는 :  8535
# 359 번 문서 종료 / 총 길이는 :  2871
# 360 번 문서 종료 / 총 길이는 :  7215
# 361 번 문서 종료 / 총 길이는 :  1054
# 362 번 문서 종료 / 총 길이는 :  1454
# 363 번 문서 종료 / 총 길이는 :  1949
# 364 번 문서 종료 / 총 길이는 :  959
# 365 번 문서 종료 / 총 길이는 :  1210
# 366 번 문서 종료 / 총 길이는 :  3274
# 367 번 문서 종료 / 총 길이는 :  4154
# 368 번 문서 종료 / 총 길이는 :  1062
# 369 번 문서 종료 / 총 길이는 :  6358
# 370 번 문서 종료 / 총 길이는 :  1009
# 371 번 문서 종료 / 총 길이는 :  4
# 372 번 문서 종료 / 총 길이는 :  4
# 373 번 문서 종료 / 총 길이는 :  6214
# 374 번 문서 종료 / 총 길이는 :  1021
# 375 번 문서 종료 / 총 길이는 :  2650
# 376 번 문서 종료 / 총 길이는 :  1072
# 377 번 문서 종료 / 총 길이는 :  1373
# 378 번 문서 종료 / 총 길이는 :  1080
# 379 번 문서 종료 / 총 길이는 :  1002
# 380 번 문서 종료 / 총 길이는 :  5898
# 381 번 문서 종료 / 총 길이는 :  1288
# 382 번 문서 종료 / 총 길이는 :  4
# 383 번 문서 종료 / 총 길이는 :  1040
# 384 번 문서 종료 / 총 길이는 :  4312
# 385 번 문서 종료 / 총 길이는 :  1953
# 386 번 문서 종료 / 총 길이는 :  1004
# 387 번 문서 종료 / 총 길이는 :  4789
# 388 번 문서 종료 / 총 길이는 :  3173
# 389 번 문서 종료 / 총 길이는 :  1423
# 390 번 문서 종료 / 총 길이는 :  4
# 391 번 문서 종료 / 총 길이는 :  1460
# 392 번 문서 종료 / 총 길이는 :  3308
# 393 번 문서 종료 / 총 길이는 :  1346
# 394 번 문서 종료 / 총 길이는 :  3518
# 395 번 문서 종료 / 총 길이는 :  1446
# 396 번 문서 종료 / 총 길이는 :  1813
# 397 번 문서 종료 / 총 길이는 :  1437
# 398 번 문서 종료 / 총 길이는 :  1857
# 399 번 문서 종료 / 총 길이는 :  1262
# 400 번 문서 종료 / 총 길이는 :  1413
# 401 번 문서 종료 / 총 길이는 :  868
# 402 번 문서 종료 / 총 길이는 :  6063
# 403 번 문서 종료 / 총 길이는 :  1247
# 404 번 문서 종료 / 총 길이는 :  1381
# 405 번 문서 종료 / 총 길이는 :  2675
# 406 번 문서 종료 / 총 길이는 :  3513
# 407 번 문서 종료 / 총 길이는 :  1512
# 408 번 문서 종료 / 총 길이는 :  5184
# 409 번 문서 종료 / 총 길이는 :  4
# 410 번 문서 종료 / 총 길이는 :  3426
# 411 번 문서 종료 / 총 길이는 :  1425
# 412 번 문서 종료 / 총 길이는 :  1302
# 413 번 문서 종료 / 총 길이는 :  1195
# 414 번 문서 종료 / 총 길이는 :  2461
# 415 번 문서 종료 / 총 길이는 :  2207
# 416 번 문서 종료 / 총 길이는 :  3820
# 417 번 문서 종료 / 총 길이는 :  3272
# 418 번 문서 종료 / 총 길이는 :  1198
# 419 번 문서 종료 / 총 길이는 :  1175
# 420 번 문서 종료 / 총 길이는 :  1180
# 421 번 문서 종료 / 총 길이는 :  1414
# 422 번 문서 종료 / 총 길이는 :  1081
# 423 번 문서 종료 / 총 길이는 :  1181
# 424 번 문서 종료 / 총 길이는 :  4
# 425 번 문서 종료 / 총 길이는 :  1273
# 426 번 문서 종료 / 총 길이는 :  1546
# 427 번 문서 종료 / 총 길이는 :  1260
# 428 번 문서 종료 / 총 길이는 :  1217
# 429 번 문서 종료 / 총 길이는 :  1463
# 430 번 문서 종료 / 총 길이는 :  1222
# 431 번 문서 종료 / 총 길이는 :  1471
# 432 번 문서 종료 / 총 길이는 :  1333
# 433 번 문서 종료 / 총 길이는 :  1406
# 434 번 문서 종료 / 총 길이는 :  1096
# 435 번 문서 종료 / 총 길이는 :  1309
# 436 번 문서 종료 / 총 길이는 :  1445
# 437 번 문서 종료 / 총 길이는 :  6624
# 438 번 문서 종료 / 총 길이는 :  6448
# 439 번 문서 종료 / 총 길이는 :  1207
# 440 번 문서 종료 / 총 길이는 :  2104
# 441 번 문서 종료 / 총 길이는 :  4
# 442 번 문서 종료 / 총 길이는 :  1823
# 443 번 문서 종료 / 총 길이는 :  3961
# 444 번 문서 종료 / 총 길이는 :  4529
# 445 번 문서 종료 / 총 길이는 :  1690
# 446 번 문서 종료 / 총 길이는 :  4
# 447 번 문서 종료 / 총 길이는 :  1349
# 448 번 문서 종료 / 총 길이는 :  6477
# 449 번 문서 종료 / 총 길이는 :  1754
# 450 번 문서 종료 / 총 길이는 :  1940
# 451 번 문서 종료 / 총 길이는 :  4
# 452 번 문서 종료 / 총 길이는 :  1849
# 453 번 문서 종료 / 총 길이는 :  2165
# 454 번 문서 종료 / 총 길이는 :  5254
# 455 번 문서 종료 / 총 길이는 :  986
# 456 번 문서 종료 / 총 길이는 :  3334
# 457 번 문서 종료 / 총 길이는 :  3545
# 458 번 문서 종료 / 총 길이는 :  1285
# 459 번 문서 종료 / 총 길이는 :  1133
# 460 번 문서 종료 / 총 길이는 :  2897
# 461 번 문서 종료 / 총 길이는 :  1055
# 462 번 문서 종료 / 총 길이는 :  12379
# 463 번 문서 종료 / 총 길이는 :  1144
# 464 번 문서 종료 / 총 길이는 :  1126
# 465 번 문서 종료 / 총 길이는 :  4
# 466 번 문서 종료 / 총 길이는 :  6834
# 467 번 문서 종료 / 총 길이는 :  1891
# 468 번 문서 종료 / 총 길이는 :  1402
# 469 번 문서 종료 / 총 길이는 :  1013
# 470 번 문서 종료 / 총 길이는 :  4
# 471 번 문서 종료 / 총 길이는 :  4
# 472 번 문서 종료 / 총 길이는 :  4
# 473 번 문서 종료 / 총 길이는 :  16716
# 474 번 문서 종료 / 총 길이는 :  1639
# 475 번 문서 종료 / 총 길이는 :  1922
# 476 번 문서 종료 / 총 길이는 :  2342
# 477 번 문서 종료 / 총 길이는 :  4051
# 478 번 문서 종료 / 총 길이는 :  683
# 479 번 문서 종료 / 총 길이는 :  1412
# 480 번 문서 종료 / 총 길이는 :  1980
# 481 번 문서 종료 / 총 길이는 :  3372
# 482 번 문서 종료 / 총 길이는 :  3801
# 483 번 문서 종료 / 총 길이는 :  1797
# 484 번 문서 종료 / 총 길이는 :  1076
# 485 번 문서 종료 / 총 길이는 :  22840
# 486 번 문서 종료 / 총 길이는 :  1876
# 487 번 문서 종료 / 총 길이는 :  1257
# 488 번 문서 종료 / 총 길이는 :  1071
# 489 번 문서 종료 / 총 길이는 :  1397
# 490 번 문서 종료 / 총 길이는 :  1315
# 491 번 문서 종료 / 총 길이는 :  1058
# 492 번 문서 종료 / 총 길이는 :  4
# 493 번 문서 종료 / 총 길이는 :  2602
# 494 번 문서 종료 / 총 길이는 :  1158
# 495 번 문서 종료 / 총 길이는 :  7070
# 496 번 문서 종료 / 총 길이는 :  11942
# 497 번 문서 종료 / 총 길이는 :  29351
# 498 번 문서 종료 / 총 길이는 :  1212
# 499 번 문서 종료 / 총 길이는 :  1022
# 500 번 문서 종료 / 총 길이는 :  4110
# 501 번 문서 종료 / 총 길이는 :  1755
# 502 번 문서 종료 / 총 길이는 :  24258
# 503 번 문서 종료 / 총 길이는 :  3108
# 504 번 문서 종료 / 총 길이는 :  43703
# 505 번 문서 종료 / 총 길이는 :  5880
# 506 번 문서 종료 / 총 길이는 :  1314
# 507 번 문서 종료 / 총 길이는 :  1332
# 508 번 문서 종료 / 총 길이는 :  5665
# 509 번 문서 종료 / 총 길이는 :  1073
# 510 번 문서 종료 / 총 길이는 :  33508
# 511 번 문서 종료 / 총 길이는 :  1722
# 512 번 문서 종료 / 총 길이는 :  2466
# 513 번 문서 종료 / 총 길이는 :  1342
# 514 번 문서 종료 / 총 길이는 :  1285
# 515 번 문서 종료 / 총 길이는 :  2554
# 516 번 문서 종료 / 총 길이는 :  3646
# 517 번 문서 종료 / 총 길이는 :  1502
# 518 번 문서 종료 / 총 길이는 :  3146
# 519 번 문서 종료 / 총 길이는 :  1333
# 520 번 문서 종료 / 총 길이는 :  1306
# 521 번 문서 종료 / 총 길이는 :  1444
# 522 번 문서 종료 / 총 길이는 :  8350
# 523 번 문서 종료 / 총 길이는 :  1108
# 524 번 문서 종료 / 총 길이는 :  1431
# 525 번 문서 종료 / 총 길이는 :  2876
# 526 번 문서 종료 / 총 길이는 :  1326
# 527 번 문서 종료 / 총 길이는 :  1970
# 528 번 문서 종료 / 총 길이는 :  2879
# 529 번 문서 종료 / 총 길이는 :  1297
# 530 번 문서 종료 / 총 길이는 :  2786
# 531 번 문서 종료 / 총 길이는 :  2205
# 532 번 문서 종료 / 총 길이는 :  1564
# 533 번 문서 종료 / 총 길이는 :  3336
# 534 번 문서 종료 / 총 길이는 :  1272
# 535 번 문서 종료 / 총 길이는 :  29429
# 536 번 문서 종료 / 총 길이는 :  1617
# 537 번 문서 종료 / 총 길이는 :  867
# 538 번 문서 종료 / 총 길이는 :  1653
# 539 번 문서 종료 / 총 길이는 :  2737
# 540 번 문서 종료 / 총 길이는 :  3620
# 541 번 문서 종료 / 총 길이는 :  1092
# 542 번 문서 종료 / 총 길이는 :  1390
# 543 번 문서 종료 / 총 길이는 :  9161
# 544 번 문서 종료 / 총 길이는 :  20137
# 545 번 문서 종료 / 총 길이는 :  2790
# 546 번 문서 종료 / 총 길이는 :  4304
# 547 번 문서 종료 / 총 길이는 :  1517
# 548 번 문서 종료 / 총 길이는 :  1398
# 549 번 문서 종료 / 총 길이는 :  1340
# 550 번 문서 종료 / 총 길이는 :  5859
# 551 번 문서 종료 / 총 길이는 :  1426
# 552 번 문서 종료 / 총 길이는 :  1828
# 553 번 문서 종료 / 총 길이는 :  17251
# 554 번 문서 종료 / 총 길이는 :  3257
# 555 번 문서 종료 / 총 길이는 :  1936
# 556 번 문서 종료 / 총 길이는 :  1197
# 557 번 문서 종료 / 총 길이는 :  1696
# 558 번 문서 종료 / 총 길이는 :  3256
# 559 번 문서 종료 / 총 길이는 :  1472
# 560 번 문서 종료 / 총 길이는 :  4766
# 561 번 문서 종료 / 총 길이는 :  1453
# 562 번 문서 종료 / 총 길이는 :  3066
# 563 번 문서 종료 / 총 길이는 :  1358
# 564 번 문서 종료 / 총 길이는 :  1217
# 565 번 문서 종료 / 총 길이는 :  1995
# 566 번 문서 종료 / 총 길이는 :  1854
# 567 번 문서 종료 / 총 길이는 :  1622
# 568 번 문서 종료 / 총 길이는 :  2858
# 569 번 문서 종료 / 총 길이는 :  1383
# 570 번 문서 종료 / 총 길이는 :  1208
# 571 번 문서 종료 / 총 길이는 :  29040
# 572 번 문서 종료 / 총 길이는 :  1525
# 573 번 문서 종료 / 총 길이는 :  7405
# 574 번 문서 종료 / 총 길이는 :  1420
# 575 번 문서 종료 / 총 길이는 :  1627
# 576 번 문서 종료 / 총 길이는 :  1163
# 577 번 문서 종료 / 총 길이는 :  4471
# 578 번 문서 종료 / 총 길이는 :  1515
# 579 번 문서 종료 / 총 길이는 :  2209
# 580 번 문서 종료 / 총 길이는 :  1472
# 581 번 문서 종료 / 총 길이는 :  12117
# 582 번 문서 종료 / 총 길이는 :  3572
# 583 번 문서 종료 / 총 길이는 :  2038
# 584 번 문서 종료 / 총 길이는 :  4397
# 585 번 문서 종료 / 총 길이는 :  1552
# 586 번 문서 종료 / 총 길이는 :  5060
# 587 번 문서 종료 / 총 길이는 :  7687
# 588 번 문서 종료 / 총 길이는 :  1414
# 589 번 문서 종료 / 총 길이는 :  1904
# 590 번 문서 종료 / 총 길이는 :  4
# 591 번 문서 종료 / 총 길이는 :  1893
# 592 번 문서 종료 / 총 길이는 :  1232
# 593 번 문서 종료 / 총 길이는 :  1401
# 594 번 문서 종료 / 총 길이는 :  29136
# 595 번 문서 종료 / 총 길이는 :  2184
# 596 번 문서 종료 / 총 길이는 :  1441
# 597 번 문서 종료 / 총 길이는 :  1555
# 598 번 문서 종료 / 총 길이는 :  1117
# 599 번 문서 종료 / 총 길이는 :  8689
# 600 번 문서 종료 / 총 길이는 :  2104
# 601 번 문서 종료 / 총 길이는 :  1009
# 602 번 문서 종료 / 총 길이는 :  2155
# 603 번 문서 종료 / 총 길이는 :  1755
# 604 번 문서 종료 / 총 길이는 :  1203
# 605 번 문서 종료 / 총 길이는 :  3108
# 606 번 문서 종료 / 총 길이는 :  1500
# 607 번 문서 종료 / 총 길이는 :  1580
# 608 번 문서 종료 / 총 길이는 :  6365
# 609 번 문서 종료 / 총 길이는 :  1775
# 610 번 문서 종료 / 총 길이는 :  1724
# 611 번 문서 종료 / 총 길이는 :  2875
# 612 번 문서 종료 / 총 길이는 :  3753
# 613 번 문서 종료 / 총 길이는 :  7321
# 614 번 문서 종료 / 총 길이는 :  1257
# 615 번 문서 종료 / 총 길이는 :  1643
# 616 번 문서 종료 / 총 길이는 :  4798
# 617 번 문서 종료 / 총 길이는 :  1232
# 618 번 문서 종료 / 총 길이는 :  29020
# 619 번 문서 종료 / 총 길이는 :  1430
# 620 번 문서 종료 / 총 길이는 :  2833
# 621 번 문서 종료 / 총 길이는 :  1751
# 622 번 문서 종료 / 총 길이는 :  1729
# 623 번 문서 종료 / 총 길이는 :  4129
# 624 번 문서 종료 / 총 길이는 :  1266
# 625 번 문서 종료 / 총 길이는 :  1423
# 626 번 문서 종료 / 총 길이는 :  2041
# 627 번 문서 종료 / 총 길이는 :  1409
# 628 번 문서 종료 / 총 길이는 :  1458
# 629 번 문서 종료 / 총 길이는 :  2560
# 630 번 문서 종료 / 총 길이는 :  1332
# 631 번 문서 종료 / 총 길이는 :  1361
# 632 번 문서 종료 / 총 길이는 :  5376
# 633 번 문서 종료 / 총 길이는 :  1310
# 634 번 문서 종료 / 총 길이는 :  2219
# 635 번 문서 종료 / 총 길이는 :  1379
# 636 번 문서 종료 / 총 길이는 :  1234
# 637 번 문서 종료 / 총 길이는 :  1118
# 638 번 문서 종료 / 총 길이는 :  1009
# 639 번 문서 종료 / 총 길이는 :  1303
# 640 번 문서 종료 / 총 길이는 :  2661
# 641 번 문서 종료 / 총 길이는 :  1397
# 642 번 문서 종료 / 총 길이는 :  4926
# 643 번 문서 종료 / 총 길이는 :  4501
# 644 번 문서 종료 / 총 길이는 :  2397
# 645 번 문서 종료 / 총 길이는 :  1369
# 646 번 문서 종료 / 총 길이는 :  18427
# 647 번 문서 종료 / 총 길이는 :  1125
# 648 번 문서 종료 / 총 길이는 :  1320
# 649 번 문서 종료 / 총 길이는 :  1870
# 650 번 문서 종료 / 총 길이는 :  1814
# 651 번 문서 종료 / 총 길이는 :  29080
# 652 번 문서 종료 / 총 길이는 :  1118
# 653 번 문서 종료 / 총 길이는 :  22569
# 654 번 문서 종료 / 총 길이는 :  1033
# 655 번 문서 종료 / 총 길이는 :  2046
# 656 번 문서 종료 / 총 길이는 :  1389
# 657 번 문서 종료 / 총 길이는 :  2944
# 658 번 문서 종료 / 총 길이는 :  1427
# 659 번 문서 종료 / 총 길이는 :  1027
# 660 번 문서 종료 / 총 길이는 :  1539
# 661 번 문서 종료 / 총 길이는 :  1230
# 662 번 문서 종료 / 총 길이는 :  1839
# 663 번 문서 종료 / 총 길이는 :  9207
# 664 번 문서 종료 / 총 길이는 :  1971
# 665 번 문서 종료 / 총 길이는 :  4881
# 666 번 문서 종료 / 총 길이는 :  1318
# 667 번 문서 종료 / 총 길이는 :  1102
# 668 번 문서 종료 / 총 길이는 :  26384
# 669 번 문서 종료 / 총 길이는 :  1105
# 670 번 문서 종료 / 총 길이는 :  1056
# 671 번 문서 종료 / 총 길이는 :  6186
# 672 번 문서 종료 / 총 길이는 :  1256
# 673 번 문서 종료 / 총 길이는 :  12403
# 674 번 문서 종료 / 총 길이는 :  1104
# 675 번 문서 종료 / 총 길이는 :  1607
# 676 번 문서 종료 / 총 길이는 :  6137
# 677 번 문서 종료 / 총 길이는 :  1249
# 678 번 문서 종료 / 총 길이는 :  23452
# 679 번 문서 종료 / 총 길이는 :  1327
# 680 번 문서 종료 / 총 길이는 :  1124
# 681 번 문서 종료 / 총 길이는 :  2082
# 682 번 문서 종료 / 총 길이는 :  4580
# 683 번 문서 종료 / 총 길이는 :  1699
# 684 번 문서 종료 / 총 길이는 :  1517
# 685 번 문서 종료 / 총 길이는 :  3949
# 686 번 문서 종료 / 총 길이는 :  1479
# 687 번 문서 종료 / 총 길이는 :  1779
# 688 번 문서 종료 / 총 길이는 :  1464
# 689 번 문서 종료 / 총 길이는 :  1257
# 690 번 문서 종료 / 총 길이는 :  1251
# 691 번 문서 종료 / 총 길이는 :  1473
# 692 번 문서 종료 / 총 길이는 :  1327
# 693 번 문서 종료 / 총 길이는 :  1121
# 694 번 문서 종료 / 총 길이는 :  4063
# 695 번 문서 종료 / 총 길이는 :  1717
# 696 번 문서 종료 / 총 길이는 :  1399
# 697 번 문서 종료 / 총 길이는 :  1751
# 698 번 문서 종료 / 총 길이는 :  5652
# 699 번 문서 종료 / 총 길이는 :  16062
# 700 번 문서 종료 / 총 길이는 :  3014
# 701 번 문서 종료 / 총 길이는 :  8423
# 702 번 문서 종료 / 총 길이는 :  1357
# 703 번 문서 종료 / 총 길이는 :  2708
# 704 번 문서 종료 / 총 길이는 :  19724
# 705 번 문서 종료 / 총 길이는 :  1172
# 706 번 문서 종료 / 총 길이는 :  2193
# 707 번 문서 종료 / 총 길이는 :  2297
# 708 번 문서 종료 / 총 길이는 :  1398
# 709 번 문서 종료 / 총 길이는 :  1368
# 710 번 문서 종료 / 총 길이는 :  1989
# 711 번 문서 종료 / 총 길이는 :  1498
# 712 번 문서 종료 / 총 길이는 :  2102
# 713 번 문서 종료 / 총 길이는 :  1533
# 714 번 문서 종료 / 총 길이는 :  1326
# 715 번 문서 종료 / 총 길이는 :  1540
# 716 번 문서 종료 / 총 길이는 :  1307
# 717 번 문서 종료 / 총 길이는 :  3882
# 718 번 문서 종료 / 총 길이는 :  2841
# 719 번 문서 종료 / 총 길이는 :  6316
# 720 번 문서 종료 / 총 길이는 :  1153
# 721 번 문서 종료 / 총 길이는 :  2041
# 722 번 문서 종료 / 총 길이는 :  1828
# 723 번 문서 종료 / 총 길이는 :  1867
# 724 번 문서 종료 / 총 길이는 :  1947
# 725 번 문서 종료 / 총 길이는 :  1938
# 726 번 문서 종료 / 총 길이는 :  1154
# 727 번 문서 종료 / 총 길이는 :  5192
# 728 번 문서 종료 / 총 길이는 :  1164
# 729 번 문서 종료 / 총 길이는 :  19582
# 730 번 문서 종료 / 총 길이는 :  1980
# 731 번 문서 종료 / 총 길이는 :  1844
# 732 번 문서 종료 / 총 길이는 :  1307
# 733 번 문서 종료 / 총 길이는 :  1479
# 734 번 문서 종료 / 총 길이는 :  4900
# 735 번 문서 종료 / 총 길이는 :  1505
# 736 번 문서 종료 / 총 길이는 :  3634
# 737 번 문서 종료 / 총 길이는 :  1246
# 738 번 문서 종료 / 총 길이는 :  3646
# 739 번 문서 종료 / 총 길이는 :  1579
# 740 번 문서 종료 / 총 길이는 :  1951
# 741 번 문서 종료 / 총 길이는 :  1782
# 742 번 문서 종료 / 총 길이는 :  5593
# 743 번 문서 종료 / 총 길이는 :  130937
# 744 번 문서 종료 / 총 길이는 :  1259
# 745 번 문서 종료 / 총 길이는 :  4
# 746 번 문서 종료 / 총 길이는 :  1248
# 747 번 문서 종료 / 총 길이는 :  2513
# 748 번 문서 종료 / 총 길이는 :  2978
# 749 번 문서 종료 / 총 길이는 :  1261
# 750 번 문서 종료 / 총 길이는 :  1151
# 751 번 문서 종료 / 총 길이는 :  1722
# 752 번 문서 종료 / 총 길이는 :  319738
# 753 번 문서 종료 / 총 길이는 :  5057
# 754 번 문서 종료 / 총 길이는 :  1259
# 755 번 문서 종료 / 총 길이는 :  1541
# 756 번 문서 종료 / 총 길이는 :  2382
# 757 번 문서 종료 / 총 길이는 :  19631
# 758 번 문서 종료 / 총 길이는 :  1661
# 759 번 문서 종료 / 총 길이는 :  2090
# 760 번 문서 종료 / 총 길이는 :  2145
# 761 번 문서 종료 / 총 길이는 :  1233
# 762 번 문서 종료 / 총 길이는 :  417867
# 763 번 문서 종료 / 총 길이는 :  2628
# 764 번 문서 종료 / 총 길이는 :  13752
# 765 번 문서 종료 / 총 길이는 :  2914
# 766 번 문서 종료 / 총 길이는 :  1703
# 767 번 문서 종료 / 총 길이는 :  4195
# 768 번 문서 종료 / 총 길이는 :  1335
# 769 번 문서 종료 / 총 길이는 :  1813
# 770 번 문서 종료 / 총 길이는 :  436928
# 771 번 문서 종료 / 총 길이는 :  3837
# 772 번 문서 종료 / 총 길이는 :  1350
# 773 번 문서 종료 / 총 길이는 :  1268
# 774 번 문서 종료 / 총 길이는 :  855963
# 775 번 문서 종료 / 총 길이는 :  1761
# 776 번 문서 종료 / 총 길이는 :  1999
# 777 번 문서 종료 / 총 길이는 :  4708
# 778 번 문서 종료 / 총 길이는 :  389095
# 779 번 문서 종료 / 총 길이는 :  1323
# 780 번 문서 종료 / 총 길이는 :  1158
# 781 번 문서 종료 / 총 길이는 :  3805
# 782 번 문서 종료 / 총 길이는 :  2467
# 783 번 문서 종료 / 총 길이는 :  1714
# 784 번 문서 종료 / 총 길이는 :  1340
# 785 번 문서 종료 / 총 길이는 :  1471
# 786 번 문서 종료 / 총 길이는 :  2366
# 787 번 문서 종료 / 총 길이는 :  18063
# 788 번 문서 종료 / 총 길이는 :  1356
# 789 번 문서 종료 / 총 길이는 :  3511
# 790 번 문서 종료 / 총 길이는 :  1203
# 791 번 문서 종료 / 총 길이는 :  2318
# 792 번 문서 종료 / 총 길이는 :  1221
# 793 번 문서 종료 / 총 길이는 :  28688
# 794 번 문서 종료 / 총 길이는 :  2348
# 795 번 문서 종료 / 총 길이는 :  345291
# 796 번 문서 종료 / 총 길이는 :  1213
# 797 번 문서 종료 / 총 길이는 :  1841
# 798 번 문서 종료 / 총 길이는 :  1844
# 799 번 문서 종료 / 총 길이는 :  9104
# 800 번 문서 종료 / 총 길이는 :  2288
# 801 번 문서 종료 / 총 길이는 :  1562
# 802 번 문서 종료 / 총 길이는 :  1926
# 803 번 문서 종료 / 총 길이는 :  874
# 804 번 문서 종료 / 총 길이는 :  423348
# 805 번 문서 종료 / 총 길이는 :  1316
# 806 번 문서 종료 / 총 길이는 :  1591
# 807 번 문서 종료 / 총 길이는 :  1370
# 808 번 문서 종료 / 총 길이는 :  10041
# 809 번 문서 종료 / 총 길이는 :  419711
# 810 번 문서 종료 / 총 길이는 :  1340
# 811 번 문서 종료 / 총 길이는 :  1757
# 812 번 문서 종료 / 총 길이는 :  1551
# 813 번 문서 종료 / 총 길이는 :  4144
# 814 번 문서 종료 / 총 길이는 :  5211
# 815 번 문서 종료 / 총 길이는 :  8871
# 816 번 문서 종료 / 총 길이는 :  24050
# 817 번 문서 종료 / 총 길이는 :  1347
# 818 번 문서 종료 / 총 길이는 :  18411
# 819 번 문서 종료 / 총 길이는 :  393969
# 820 번 문서 종료 / 총 길이는 :  1166
# 821 번 문서 종료 / 총 길이는 :  2508
# 822 번 문서 종료 / 총 길이는 :  4076
# 823 번 문서 종료 / 총 길이는 :  3859
# 824 번 문서 종료 / 총 길이는 :  18446
# 825 번 문서 종료 / 총 길이는 :  3041
# 826 번 문서 종료 / 총 길이는 :  2491
# 827 번 문서 종료 / 총 길이는 :  1995
# 828 번 문서 종료 / 총 길이는 :  2380
# 829 번 문서 종료 / 총 길이는 :  340473
# 830 번 문서 종료 / 총 길이는 :  759
# 831 번 문서 종료 / 총 길이는 :  2177
# 832 번 문서 종료 / 총 길이는 :  2576
# 833 번 문서 종료 / 총 길이는 :  2324
# 834 번 문서 종료 / 총 길이는 :  1651
# 835 번 문서 종료 / 총 길이는 :  1121
# 836 번 문서 종료 / 총 길이는 :  2351
# 837 번 문서 종료 / 총 길이는 :  1821
# 838 번 문서 종료 / 총 길이는 :  3518
# 839 번 문서 종료 / 총 길이는 :  2281
# 840 번 문서 종료 / 총 길이는 :  672
# 841 번 문서 종료 / 총 길이는 :  418432
# 842 번 문서 종료 / 총 길이는 :  1984
# 843 번 문서 종료 / 총 길이는 :  2325
# 844 번 문서 종료 / 총 길이는 :  355940
# 845 번 문서 종료 / 총 길이는 :  5966
# 846 번 문서 종료 / 총 길이는 :  3972
# 847 번 문서 종료 / 총 길이는 :  957
# 848 번 문서 종료 / 총 길이는 :  1775
# 849 번 문서 종료 / 총 길이는 :  1729
# 850 번 문서 종료 / 총 길이는 :  940
# 851 번 문서 종료 / 총 길이는 :  11630
# 852 번 문서 종료 / 총 길이는 :  772
# 853 번 문서 종료 / 총 길이는 :  1293
# 854 번 문서 종료 / 총 길이는 :  1393
# 855 번 문서 종료 / 총 길이는 :  1207
# 856 번 문서 종료 / 총 길이는 :  4240
# 857 번 문서 종료 / 총 길이는 :  5597
# 858 번 문서 종료 / 총 길이는 :  1181
# 859 번 문서 종료 / 총 길이는 :  4955
# 860 번 문서 종료 / 총 길이는 :  2049
# 861 번 문서 종료 / 총 길이는 :  936
# 862 번 문서 종료 / 총 길이는 :  2261
# 863 번 문서 종료 / 총 길이는 :  1856
# 864 번 문서 종료 / 총 길이는 :  5563
# 865 번 문서 종료 / 총 길이는 :  329142
# 866 번 문서 종료 / 총 길이는 :  1008
# 867 번 문서 종료 / 총 길이는 :  3108
# 868 번 문서 종료 / 총 길이는 :  2455
# 869 번 문서 종료 / 총 길이는 :  2661
# 870 번 문서 종료 / 총 길이는 :  2761
# 871 번 문서 종료 / 총 길이는 :  1148
# 872 번 문서 종료 / 총 길이는 :  18448
# 873 번 문서 종료 / 총 길이는 :  1084
# 874 번 문서 종료 / 총 길이는 :  18127
# 875 번 문서 종료 / 총 길이는 :  912
# 876 번 문서 종료 / 총 길이는 :  1647
# 877 번 문서 종료 / 총 길이는 :  5869
# 878 번 문서 종료 / 총 길이는 :  861
# 879 번 문서 종료 / 총 길이는 :  5090
# 880 번 문서 종료 / 총 길이는 :  1948
# 881 번 문서 종료 / 총 길이는 :  13246
# 882 번 문서 종료 / 총 길이는 :  321745
# 883 번 문서 종료 / 총 길이는 :  2614
# 884 번 문서 종료 / 총 길이는 :  749
# 885 번 문서 종료 / 총 길이는 :  18268
# 886 번 문서 종료 / 총 길이는 :  770
# 887 번 문서 종료 / 총 길이는 :  1010
# 888 번 문서 종료 / 총 길이는 :  4691
# 889 번 문서 종료 / 총 길이는 :  1771
# 890 번 문서 종료 / 총 길이는 :  829
# 891 번 문서 종료 / 총 길이는 :  1709
# 892 번 문서 종료 / 총 길이는 :  1895
# 893 번 문서 종료 / 총 길이는 :  1818
# 894 번 문서 종료 / 총 길이는 :  750
# 895 번 문서 종료 / 총 길이는 :  617773
# 896 번 문서 종료 / 총 길이는 :  8989
# 897 번 문서 종료 / 총 길이는 :  2534
# 898 번 문서 종료 / 총 길이는 :  1531
# 899 번 문서 종료 / 총 길이는 :  1080
# 900 번 문서 종료 / 총 길이는 :  1741
# 901 번 문서 종료 / 총 길이는 :  1354
# 902 번 문서 종료 / 총 길이는 :  2649
# 903 번 문서 종료 / 총 길이는 :  1298
# 904 번 문서 종료 / 총 길이는 :  1522
# 905 번 문서 종료 / 총 길이는 :  2234
# 906 번 문서 종료 / 총 길이는 :  1150
# 907 번 문서 종료 / 총 길이는 :  3870
# 908 번 문서 종료 / 총 길이는 :  986
# 909 번 문서 종료 / 총 길이는 :  2451
# 910 번 문서 종료 / 총 길이는 :  3892
# 911 번 문서 종료 / 총 길이는 :  1969
# 912 번 문서 종료 / 총 길이는 :  4073
# 913 번 문서 종료 / 총 길이는 :  424756
# 914 번 문서 종료 / 총 길이는 :  4053
# 915 번 문서 종료 / 총 길이는 :  1176
# 916 번 문서 종료 / 총 길이는 :  2285
# 917 번 문서 종료 / 총 길이는 :  898
# 918 번 문서 종료 / 총 길이는 :  1462
# 919 번 문서 종료 / 총 길이는 :  5186
# 920 번 문서 종료 / 총 길이는 :  551876
# 921 번 문서 종료 / 총 길이는 :  9036
# 922 번 문서 종료 / 총 길이는 :  2700
# 923 번 문서 종료 / 총 길이는 :  18302
# 924 번 문서 종료 / 총 길이는 :  5702
# 925 번 문서 종료 / 총 길이는 :  2699
# 926 번 문서 종료 / 총 길이는 :  3279
# 927 번 문서 종료 / 총 길이는 :  444417
# 928 번 문서 종료 / 총 길이는 :  1249
# 929 번 문서 종료 / 총 길이는 :  2409
# 930 번 문서 종료 / 총 길이는 :  3626
# 931 번 문서 종료 / 총 길이는 :  1632
# 932 번 문서 종료 / 총 길이는 :  13308
# 933 번 문서 종료 / 총 길이는 :  961
# 934 번 문서 종료 / 총 길이는 :  2081
# 935 번 문서 종료 / 총 길이는 :  716
# 936 번 문서 종료 / 총 길이는 :  3119
# 937 번 문서 종료 / 총 길이는 :  15690
# 938 번 문서 종료 / 총 길이는 :  1054
# 939 번 문서 종료 / 총 길이는 :  2619
# 940 번 문서 종료 / 총 길이는 :  5212
# 941 번 문서 종료 / 총 길이는 :  1529
# 942 번 문서 종료 / 총 길이는 :  2399
# 943 번 문서 종료 / 총 길이는 :  238832
# 944 번 문서 종료 / 총 길이는 :  1145
# 945 번 문서 종료 / 총 길이는 :  10307
# 946 번 문서 종료 / 총 길이는 :  740
# 947 번 문서 종료 / 총 길이는 :  1411
# 948 번 문서 종료 / 총 길이는 :  2944
# 949 번 문서 종료 / 총 길이는 :  213247
# 950 번 문서 종료 / 총 길이는 :  2506
# 951 번 문서 종료 / 총 길이는 :  1933
# 952 번 문서 종료 / 총 길이는 :  776
# 953 번 문서 종료 / 총 길이는 :  205985
# 954 번 문서 종료 / 총 길이는 :  18348
# 955 번 문서 종료 / 총 길이는 :  2219
# 956 번 문서 종료 / 총 길이는 :  5905
# 957 번 문서 종료 / 총 길이는 :  1150
# 958 번 문서 종료 / 총 길이는 :  7399
# 959 번 문서 종료 / 총 길이는 :  5380
# 960 번 문서 종료 / 총 길이는 :  4025
# 961 번 문서 종료 / 총 길이는 :  732
# 962 번 문서 종료 / 총 길이는 :  1034
# 963 번 문서 종료 / 총 길이는 :  1756
# 964 번 문서 종료 / 총 길이는 :  866
# 965 번 문서 종료 / 총 길이는 :  3635
# 966 번 문서 종료 / 총 길이는 :  1292
# 967 번 문서 종료 / 총 길이는 :  11946
# 968 번 문서 종료 / 총 길이는 :  5627
# 969 번 문서 종료 / 총 길이는 :  1042
# 970 번 문서 종료 / 총 길이는 :  727
# 971 번 문서 종료 / 총 길이는 :  3266
# 972 번 문서 종료 / 총 길이는 :  3755
# 973 번 문서 종료 / 총 길이는 :  24251
# 974 번 문서 종료 / 총 길이는 :  906
# 975 번 문서 종료 / 총 길이는 :  2895
# 976 번 문서 종료 / 총 길이는 :  909
# 977 번 문서 종료 / 총 길이는 :  16785
# 978 번 문서 종료 / 총 길이는 :  1969
# 979 번 문서 종료 / 총 길이는 :  2076
# 980 번 문서 종료 / 총 길이는 :  998
# 981 번 문서 종료 / 총 길이는 :  6180
# 982 번 문서 종료 / 총 길이는 :  12486
# 983 번 문서 종료 / 총 길이는 :  11313
# 984 번 문서 종료 / 총 길이는 :  1918
# 985 번 문서 종료 / 총 길이는 :  1367
# 986 번 문서 종료 / 총 길이는 :  1598
# 987 번 문서 종료 / 총 길이는 :  1683
# 988 번 문서 종료 / 총 길이는 :  1321
# 989 번 문서 종료 / 총 길이는 :  1827
# 990 번 문서 종료 / 총 길이는 :  5297
# 991 번 문서 종료 / 총 길이는 :  4332
# 992 번 문서 종료 / 총 길이는 :  1641
# 993 번 문서 종료 / 총 길이는 :  1493
# 994 번 문서 종료 / 총 길이는 :  2380
# 995 번 문서 종료 / 총 길이는 :  764
# 996 번 문서 종료 / 총 길이는 :  1823
# 997 번 문서 종료 / 총 길이는 :  12710
# 998 번 문서 종료 / 총 길이는 :  398707
# 999 번 문서 종료 / 총 길이는 :  964
# 1000 번 문서 종료 / 총 길이는 :  1362
# 1001 번 문서 종료 / 총 길이는 :  981
# 1002 번 문서 종료 / 총 길이는 :  1697
# 1003 번 문서 종료 / 총 길이는 :  882
# 1004 번 문서 종료 / 총 길이는 :  1772
# 1005 번 문서 종료 / 총 길이는 :  10931
# 1006 번 문서 종료 / 총 길이는 :  763
# 1007 번 문서 종료 / 총 길이는 :  4155
# 1008 번 문서 종료 / 총 길이는 :  5807
# 1009 번 문서 종료 / 총 길이는 :  7183
# 1010 번 문서 종료 / 총 길이는 :  8011
# 1011 번 문서 종료 / 총 길이는 :  628589
# 1012 번 문서 종료 / 총 길이는 :  1354
# 1013 번 문서 종료 / 총 길이는 :  727
# 1014 번 문서 종료 / 총 길이는 :  2316
# 1015 번 문서 종료 / 총 길이는 :  1831
# 1016 번 문서 종료 / 총 길이는 :  1081
# 1017 번 문서 종료 / 총 길이는 :  2030
# 1018 번 문서 종료 / 총 길이는 :  1037
# 1019 번 문서 종료 / 총 길이는 :  6450
# 1020 번 문서 종료 / 총 길이는 :  3413
# 1021 번 문서 종료 / 총 길이는 :  1413
# 1022 번 문서 종료 / 총 길이는 :  4545
# 1023 번 문서 종료 / 총 길이는 :  7838
# 1024 번 문서 종료 / 총 길이는 :  79870
# 1025 번 문서 종료 / 총 길이는 :  2837
# 1026 번 문서 종료 / 총 길이는 :  942
# 1027 번 문서 종료 / 총 길이는 :  90679
# 1028 번 문서 종료 / 총 길이는 :  5791
# 1029 번 문서 종료 / 총 길이는 :  6722
# 1030 번 문서 종료 / 총 길이는 :  549
# 1031 번 문서 종료 / 총 길이는 :  10913
# 1032 번 문서 종료 / 총 길이는 :  527
# 1033 번 문서 종료 / 총 길이는 :  3268
# 1034 번 문서 종료 / 총 길이는 :  1114
# 1035 번 문서 종료 / 총 길이는 :  1513
# 1036 번 문서 종료 / 총 길이는 :  1833
# 1037 번 문서 종료 / 총 길이는 :  2633
# 1038 번 문서 종료 / 총 길이는 :  2919
# 1039 번 문서 종료 / 총 길이는 :  16263
# 1040 번 문서 종료 / 총 길이는 :  7630
# 1041 번 문서 종료 / 총 길이는 :  1555
# 1042 번 문서 종료 / 총 길이는 :  1929
# 1043 번 문서 종료 / 총 길이는 :  1955
# 1044 번 문서 종료 / 총 길이는 :  898
# 1045 번 문서 종료 / 총 길이는 :  2121
# 1046 번 문서 종료 / 총 길이는 :  154354
# 1047 번 문서 종료 / 총 길이는 :  939
# 1048 번 문서 종료 / 총 길이는 :  6701
# 1049 번 문서 종료 / 총 길이는 :  1611
# 1050 번 문서 종료 / 총 길이는 :  2098
# 1051 번 문서 종료 / 총 길이는 :  2763
# 1052 번 문서 종료 / 총 길이는 :  971
# 1053 번 문서 종료 / 총 길이는 :  1849
# 1054 번 문서 종료 / 총 길이는 :  2074
# 1055 번 문서 종료 / 총 길이는 :  10908
# 1056 번 문서 종료 / 총 길이는 :  134562
# 1057 번 문서 종료 / 총 길이는 :  1666
# 1058 번 문서 종료 / 총 길이는 :  1519
# 1059 번 문서 종료 / 총 길이는 :  2089
# 1060 번 문서 종료 / 총 길이는 :  4086
# 1061 번 문서 종료 / 총 길이는 :  5255
# 1062 번 문서 종료 / 총 길이는 :  1488
# 1063 번 문서 종료 / 총 길이는 :  1104
# 1064 번 문서 종료 / 총 길이는 :  2588
# 1065 번 문서 종료 / 총 길이는 :  985
# 1066 번 문서 종료 / 총 길이는 :  1006
# 1067 번 문서 종료 / 총 길이는 :  582
# 1068 번 문서 종료 / 총 길이는 :  821
# 1069 번 문서 종료 / 총 길이는 :  4476
# 1070 번 문서 종료 / 총 길이는 :  5702
# 1071 번 문서 종료 / 총 길이는 :  2796
# 1072 번 문서 종료 / 총 길이는 :  150327
# 1073 번 문서 종료 / 총 길이는 :  539
# 1074 번 문서 종료 / 총 길이는 :  1936
# 1075 번 문서 종료 / 총 길이는 :  1966
# 1076 번 문서 종료 / 총 길이는 :  738
# 1077 번 문서 종료 / 총 길이는 :  2437
# 1078 번 문서 종료 / 총 길이는 :  835
# 1079 번 문서 종료 / 총 길이는 :  4002
# 1080 번 문서 종료 / 총 길이는 :  545
# 1081 번 문서 종료 / 총 길이는 :  727
# 1082 번 문서 종료 / 총 길이는 :  54575
# 1083 번 문서 종료 / 총 길이는 :  10779
# 1084 번 문서 종료 / 총 길이는 :  1160
# 1085 번 문서 종료 / 총 길이는 :  595
# 1086 번 문서 종료 / 총 길이는 :  1198
# 1087 번 문서 종료 / 총 길이는 :  6777
# 1088 번 문서 종료 / 총 길이는 :  712
# 1089 번 문서 종료 / 총 길이는 :  3243
# 1090 번 문서 종료 / 총 길이는 :  11835
# 1091 번 문서 종료 / 총 길이는 :  578
# 1092 번 문서 종료 / 총 길이는 :  1468
# 1093 번 문서 종료 / 총 길이는 :  4154
# 1094 번 문서 종료 / 총 길이는 :  2081
# 1095 번 문서 종료 / 총 길이는 :  3829
# 1096 번 문서 종료 / 총 길이는 :  939
# 1097 번 문서 종료 / 총 길이는 :  169963
# 1098 번 문서 종료 / 총 길이는 :  1685
# 1099 번 문서 종료 / 총 길이는 :  1602
# 1100 번 문서 종료 / 총 길이는 :  2089
# 1101 번 문서 종료 / 총 길이는 :  549
# 1102 번 문서 종료 / 총 길이는 :  23626
# 1103 번 문서 종료 / 총 길이는 :  749
# 1104 번 문서 종료 / 총 길이는 :  1545
# 1105 번 문서 종료 / 총 길이는 :  862
# 1106 번 문서 종료 / 총 길이는 :  2750
# 1107 번 문서 종료 / 총 길이는 :  934
# 1108 번 문서 종료 / 총 길이는 :  1059
# 1109 번 문서 종료 / 총 길이는 :  4850
# 1110 번 문서 종료 / 총 길이는 :  11918
# 1111 번 문서 종료 / 총 길이는 :  858
# 1112 번 문서 종료 / 총 길이는 :  84874
# 1113 번 문서 종료 / 총 길이는 :  9959
# 1114 번 문서 종료 / 총 길이는 :  2728
# 1115 번 문서 종료 / 총 길이는 :  551
# 1116 번 문서 종료 / 총 길이는 :  3006
# 1117 번 문서 종료 / 총 길이는 :  682
# 1118 번 문서 종료 / 총 길이는 :  1740
# 1119 번 문서 종료 / 총 길이는 :  953
# 1120 번 문서 종료 / 총 길이는 :  1155
# 1121 번 문서 종료 / 총 길이는 :  662
# 1122 번 문서 종료 / 총 길이는 :  895
# 1123 번 문서 종료 / 총 길이는 :  2142
# 1124 번 문서 종료 / 총 길이는 :  2977
# 1125 번 문서 종료 / 총 길이는 :  723
# 1126 번 문서 종료 / 총 길이는 :  2667
# 1127 번 문서 종료 / 총 길이는 :  2540
# 1128 번 문서 종료 / 총 길이는 :  4232
# 1129 번 문서 종료 / 총 길이는 :  720
# 1130 번 문서 종료 / 총 길이는 :  2680
# 1131 번 문서 종료 / 총 길이는 :  3085
# 1132 번 문서 종료 / 총 길이는 :  3422
# 1133 번 문서 종료 / 총 길이는 :  127653
# 1134 번 문서 종료 / 총 길이는 :  984
# 1135 번 문서 종료 / 총 길이는 :  1819
# 1136 번 문서 종료 / 총 길이는 :  2069
# 1137 번 문서 종료 / 총 길이는 :  1681
# 1138 번 문서 종료 / 총 길이는 :  1463
# 1139 번 문서 종료 / 총 길이는 :  4256
# 1140 번 문서 종료 / 총 길이는 :  863
# 1141 번 문서 종료 / 총 길이는 :  5881
# 1142 번 문서 종료 / 총 길이는 :  869
# 1143 번 문서 종료 / 총 길이는 :  7054
# 1144 번 문서 종료 / 총 길이는 :  3998
# 1145 번 문서 종료 / 총 길이는 :  526
# 1146 번 문서 종료 / 총 길이는 :  646
# 1147 번 문서 종료 / 총 길이는 :  523
# 1148 번 문서 종료 / 총 길이는 :  2612
# 1149 번 문서 종료 / 총 길이는 :  9043
# 1150 번 문서 종료 / 총 길이는 :  10468
# 1151 번 문서 종료 / 총 길이는 :  3528
# 1152 번 문서 종료 / 총 길이는 :  31487
# 1153 번 문서 종료 / 총 길이는 :  10871
# 1154 번 문서 종료 / 총 길이는 :  1904
# 1155 번 문서 종료 / 총 길이는 :  555
# 1156 번 문서 종료 / 총 길이는 :  8853
# 1157 번 문서 종료 / 총 길이는 :  3075
# 1158 번 문서 종료 / 총 길이는 :  8795
# 1159 번 문서 종료 / 총 길이는 :  4626
# 1160 번 문서 종료 / 총 길이는 :  9719
# 1161 번 문서 종료 / 총 길이는 :  674
# 1162 번 문서 종료 / 총 길이는 :  543
# 1163 번 문서 종료 / 총 길이는 :  587
# 1164 번 문서 종료 / 총 길이는 :  852
# 1165 번 문서 종료 / 총 길이는 :  1806
# 1166 번 문서 종료 / 총 길이는 :  686
# 1167 번 문서 종료 / 총 길이는 :  557
# 1168 번 문서 종료 / 총 길이는 :  1568
# 1169 번 문서 종료 / 총 길이는 :  1555
# 1170 번 문서 종료 / 총 길이는 :  2299
# 1171 번 문서 종료 / 총 길이는 :  79789
# 1172 번 문서 종료 / 총 길이는 :  618
# 1173 번 문서 종료 / 총 길이는 :  1549
# 1174 번 문서 종료 / 총 길이는 :  591
# 1175 번 문서 종료 / 총 길이는 :  11657
# 1176 번 문서 종료 / 총 길이는 :  939
# 1177 번 문서 종료 / 총 길이는 :  917
# 1178 번 문서 종료 / 총 길이는 :  651
# 1179 번 문서 종료 / 총 길이는 :  1086
# 1180 번 문서 종료 / 총 길이는 :  3679
# 1181 번 문서 종료 / 총 길이는 :  762
# 1182 번 문서 종료 / 총 길이는 :  4813
# 1183 번 문서 종료 / 총 길이는 :  738
# 1184 번 문서 종료 / 총 길이는 :  3476
# 1185 번 문서 종료 / 총 길이는 :  35538
# 1186 번 문서 종료 / 총 길이는 :  4416
# 1187 번 문서 종료 / 총 길이는 :  2430
# 1188 번 문서 종료 / 총 길이는 :  840
# 1189 번 문서 종료 / 총 길이는 :  817
# 1190 번 문서 종료 / 총 길이는 :  4103
# 1191 번 문서 종료 / 총 길이는 :  14304
# 1192 번 문서 종료 / 총 길이는 :  729
# 1193 번 문서 종료 / 총 길이는 :  2397
# 1194 번 문서 종료 / 총 길이는 :  1344
# 1195 번 문서 종료 / 총 길이는 :  724
# 1196 번 문서 종료 / 총 길이는 :  3530
# 1197 번 문서 종료 / 총 길이는 :  2205
# 1198 번 문서 종료 / 총 길이는 :  2087
# 1199 번 문서 종료 / 총 길이는 :  850
# 1200 번 문서 종료 / 총 길이는 :  883
# 1201 번 문서 종료 / 총 길이는 :  3691
# 1202 번 문서 종료 / 총 길이는 :  2582
# 1203 번 문서 종료 / 총 길이는 :  1664
# 1204 번 문서 종료 / 총 길이는 :  726
# 1205 번 문서 종료 / 총 길이는 :  2773
# 1206 번 문서 종료 / 총 길이는 :  1168
# 1207 번 문서 종료 / 총 길이는 :  1567
# 1208 번 문서 종료 / 총 길이는 :  20522
# 1209 번 문서 종료 / 총 길이는 :  674
# 1210 번 문서 종료 / 총 길이는 :  5859
# 1211 번 문서 종료 / 총 길이는 :  1385
# 1212 번 문서 종료 / 총 길이는 :  97519
# 1213 번 문서 종료 / 총 길이는 :  1069
# 1214 번 문서 종료 / 총 길이는 :  1928
# 1215 번 문서 종료 / 총 길이는 :  5755
# 1216 번 문서 종료 / 총 길이는 :  1725
# 1217 번 문서 종료 / 총 길이는 :  2433
# 1218 번 문서 종료 / 총 길이는 :  2512
# 1219 번 문서 종료 / 총 길이는 :  551
# 1220 번 문서 종료 / 총 길이는 :  5105
# 1221 번 문서 종료 / 총 길이는 :  3420
# 1222 번 문서 종료 / 총 길이는 :  1189
# 1223 번 문서 종료 / 총 길이는 :  2030
# 1224 번 문서 종료 / 총 길이는 :  1950
# 1225 번 문서 종료 / 총 길이는 :  549
# 1226 번 문서 종료 / 총 길이는 :  19560
# 1227 번 문서 종료 / 총 길이는 :  2175
# 1228 번 문서 종료 / 총 길이는 :  2617
# 1229 번 문서 종료 / 총 길이는 :  863
# 1230 번 문서 종료 / 총 길이는 :  2995
# 1231 번 문서 종료 / 총 길이는 :  1170
# 1232 번 문서 종료 / 총 길이는 :  1581
# 1233 번 문서 종료 / 총 길이는 :  744
# 1234 번 문서 종료 / 총 길이는 :  4395
# 1235 번 문서 종료 / 총 길이는 :  1208
# 1236 번 문서 종료 / 총 길이는 :  15973
# 1237 번 문서 종료 / 총 길이는 :  3148
# 1238 번 문서 종료 / 총 길이는 :  627
# 1239 번 문서 종료 / 총 길이는 :  798
# 1240 번 문서 종료 / 총 길이는 :  3628
# 1241 번 문서 종료 / 총 길이는 :  3499
# 1242 번 문서 종료 / 총 길이는 :  2696
# 1243 번 문서 종료 / 총 길이는 :  544
# 1244 번 문서 종료 / 총 길이는 :  770
# 1245 번 문서 종료 / 총 길이는 :  625
# 1246 번 문서 종료 / 총 길이는 :  4956
# 1247 번 문서 종료 / 총 길이는 :  659
# 1248 번 문서 종료 / 총 길이는 :  3156
# 1249 번 문서 종료 / 총 길이는 :  2399
# 1250 번 문서 종료 / 총 길이는 :  1452
# 1251 번 문서 종료 / 총 길이는 :  551
# 1252 번 문서 종료 / 총 길이는 :  615
# 1253 번 문서 종료 / 총 길이는 :  720
# 1254 번 문서 종료 / 총 길이는 :  3349
# 1255 번 문서 종료 / 총 길이는 :  2380
# 1256 번 문서 종료 / 총 길이는 :  1600
# 1257 번 문서 종료 / 총 길이는 :  68417
# 1258 번 문서 종료 / 총 길이는 :  7134
# 1259 번 문서 종료 / 총 길이는 :  2129
# 1260 번 문서 종료 / 총 길이는 :  2398
# 1261 번 문서 종료 / 총 길이는 :  3117
# 1262 번 문서 종료 / 총 길이는 :  1061
# 1263 번 문서 종료 / 총 길이는 :  2840
# 1264 번 문서 종료 / 총 길이는 :  2839
# 1265 번 문서 종료 / 총 길이는 :  1006
# 1266 번 문서 종료 / 총 길이는 :  4726
# 1267 번 문서 종료 / 총 길이는 :  894
# 1268 번 문서 종료 / 총 길이는 :  1172
# 1269 번 문서 종료 / 총 길이는 :  4335
# 1270 번 문서 종료 / 총 길이는 :  642
# 1271 번 문서 종료 / 총 길이는 :  581
# 1272 번 문서 종료 / 총 길이는 :  682
# 1273 번 문서 종료 / 총 길이는 :  1907
# 1274 번 문서 종료 / 총 길이는 :  4965
# 1275 번 문서 종료 / 총 길이는 :  1631
# 1276 번 문서 종료 / 총 길이는 :  1685
# 1277 번 문서 종료 / 총 길이는 :  163
# 1278 번 문서 종료 / 총 길이는 :  561
# 1279 번 문서 종료 / 총 길이는 :  592
# 1280 번 문서 종료 / 총 길이는 :  3080
# 1281 번 문서 종료 / 총 길이는 :  2692
# 1282 번 문서 종료 / 총 길이는 :  6846
# 1283 번 문서 종료 / 총 길이는 :  732
# 1284 번 문서 종료 / 총 길이는 :  2128
# 1285 번 문서 종료 / 총 길이는 :  1780
# 1286 번 문서 종료 / 총 길이는 :  720
# 1287 번 문서 종료 / 총 길이는 :  685
# 1288 번 문서 종료 / 총 길이는 :  716
# 1289 번 문서 종료 / 총 길이는 :  13996
# 1290 번 문서 종료 / 총 길이는 :  4069
# 1291 번 문서 종료 / 총 길이는 :  2070
# 1292 번 문서 종료 / 총 길이는 :  3323
# 1293 번 문서 종료 / 총 길이는 :  6646
# 1294 번 문서 종료 / 총 길이는 :  828
# 1295 번 문서 종료 / 총 길이는 :  1645
# 1296 번 문서 종료 / 총 길이는 :  1715
# 1297 번 문서 종료 / 총 길이는 :  394
# 1298 번 문서 종료 / 총 길이는 :  1385
# 1299 번 문서 종료 / 총 길이는 :  1378
# 1300 번 문서 종료 / 총 길이는 :  5091
# 1301 번 문서 종료 / 총 길이는 :  1288
# 1302 번 문서 종료 / 총 길이는 :  591
# 1303 번 문서 종료 / 총 길이는 :  2774
# 1304 번 문서 종료 / 총 길이는 :  4093
# 1305 번 문서 종료 / 총 길이는 :  544
# 1306 번 문서 종료 / 총 길이는 :  3337
# 1307 번 문서 종료 / 총 길이는 :  4667
# 1308 번 문서 종료 / 총 길이는 :  2118
# 1309 번 문서 종료 / 총 길이는 :  20218
# 1310 번 문서 종료 / 총 길이는 :  3174
# 1311 번 문서 종료 / 총 길이는 :  2107
# 1312 번 문서 종료 / 총 길이는 :  3096
# 1313 번 문서 종료 / 총 길이는 :  12061
# 1314 번 문서 종료 / 총 길이는 :  532
# 1315 번 문서 종료 / 총 길이는 :  540
# 1316 번 문서 종료 / 총 길이는 :  745
# 1317 번 문서 종료 / 총 길이는 :  699
# 1318 번 문서 종료 / 총 길이는 :  3824
# 1319 번 문서 종료 / 총 길이는 :  619
# 1320 번 문서 종료 / 총 길이는 :  3157
# 1321 번 문서 종료 / 총 길이는 :  602
# 1322 번 문서 종료 / 총 길이는 :  1249
# 1323 번 문서 종료 / 총 길이는 :  1782
# 1324 번 문서 종료 / 총 길이는 :  3425
# 1325 번 문서 종료 / 총 길이는 :  3505
# 1326 번 문서 종료 / 총 길이는 :  3071
# 1327 번 문서 종료 / 총 길이는 :  632
# 1328 번 문서 종료 / 총 길이는 :  30248
# 1329 번 문서 종료 / 총 길이는 :  703
# 1330 번 문서 종료 / 총 길이는 :  428
# 1331 번 문서 종료 / 총 길이는 :  2626
# 1332 번 문서 종료 / 총 길이는 :  620
# 1333 번 문서 종료 / 총 길이는 :  2172
# 1334 번 문서 종료 / 총 길이는 :  2017
# 1335 번 문서 종료 / 총 길이는 :  1532
# 1336 번 문서 종료 / 총 길이는 :  802
# 1337 번 문서 종료 / 총 길이는 :  1378
# 1338 번 문서 종료 / 총 길이는 :  3781
# 1339 번 문서 종료 / 총 길이는 :  12003
# 1340 번 문서 종료 / 총 길이는 :  11978
# 1341 번 문서 종료 / 총 길이는 :  3155
# 1342 번 문서 종료 / 총 길이는 :  30139
# 1343 번 문서 종료 / 총 길이는 :  679
# 1344 번 문서 종료 / 총 길이는 :  736
# 1345 번 문서 종료 / 총 길이는 :  3493
# 1346 번 문서 종료 / 총 길이는 :  7824
# 1347 번 문서 종료 / 총 길이는 :  13017
# 1348 번 문서 종료 / 총 길이는 :  778
# 1349 번 문서 종료 / 총 길이는 :  1987
# 1350 번 문서 종료 / 총 길이는 :  2519
# 1351 번 문서 종료 / 총 길이는 :  1411
# 1352 번 문서 종료 / 총 길이는 :  5103
# 1353 번 문서 종료 / 총 길이는 :  3154
# 1354 번 문서 종료 / 총 길이는 :  3086
# 1355 번 문서 종료 / 총 길이는 :  1405
# 1356 번 문서 종료 / 총 길이는 :  688
# 1357 번 문서 종료 / 총 길이는 :  1187
# 1358 번 문서 종료 / 총 길이는 :  2413
# 1359 번 문서 종료 / 총 길이는 :  1056
# 1360 번 문서 종료 / 총 길이는 :  1276
# 1361 번 문서 종료 / 총 길이는 :  646
# 1362 번 문서 종료 / 총 길이는 :  600
# 1363 번 문서 종료 / 총 길이는 :  706
# 1364 번 문서 종료 / 총 길이는 :  558
# 1365 번 문서 종료 / 총 길이는 :  713
# 1366 번 문서 종료 / 총 길이는 :  2646
# 1367 번 문서 종료 / 총 길이는 :  4843
# 1368 번 문서 종료 / 총 길이는 :  2504
# 1369 번 문서 종료 / 총 길이는 :  5889
# 1370 번 문서 종료 / 총 길이는 :  762
# 1371 번 문서 종료 / 총 길이는 :  2176
# 1372 번 문서 종료 / 총 길이는 :  3341
# 1373 번 문서 종료 / 총 길이는 :  689
# 1374 번 문서 종료 / 총 길이는 :  613
# 1375 번 문서 종료 / 총 길이는 :  724
# 1376 번 문서 종료 / 총 길이는 :  2339
# 1377 번 문서 종료 / 총 길이는 :  746
# 1378 번 문서 종료 / 총 길이는 :  11223
# 1379 번 문서 종료 / 총 길이는 :  1941
# 1380 번 문서 종료 / 총 길이는 :  1581
# 1381 번 문서 종료 / 총 길이는 :  1081
# 1382 번 문서 종료 / 총 길이는 :  670
# 1383 번 문서 종료 / 총 길이는 :  695
# 1384 번 문서 종료 / 총 길이는 :  1454
# 1385 번 문서 종료 / 총 길이는 :  3686
# 1386 번 문서 종료 / 총 길이는 :  559
# 1387 번 문서 종료 / 총 길이는 :  737
# 1388 번 문서 종료 / 총 길이는 :  1068
# 1389 번 문서 종료 / 총 길이는 :  3549
# 1390 번 문서 종료 / 총 길이는 :  1849
# 1391 번 문서 종료 / 총 길이는 :  4121
# 1392 번 문서 종료 / 총 길이는 :  1405
# 1393 번 문서 종료 / 총 길이는 :  1812
# 1394 번 문서 종료 / 총 길이는 :  863
# 1395 번 문서 종료 / 총 길이는 :  1269
# 1396 번 문서 종료 / 총 길이는 :  640
# 1397 번 문서 종료 / 총 길이는 :  1390
# 1398 번 문서 종료 / 총 길이는 :  1964
# 1399 번 문서 종료 / 총 길이는 :  854
# 1400 번 문서 종료 / 총 길이는 :  793
# 1401 번 문서 종료 / 총 길이는 :  477
# 1402 번 문서 종료 / 총 길이는 :  1544
# 1403 번 문서 종료 / 총 길이는 :  1029
# 1404 번 문서 종료 / 총 길이는 :  574
# 1405 번 문서 종료 / 총 길이는 :  3478
# 1406 번 문서 종료 / 총 길이는 :  2871
# 1407 번 문서 종료 / 총 길이는 :  1155
# 1408 번 문서 종료 / 총 길이는 :  560
# 1409 번 문서 종료 / 총 길이는 :  35461
# 1410 번 문서 종료 / 총 길이는 :  3238
# 1411 번 문서 종료 / 총 길이는 :  997
# 1412 번 문서 종료 / 총 길이는 :  2697
# 1413 번 문서 종료 / 총 길이는 :  4550
# 1414 번 문서 종료 / 총 길이는 :  1802
# 1415 번 문서 종료 / 총 길이는 :  1611
# 1416 번 문서 종료 / 총 길이는 :  1696
# 1417 번 문서 종료 / 총 길이는 :  753
# 1418 번 문서 종료 / 총 길이는 :  6338
# 1419 번 문서 종료 / 총 길이는 :  870
# 1420 번 문서 종료 / 총 길이는 :  688
# 1421 번 문서 종료 / 총 길이는 :  4610
# 1422 번 문서 종료 / 총 길이는 :  1393
# 1423 번 문서 종료 / 총 길이는 :  776
# 1424 번 문서 종료 / 총 길이는 :  5024
# 1425 번 문서 종료 / 총 길이는 :  2370
# 1426 번 문서 종료 / 총 길이는 :  5157
# 1427 번 문서 종료 / 총 길이는 :  6256
# 1428 번 문서 종료 / 총 길이는 :  1394
# 1429 번 문서 종료 / 총 길이는 :  3655
# 1430 번 문서 종료 / 총 길이는 :  1399
# 1431 번 문서 종료 / 총 길이는 :  578
# 1432 번 문서 종료 / 총 길이는 :  3070
# 1433 번 문서 종료 / 총 길이는 :  3521
# 1434 번 문서 종료 / 총 길이는 :  3334
# 1435 번 문서 종료 / 총 길이는 :  1949
# 1436 번 문서 종료 / 총 길이는 :  638
# 1437 번 문서 종료 / 총 길이는 :  755
# 1438 번 문서 종료 / 총 길이는 :  1563
# 1439 번 문서 종료 / 총 길이는 :  857
# 1440 번 문서 종료 / 총 길이는 :  727
# 1441 번 문서 종료 / 총 길이는 :  6572
# 1442 번 문서 종료 / 총 길이는 :  724
# 1443 번 문서 종료 / 총 길이는 :  930
# 1444 번 문서 종료 / 총 길이는 :  27420
# 1445 번 문서 종료 / 총 길이는 :  3282
# 1446 번 문서 종료 / 총 길이는 :  1435
# 1447 번 문서 종료 / 총 길이는 :  2186
# 1448 번 문서 종료 / 총 길이는 :  647
# 1449 번 문서 종료 / 총 길이는 :  588
# 1450 번 문서 종료 / 총 길이는 :  3130
# 1451 번 문서 종료 / 총 길이는 :  6368
# 1452 번 문서 종료 / 총 길이는 :  4888
# 1453 번 문서 종료 / 총 길이는 :  1813
# 1454 번 문서 종료 / 총 길이는 :  1421
# 1455 번 문서 종료 / 총 길이는 :  4971
# 1456 번 문서 종료 / 총 길이는 :  2084
# 1457 번 문서 종료 / 총 길이는 :  575
# 1458 번 문서 종료 / 총 길이는 :  2103
# 1459 번 문서 종료 / 총 길이는 :  1439
# 1460 번 문서 종료 / 총 길이는 :  11965
# 1461 번 문서 종료 / 총 길이는 :  3247
# 1462 번 문서 종료 / 총 길이는 :  3709
# 1463 번 문서 종료 / 총 길이는 :  1408
# 1464 번 문서 종료 / 총 길이는 :  164
# 1465 번 문서 종료 / 총 길이는 :  3315
# 1466 번 문서 종료 / 총 길이는 :  580
# 1467 번 문서 종료 / 총 길이는 :  1537
# 1468 번 문서 종료 / 총 길이는 :  768
# 1469 번 문서 종료 / 총 길이는 :  2981
# 1470 번 문서 종료 / 총 길이는 :  552
# 1471 번 문서 종료 / 총 길이는 :  5628
# 1472 번 문서 종료 / 총 길이는 :  557
# 1473 번 문서 종료 / 총 길이는 :  5939
# 1474 번 문서 종료 / 총 길이는 :  1311
# 1475 번 문서 종료 / 총 길이는 :  2050
# 1476 번 문서 종료 / 총 길이는 :  1442
# 1477 번 문서 종료 / 총 길이는 :  14010
# 1478 번 문서 종료 / 총 길이는 :  1408
# 1479 번 문서 종료 / 총 길이는 :  6921
# 1480 번 문서 종료 / 총 길이는 :  6038
# 1481 번 문서 종료 / 총 길이는 :  2768
# 1482 번 문서 종료 / 총 길이는 :  699
# 1483 번 문서 종료 / 총 길이는 :  1162
# 1484 번 문서 종료 / 총 길이는 :  3041
# 1485 번 문서 종료 / 총 길이는 :  1227
# 1486 번 문서 종료 / 총 길이는 :  7067
# 1487 번 문서 종료 / 총 길이는 :  1410
# 1488 번 문서 종료 / 총 길이는 :  2028
# 1489 번 문서 종료 / 총 길이는 :  249
# 1490 번 문서 종료 / 총 길이는 :  3889
# 1491 번 문서 종료 / 총 길이는 :  703
# 1492 번 문서 종료 / 총 길이는 :  967
# 1493 번 문서 종료 / 총 길이는 :  1286
# 1494 번 문서 종료 / 총 길이는 :  871
# 1495 번 문서 종료 / 총 길이는 :  1635
# 1496 번 문서 종료 / 총 길이는 :  462
# 1497 번 문서 종료 / 총 길이는 :  1608
# 1498 번 문서 종료 / 총 길이는 :  1585
# 1499 번 문서 종료 / 총 길이는 :  9813
# 1500 번 문서 종료 / 총 길이는 :  826
# 1501 번 문서 종료 / 총 길이는 :  6605
# 1502 번 문서 종료 / 총 길이는 :  1005
# 1503 번 문서 종료 / 총 길이는 :  2386
# 1504 번 문서 종료 / 총 길이는 :  2093
# 1505 번 문서 종료 / 총 길이는 :  1415
# 1506 번 문서 종료 / 총 길이는 :  7493
# 1507 번 문서 종료 / 총 길이는 :  2814
# 1508 번 문서 종료 / 총 길이는 :  5306
# 1509 번 문서 종료 / 총 길이는 :  9046
# 1510 번 문서 종료 / 총 길이는 :  1384
# 1511 번 문서 종료 / 총 길이는 :  6865
# 1512 번 문서 종료 / 총 길이는 :  3395
# 1513 번 문서 종료 / 총 길이는 :  1270
# 1514 번 문서 종료 / 총 길이는 :  2151
# 1515 번 문서 종료 / 총 길이는 :  1350
# 1516 번 문서 종료 / 총 길이는 :  4477
# 1517 번 문서 종료 / 총 길이는 :  2065
# 1518 번 문서 종료 / 총 길이는 :  5728
# 1519 번 문서 종료 / 총 길이는 :  2778
# 1520 번 문서 종료 / 총 길이는 :  1523
# 1521 번 문서 종료 / 총 길이는 :  1669
# 1522 번 문서 종료 / 총 길이는 :  6960
# 1523 번 문서 종료 / 총 길이는 :  782
# 1524 번 문서 종료 / 총 길이는 :  1510
# 1525 번 문서 종료 / 총 길이는 :  12078
# 1526 번 문서 종료 / 총 길이는 :  7883
# 1527 번 문서 종료 / 총 길이는 :  22668
# 1528 번 문서 종료 / 총 길이는 :  1917
# 1529 번 문서 종료 / 총 길이는 :  3699
# 1530 번 문서 종료 / 총 길이는 :  8835
# 1531 번 문서 종료 / 총 길이는 :  10540
# 1532 번 문서 종료 / 총 길이는 :  558
# 1533 번 문서 종료 / 총 길이는 :  693
# 1534 번 문서 종료 / 총 길이는 :  3220
# 1535 번 문서 종료 / 총 길이는 :  2342
# 1536 번 문서 종료 / 총 길이는 :  5008
# 1537 번 문서 종료 / 총 길이는 :  4758
# 1538 번 문서 종료 / 총 길이는 :  8184
# 1539 번 문서 종료 / 총 길이는 :  7066
# 1540 번 문서 종료 / 총 길이는 :  3691
# 1541 번 문서 종료 / 총 길이는 :  2562
# 1542 번 문서 종료 / 총 길이는 :  13707
# 1543 번 문서 종료 / 총 길이는 :  8919
# 1544 번 문서 종료 / 총 길이는 :  1461
# 1545 번 문서 종료 / 총 길이는 :  3622
# 1546 번 문서 종료 / 총 길이는 :  6406
# 1547 번 문서 종료 / 총 길이는 :  2043
# 1548 번 문서 종료 / 총 길이는 :  4471
# 1549 번 문서 종료 / 총 길이는 :  2211
# 1550 번 문서 종료 / 총 길이는 :  3564
# 1551 번 문서 종료 / 총 길이는 :  3789
# 1552 번 문서 종료 / 총 길이는 :  1454
# 1553 번 문서 종료 / 총 길이는 :  1647
# 1554 번 문서 종료 / 총 길이는 :  2299
# 1555 번 문서 종료 / 총 길이는 :  3116
# 1556 번 문서 종료 / 총 길이는 :  1746
# 1557 번 문서 종료 / 총 길이는 :  7489
# 1558 번 문서 종료 / 총 길이는 :  4245
# 1559 번 문서 종료 / 총 길이는 :  3939
# 1560 번 문서 종료 / 총 길이는 :  6234
# 1561 번 문서 종료 / 총 길이는 :  2708
# 1562 번 문서 종료 / 총 길이는 :  5109
# 1563 번 문서 종료 / 총 길이는 :  2186
# 1564 번 문서 종료 / 총 길이는 :  1359
# 1565 번 문서 종료 / 총 길이는 :  3256
# 1566 번 문서 종료 / 총 길이는 :  3416
# 1567 번 문서 종료 / 총 길이는 :  1355
# 1568 번 문서 종료 / 총 길이는 :  2467
# 1569 번 문서 종료 / 총 길이는 :  2147
# 1570 번 문서 종료 / 총 길이는 :  2968
# 1571 번 문서 종료 / 총 길이는 :  9648
# 1572 번 문서 종료 / 총 길이는 :  5422
# 1573 번 문서 종료 / 총 길이는 :  9882
# 1574 번 문서 종료 / 총 길이는 :  1210
# 1575 번 문서 종료 / 총 길이는 :  2107
# 1576 번 문서 종료 / 총 길이는 :  1419
# 1577 번 문서 종료 / 총 길이는 :  1023
# 1578 번 문서 종료 / 총 길이는 :  4264
# 1579 번 문서 종료 / 총 길이는 :  2600
# 1580 번 문서 종료 / 총 길이는 :  2624
# 1581 번 문서 종료 / 총 길이는 :  13917
# 1582 번 문서 종료 / 총 길이는 :  10575
# 1583 번 문서 종료 / 총 길이는 :  2938
# 1584 번 문서 종료 / 총 길이는 :  1152
# 1585 번 문서 종료 / 총 길이는 :  10004
# 1586 번 문서 종료 / 총 길이는 :  1743
# 1587 번 문서 종료 / 총 길이는 :  2854
# 1588 번 문서 종료 / 총 길이는 :  1243
# 1589 번 문서 종료 / 총 길이는 :  2175
# 1590 번 문서 종료 / 총 길이는 :  1073
# 1591 번 문서 종료 / 총 길이는 :  1000
# 1592 번 문서 종료 / 총 길이는 :  3098
# 1593 번 문서 종료 / 총 길이는 :  681
# 1594 번 문서 종료 / 총 길이는 :  1665
# 1595 번 문서 종료 / 총 길이는 :  1812
# 1596 번 문서 종료 / 총 길이는 :  4125
# 1597 번 문서 종료 / 총 길이는 :  8178
# 1598 번 문서 종료 / 총 길이는 :  2203
# 1599 번 문서 종료 / 총 길이는 :  3714
# 1600 번 문서 종료 / 총 길이는 :  1055
# 1601 번 문서 종료 / 총 길이는 :  1417
# 1602 번 문서 종료 / 총 길이는 :  1053
# 1603 번 문서 종료 / 총 길이는 :  3440
# 1604 번 문서 종료 / 총 길이는 :  7518
# 1605 번 문서 종료 / 총 길이는 :  1270
# 1606 번 문서 종료 / 총 길이는 :  1153
# 1607 번 문서 종료 / 총 길이는 :  1690
# 1608 번 문서 종료 / 총 길이는 :  1940
# 1609 번 문서 종료 / 총 길이는 :  751
# 1610 번 문서 종료 / 총 길이는 :  4866
# 1611 번 문서 종료 / 총 길이는 :  1298
# 1612 번 문서 종료 / 총 길이는 :  2904
# 1613 번 문서 종료 / 총 길이는 :  4988
# 1614 번 문서 종료 / 총 길이는 :  2507
# 1615 번 문서 종료 / 총 길이는 :  2964
# 1616 번 문서 종료 / 총 길이는 :  16737
# 1617 번 문서 종료 / 총 길이는 :  16736
# 1618 번 문서 종료 / 총 길이는 :  3948
# 1619 번 문서 종료 / 총 길이는 :  6585
# 1620 번 문서 종료 / 총 길이는 :  4987
# 1621 번 문서 종료 / 총 길이는 :  8992
# 1622 번 문서 종료 / 총 길이는 :  4231
# 1623 번 문서 종료 / 총 길이는 :  6536
# 1624 번 문서 종료 / 총 길이는 :  1234
# 1625 번 문서 종료 / 총 길이는 :  908
# 1626 번 문서 종료 / 총 길이는 :  5800
# 1627 번 문서 종료 / 총 길이는 :  1645
# 1628 번 문서 종료 / 총 길이는 :  767
# 1629 번 문서 종료 / 총 길이는 :  16811
# 1630 번 문서 종료 / 총 길이는 :  3264
# 1631 번 문서 종료 / 총 길이는 :  4151
# 1632 번 문서 종료 / 총 길이는 :  883
# 1633 번 문서 종료 / 총 길이는 :  567
# 1634 번 문서 종료 / 총 길이는 :  10218
# 1635 번 문서 종료 / 총 길이는 :  1136
# 1636 번 문서 종료 / 총 길이는 :  2345
# 1637 번 문서 종료 / 총 길이는 :  7385
# 1638 번 문서 종료 / 총 길이는 :  3452
# 1639 번 문서 종료 / 총 길이는 :  4931
# 1640 번 문서 종료 / 총 길이는 :  2182
# 1641 번 문서 종료 / 총 길이는 :  2077
# 1642 번 문서 종료 / 총 길이는 :  3525
# 1643 번 문서 종료 / 총 길이는 :  1838
# 1644 번 문서 종료 / 총 길이는 :  3580
# 1645 번 문서 종료 / 총 길이는 :  1463
# 1646 번 문서 종료 / 총 길이는 :  6046
# 1647 번 문서 종료 / 총 길이는 :  16016
# 1648 번 문서 종료 / 총 길이는 :  1082
# 1649 번 문서 종료 / 총 길이는 :  1997
# 1650 번 문서 종료 / 총 길이는 :  3215
# 1651 번 문서 종료 / 총 길이는 :  1487
# 1652 번 문서 종료 / 총 길이는 :  1166
# 1653 번 문서 종료 / 총 길이는 :  2463
# 1654 번 문서 종료 / 총 길이는 :  8885
# 1655 번 문서 종료 / 총 길이는 :  4305
# 1656 번 문서 종료 / 총 길이는 :  52440
# 1657 번 문서 종료 / 총 길이는 :  4361
# 1658 번 문서 종료 / 총 길이는 :  16509
# 1659 번 문서 종료 / 총 길이는 :  2548
# 1660 번 문서 종료 / 총 길이는 :  1737
# 1661 번 문서 종료 / 총 길이는 :  7485
# 1662 번 문서 종료 / 총 길이는 :  2868
# 1663 번 문서 종료 / 총 길이는 :  6691
# 1664 번 문서 종료 / 총 길이는 :  15888
# 1665 번 문서 종료 / 총 길이는 :  1680
# 1666 번 문서 종료 / 총 길이는 :  4114
# 1667 번 문서 종료 / 총 길이는 :  2151
# 1668 번 문서 종료 / 총 길이는 :  1496
# 1669 번 문서 종료 / 총 길이는 :  2918
# 1670 번 문서 종료 / 총 길이는 :  2432
# 1671 번 문서 종료 / 총 길이는 :  2578
# 1672 번 문서 종료 / 총 길이는 :  5790
# 1673 번 문서 종료 / 총 길이는 :  4971
# 1674 번 문서 종료 / 총 길이는 :  4697
# 1675 번 문서 종료 / 총 길이는 :  4737
# 1676 번 문서 종료 / 총 길이는 :  3961
# 1677 번 문서 종료 / 총 길이는 :  1825
# 1678 번 문서 종료 / 총 길이는 :  2620
# 1679 번 문서 종료 / 총 길이는 :  9180
# 1680 번 문서 종료 / 총 길이는 :  1925

# %%
# title 한국어 번역 함수

def get_translate(text):
    client_id = "" # <-- client_id 기입
    client_secret = "" # <-- client_secret 기입

    data = {'text' : text,
            'source' : 'en',
            'target': 'ko'}

    url = "https://openapi.naver.com/v1/papago/n2mt"

    header = {"X-Naver-Client-Id":client_id,
              "X-Naver-Client-Secret":client_secret}

    response = requests.post(url, headers=header, data=data)
    rescode = response.status_code

    if(rescode==200):
        send_data = response.json()
        trans_data = (send_data['message']['result']['translatedText'])
        return trans_data
    else:
        print("Error Code:" , rescode)

# %%
#타이틀 번역
title_trans = []

for i in df["title"]:
    trans = get_translate(i)
    title_trans.append(trans)

# %%
# hscode 데이터프레임 생성 함수
def make_df(hscodes):

    df_final = pd.DataFrame()

    hs_code = []

    for i in range(len(hscodes)):
        H = []
        h_result = ''
        df_check = pd.DataFrame()
        df_check['hscode'] = pd.Series(hscodes[i])

        H = df_check['hscode'].tolist()

        for h in H:
            h_result = h_result + "/" + h

        hs_code.append(h_result[1:])

        del df_check

    df_final['hscode'] = hs_code

    return df_final

# %%
import pandas as pd

df = pd.DataFrame()
df1 = pd.read_csv('호주_세관_v3(전체).csv', index_col = False)
df1['title_ko'] = title_trans
df2 = make_df(hscodes)
df3 = pd.concat([df1, df2], axis = 1)
df3
# Out:
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# ...
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
# C:\Users\water\AppData\Local\Temp\ipykernel_18176\1313424927.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_check['hscode'] = pd.Series(hscodes[i])
#             date                                               link  \
# 0     2022-07-28  https://www.abf.gov.au/help-and-support-subsit...
# 1     2022-07-22  https://www.abf.gov.au/help-and-support-subsit...
# 2     2022-07-21  https://www.abf.gov.au/help-and-support-subsit...
# 3     2022-07-12  https://www.abf.gov.au/help-and-support-subsit...
# 4     2022-07-11  https://www.abf.gov.au/help-and-support-subsit...
# ...          ...                                                ...
# 1675  2018-12-10  https://www.abf.gov.au/help-and-support-subsit...
# 1676  2018-12-10  https://www.abf.gov.au/help-and-support-subsit...
# 1677  2018-12-10  https://www.abf.gov.au/help-and-support-subsit...
# 1678  2018-12-10  https://www.abf.gov.au/help-and-support-subsit...
# 1679  2018-12-10  https://www.abf.gov.au/help-and-support-subsit...
#
#                                                   title  \
# 0     Indexation of customs duty rates on excise-equ...
# 1     Removal of customs duty on certain electric ve...
# 2               Application for Customs Broker Licences
# 3       Temporary duty reduction for goods from Ukraine
# 4               Application for Customs Broker Licences
# ...                                                 ...
# 1675  Preparation of submanifests for export cargo c...
# 1676              Section 135 of the Copyright Act 1968
# 1677  Sea cargo automation: electronic transhipment ...
# 1678  Indexation of certain excise and customs tarif...
# 1679  Customs Act 1901 - Part XVB Review of Anti-Dum...
#
#                                                    text  \
# 0      australian customs notice no. 2022/35 indexat...
# 1      australian customs notice no. 2022/34 removal...
# 2      australian customs notice no. 2022/33 applica...
# 3      australian customs notice no. 2022/32 tempora...
# 4      australian customs notice no. 2022/31 applica...
# ...                                                 ...
# 1675   australian customs notice 1996 09 preparation...
# 1676   australian customs notice 1996 07 section 135...
# 1677   australian customs notice 1996 06 sea cargo a...
# 1678   australian customs notice 1996 05 29 indexati...
# 1679   australian customs notice 1996 05 2 customs a...
#
#                              title_ko  \
# 0     2022년 8월 1일 소비재 등가물품에 대한 관세율 지표
# 1                  특정 전기 차량에 대한 관세 철폐
# 2                       관세 브로커 면허 신청서
# 3               우크라이나 물품에 대한 임시 관세 감면
# 4                       관세 브로커 면허 신청서
# ...                               ...
# 1675                             None
# 1676                             None
# 1677                             None
# 1678                             None
# 1679                             None
#
#                                                  hscode
# 0     2202.99/3825.69/2903.41/3824.89/2710.99/2701.1...
# 1     8701.92/8701.29/8701.94/8703.70/8704.31/8701.9...
# 2
# 3
# 4
# ...                                                 ...
# 1675
# 1676
# 1677
# 1678  2208.20/2208.30/2208.40/2206.00/2402.20/2208.9...
# 1679
#
# [1680 rows x 6 columns]

# %%
df3.to_csv('호주_세관고시_번역_hs.csv', mode='w', encoding='utf-8-sig', index = False)
