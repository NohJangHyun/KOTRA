# %%
#U.S. Department of Commerce - 미국 상무부에서 발행하는 연방 관보 고지
#2022년만 가능
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
from time import sleep

options= Options()
options.headless = True
driver = webdriver.Chrome(options = options)
url= "https://bis.doc.gov/index.php/federal-register-notices/17-regulations/1963-federal-register-notices-2022"

driver.get(url)
sleep(1)

# %%
soup = BeautifulSoup(driver.page_source, 'lxml')
div = soup.find("div", attrs={"itemprop":"articleBody"})

# %%
#table : 총 문건 개수
table = div.find("table", attrs={"border":"1"}).find_all("tr", attrs={"valign":"top"})
#type1 : 1번 유형 개수
type1 = div.find_all("div", attrs={"class":"OutlineElement Ltr SCXW30029558 BCX8"})

# %%
#dates 리스트에 date 담기
dates=[]

#1번 유형 담기
for i in range(len(type1)):
    dates.append(table[i].find("span").get_text().strip())

#2번 유형 담기
for i in range(len(type1),len(table)):
    dates.append(table[i].get_text()[1:10].strip())

# %%
#titles 리스트에 title 담기
titles=[]

for i in range(len(table)):
    title = table[i].find("a").get_text() 
    titles.append(title)

# %%
#links 리스트에 link 담기
links = []
for i in range(len(table)):
    link = url + table[i].find("a")['href']
    links.append(link)

# %%
#contents 리스트에 content 담기 : 마지막 content 제외
max = len(div.find_all("hr"))
cnt = len(div.find_all("hr"))
start = div.find("hr")
contents = []
while cnt > 0:
    if cnt == max:
        cnt -= 1
        next = start.next_sibling
        string = next.get_text().strip()
    else:
        if str(next)[:3] == "<hr":
            next = next.next_sibling
            contents.append(string)
            string = ""
            cnt -= 1
        else:
            next = next.next_sibling
            string = string +  next.get_text().strip() + ""

# %%
#contents 리스트에 content 담기 : 마지막 content 추가
last = div.find_all('hr')[-1]

l = 1
while not None:
    if l == 1:
        l -= 1
        la = last.next_sibling
        string = la.get_text().strip()
    else:
        la = la.next_sibling
        if la == None:
            contents.append(string)
            break
        else:
            string += la.get_text().strip() +""

# %%
#csv file
import pandas as pd

df = pd.DataFrame()
df['date'] = dates
df['title'] = titles
df['link'] = links
df['content'] = contents
df
# Out:
#          date                                              title  \
# 0   6/30/2022  Addition of Entities, Revision and Correction ...
# 1   6/06/2022           Additions of Entities to the Entity List
# 2   6/06/2022  Export Administration Regulations: Revisions t...
# 3   6/01/2022  Adoption of Congressional Notification Require...
# 4   5/26/2022  Information Security Controls: Cybersecurity I...
# 5   5/23/2022  Commerce Control List: Controls on Certain Mar...
# 6   5/11/2022  Expansion of Sanctions Against Russian Industr...
# 7   4/14/2022  Expansion of Sanctions Against Russia and Bela...
# 8   4/12/2022  Additions to the List of Countries Excluded fr...
# 9   4/11/2022  Addition of Certain Entities to the Entity Lis...
# 10  4/07/2022           Additions of Entities to the Entity List
# 11  3/16/2022  Imposition of Sanctions on ‘Luxury Goods’ Dest...
# 12  3/10/2022  Addition to the List of Countries Excluded fro...
# 13  3/09/2022  Further Imposition of Sanctions Against Russia...
# 14  3/08/2022  Expansion of Sanctions Against the Russian Ind...
