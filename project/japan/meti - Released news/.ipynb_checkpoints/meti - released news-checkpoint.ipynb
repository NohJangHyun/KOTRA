# %%
#METI(Ministry of Economoy, Trade and Industy) - 일본 경제산업성에서 올라오는 대외 경제 카테고리 뉴스

from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
from time import sleep

options= Options()
options.headless = True
driver = webdriver.Chrome(options = options)
url= "https://www.meti.go.jp/press/category_02.html"

driver.get(url)
sleep(1)

soup = BeautifulSoup(driver.page_source, 'lxml')
dl = soup.find("dl", attrs={"class":"date_sp b-solid"})

# %%
#date
dates = []

dt = dl.find_all("dt")
for d in range(len(dt)):
    date = dt[d].get_text()
    dates.append(date)
print(len(dates))
# Out:
# 500

# %%
#title & link
titles = []
links = []

A = dl.find_all("a")
for a in A:
    title = a.get_text()
    link = "https://www.meti.go.jp/"+a['href']
    titles.append(title)
    links.append(link)
print(len(titles))
print(len(links))
# Out:
# 500
# 500

# %%
#csv file
import pandas as pd

df = pd.DataFrame()
df['date'] = dates
df['title'] = titles
df['link'] = links
df
# Out:
#            date                                              title  \
# 0    2022年7月27日                     インド太平洋経済枠組み（IPEF）閣僚級会合が開催されました
# 1    2022年7月25日                    萩生田経済産業大臣がエマニュエル駐日米国大使の表敬を受けました
# 2    2022年7月25日    萩生田経済産業大臣がインドネシア・アイルランガ経済担当調整大臣及びアグス工業大臣と会談しました
# 3    2022年7月22日              第1回「日ASEAN経済共創ビジョン策定のための検討委員会」を開催しました
# 4    2022年7月21日                      萩生田経済産業大臣がサプライチェーン閣僚会合に出席しました
# ..          ...                                                ...
# 495  2019年5月29日  石川経済産業大臣政務官がチリ共和国、ブラジル連邦共和国、ペルー共和国及びアメリカ合衆国に出張...
# 496  2019年5月27日                        対内直接投資等に係る事前届出対象業種の追加等を行います
# 497  2019年5月24日      世耕大臣が第6回三極貿易大臣会合、OECD閣僚理事会及びWTO非公式閣僚会合に出席しました
# 498  2019年5月23日                                 三極貿易大臣共同声明が発表されました
# 499  2019年5月23日                        「国際化促進インターンシップ事業」参加企業を募集中です
#
#                                                   link
# 0    https://www.meti.go.jp//press/2022/07/20220727...
# 1    https://www.meti.go.jp//press/2022/07/20220725...
# 2    https://www.meti.go.jp//press/2022/07/20220725...
# 3    https://www.meti.go.jp//press/2022/07/20220722...
# 4    https://www.meti.go.jp//press/2022/07/20220721...
# ..                                                 ...
# 495  https://www.meti.go.jp//press/2019/05/20190529...
# 496  https://www.meti.go.jp//press/2019/05/20190527...
# 497  https://www.meti.go.jp//press/2019/05/20190524...
# 498  https://www.meti.go.jp//press/2019/05/20190523...
# 499  https://www.meti.go.jp//press/2019/05/20190523...
#
# [500 rows x 3 columns]

# %%
df.to_csv('meti_released_news.csv', mode='w', encoding='utf-8-sig')

# %%
#contents
contents = []
for link in links[1:5]:
    options= Options()
    options.headless = True
    driver = webdriver.Chrome(options = options)
    url= link
    
    driver.get(url)
    sleep(1)

    str_con = ""
    soup = BeautifulSoup(driver.page_source, 'lxml')
    content = soup.find("div", attrs={"class":"main w1000"})
    for con in content:
        c = con.get_text()
        if len(c) > 1:
            if c != "担当": 
                str_con = str_con + " " + c.strip()
            else:
                break
    contents.append(list(str_con))
print(contents)
# Out:
# [[' ', '2', '0', '2', '2', '年', '7', '月', '2', '5', '日', ' ', '対', '外', '経', '済', ' ', '7', '月', '2', '5', '日', '（', '月', '曜', '日', '）', '、', '萩', '生', '田', '経', '済', '産', '業', '大', '臣', 'は', '、', 'エ', 'マ', 'ニ', 'ュ', 'エ', 'ル', '駐', '日', '米', '国', '大', '使', 'の', '表', '敬', 'を', '受', 'け', 'ま', 'し', 'た', '。', ' ', '7', '月', '2', '5', '日', '（', '月', '曜', '日', '）', '、', '萩', '生', '田', '経', '済', '産', '業', '大', '臣', 'は', '、', 'エ', 'マ', 'ニ', 'ュ', 'エ', 'ル', '駐', '日', '米', '国', '大', '使', 'の', '表', '敬', 'を', '受', 'け', 'ま', 'し', 'た', '。', ' ', '冒', '頭', '、', '萩', '生', '田', '大', '臣', 'は', '、', '安', '倍', '晋', '三', '元', '内', '閣', '総', '理', '大', '臣', 'の', '逝', '去', 'に', '対', 'す', 'る', '米', '国', 'か', 'ら', 'の', '弔', '意', 'の', '表', '明', 'に', '対', 'し', '感', '謝', 'の', '意', 'を', '伝', 'え', 'ま', 'し', 'た', '。', ' ', '両', '者', 'は', '、', '今', '月', '行', 'わ', 'れ', 'る', '日', '米', '経', '済', '政', '策', '協', '議', '委', '員', '会', '（', '経', '済', '版', '「', '２', '＋', '２', '」', '）', '閣', '僚', '会', '合', 'に', '向', 'け', 'て', '、', '経', '済', '分', '野', 'で', 'の', '日', '米', '協', '力', 'を', '深', '化', '・', '拡', '大', 'さ', 'せ', 'て', 'い', 'く', 'こ', 'と', 'で', '一', '致', 'し', 'ま', 'し', 'た', '。', 'ま', 'た', '、', '萩', '生', '田', '大', '臣', 'か', 'ら', 'は', '、', '世', '界', '有', '数', 'の', 'L', 'N', 'G', '生', '産', '国', 'で', 'あ', 'る', '米', '国', 'に', '対', 'し', '、', 'L', 'N', 'G', 'の', '増', '産', 'や', '安', '定', '供', '給', 'に', 'つ', 'い', 'て', '要', '請', 'を', '行', 'い', 'ま', 'し', 'た', '。'], [' ', '2', '0', '2', '2', '年', '7', '月', '2', '5', '日', ' ', '対', '外', '経', '済', ' ', '7', '月', '2', '5', '日', '、', '萩', '生', '田', '経', '済', '産', '業', '大', '臣', 'は', '、', 'イ', 'ン', 'ド', 'ネ', 'シ', 'ア', '・', 'ア', 'イ', 'ル', 'ラ', 'ン', 'ガ', '経', '済', '担', '当', '調', '整', '大', '臣', '及', 'び', 'ア', 'グ', 'ス', '工', '業', '大', '臣', 'と', '会', '談', 'し', '、', '自', '動', '車', '産', '業', 'や', '鉄', '鋼', '産', '業', 'な', 'ど', '個', '別', 'の', '産', '業', '政', '策', 'や', '官', '民', '経', '済', '対', '話', '等', 'に', 'つ', 'い', 'て', 'の', '意', '見', '交', '換', 'を', '通', 'じ', 'て', '、', '両', '国', 'の', '経', '済', '関', '係', 'を', '一', '層', '深', '化', 'さ', 'せ', 'て', 'い', 'く', 'こ', 'と', 'を', '確', '認', 'し', 'ま', 'し', 'た', '。', ' ', '2', '0', '2', '2', '年', '7', '月', '2', '5', '日', '、', '萩', '生', '田', '経', '済', '産', '業', '大', '臣', 'は', '、', 'イ', 'ン', 'ド', 'ネ', 'シ', 'ア', '・', 'ア', 'イ', 'ル', 'ラ', 'ン', 'ガ', '経', '済', '担', '当', '調', '整', '大', '臣', '及', 'び', 'ア', 'グ', 'ス', '工', '業', '大', '臣', 'と', '会', '談', 'し', 'ま', 'し', 'た', '。', ' ', '会', '談', 'で', 'は', '、', '日', 'イ', 'ン', 'ド', 'ネ', 'シ', 'ア', '二', '国', '間', '経', '済', '関', '係', 'の', '強', '化', 'に', '向', 'け', 'て', '、', '日', 'イ', 'ン', 'ド', 'ネ', 'シ', 'ア', 'の', 'サ', 'プ', 'ラ', 'イ', 'チ', 'ェ', 'ー', 'ン', 'の', '強', '靱', '化', '等', 'に', '向', 'け', 'た', '自', '動', '車', '産', '業', 'や', '鉄', '鋼', '産', '業', 'な', 'ど', '個', '別', 'の', '産', '業', '政', '策', 'や', '、', 'ア', 'イ', 'ル', 'ラ', 'ン', 'ガ', '大', '臣', 'と', '1', '月', 'の', '会', '談', 'で', '設', '置', 'に', '合', '意', 'し', 'た', '官', '民', '経', '済', '対', '話', '等', 'に', 'つ', 'い', 'て', '意', '見', '交', '換', 'を', '行', 'い', 'ま', 'し', 'た', '。', ' '], [' ', '2', '0', '2', '2', '年', '7', '月', '2', '2', '日', '同', '時', '発', '表', '：', '独', '立', '行', '政', '法', '人', '日', '本', '貿', '易', '振', '興', '機', '構', ' ', '対', '外', '経', '済', ' ', '経', '済', '産', '業', '省', '及', 'び', 'ジ', 'ェ', 'ト', 'ロ', '並', 'び', 'に', '日', '本', '商', '工', '会', '議', '所', 'を', 'は', 'じ', 'め', 'と', 'す', 'る', '経', '済', '界', 'は', '、', '本', '日', '、', '第', '1', '回', '「', '日', 'A', 'S', 'E', 'A', 'N', '経', '済', '共', '創', 'ビ', 'ジ', 'ョ', 'ン', '策', '定', 'の', 'た', 'め', 'の', '検', '討', '委', '員', '会', '」', 'を', '開', '催', 'し', '、', '新', 'た', 'な', '日', 'A', 'S', 'E', 'A', 'N', 'の', '経', '済', '関', '係', 'の', '将', '来', '像', 'に', 'つ', 'い', 'て', '検', '討', 'を', '行', 'い', 'ま', 'し', 'た', '。', ' ', '１', '．', '概', '要', ' ', '本', '日', '、', '経', '済', '産', '業', '省', '及', 'び', 'ジ', 'ェ', 'ト', 'ロ', '並', 'び', 'に', '日', '本', '商', '工', '会', '議', '所', 'を', 'は', 'じ', 'め', 'と', 'す', 'る', '経', '済', '界', 'は', '、', '来', '年', '2', '0', '2', '3', '年', 'の', '日', 'A', 'S', 'E', 'A', 'N', '友', ...

# %%
df.to_csv('meti_released_news_contents.csv', mode='w', encoding='utf-8-sig')
