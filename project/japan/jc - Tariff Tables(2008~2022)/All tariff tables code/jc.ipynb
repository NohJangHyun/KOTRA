# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
from time import sleep
import pandas as pd

# %%
options= Options()
options.headless = True
driver = webdriver.Chrome(options = options)
url = "https://www.customs.go.jp/tariff/2022_04_01/data/print_j_01.htm"

driver.get(url)
sleep(1)

# %%
soup = BeautifulSoup(driver.page_source, 'lxml')
table = soup.find_all("table")

# %%
len(table)
# Out:
# 3

# %%
df = pd.read_html(driver.page_source)[2]
df
# Out:
#    統計番号Statistical code                     \
#             番号H.S. code Unnamed: 1_level_1
# 0                  1.01                NaN
# 1                   NaN                NaN
# 2                101.21                NaN
# 3                   NaN              100.0
# 4                   NaN                NaN
# ..                  ...                ...
# 76                  NaN                NaN
# 77                  NaN               11.0
# 78                  NaN               12.0
# 79                  NaN               19.0
# 80                  NaN               90.0
#
#                                         品名Description 関税率Tariff rate  \
#                                         品名Description      基本General
# 0                           馬、ろ馬、ら馬及びヒニー（生きているものに限る。）            NaN
# 1                                                   馬            NaN
# 2                                          純粋種の繁殖用のもの            NaN
# 3   1 サラブレッド種、サラブレッド系種、アラブ種、アングロアラブ種又はアラブ系種の馬（以下この...             無税
# 4                                            2 その他のもの            NaN
# ..                                                ...            ...
# 76                                              － 両生類            NaN
# 77                                             －－ 無尾目            NaN
# 78                                             －－ 有尾目            NaN
# 79                                          －－ その他のもの            NaN
# 80                                           － その他のもの            NaN
#
#                                       関税率（経済連携協定）Tariff rate (EPA)             \
#    暫定Temporary WTO協定WTO 特恵GSP 特別特恵LDC              シンガポールSingapore メキシコMexico
# 0          NaN      NaN   NaN     NaN                          NaN        NaN
# 1          NaN      NaN   NaN     NaN                          NaN        NaN
# 2          NaN      NaN   NaN     NaN                          NaN        NaN
# 3          NaN     (無税)   NaN     NaN                           無税         無税
# 4          NaN      NaN   NaN     NaN                          NaN        NaN
# ..         ...      ...   ...     ...                          ...        ...
# 76         NaN      NaN   NaN     NaN                          NaN        NaN
# 77         NaN      NaN   NaN     NaN                           無税         無税
# 78         NaN      NaN   NaN     NaN                           無税         無税
# 79         NaN      NaN   NaN     NaN                           無税         無税
# 80         NaN      NaN   NaN     NaN                           無税         無税
#
#     ...                                                                     \
#     ... TPP11 (CPTPP) 欧州連合EU 英国UK RCEP(アセアン/豪州/ニュージーランド) RCEP(中国) RCEP(韓国)
# 0   ...           NaN    NaN  NaN                    NaN      NaN      NaN
# 1   ...           NaN    NaN  NaN                    NaN      NaN      NaN
# 2   ...           NaN    NaN  NaN                    NaN      NaN      NaN
# 3   ...            無税     無税   無税                     無税       無税       無税
# 4   ...           NaN    NaN  NaN                    NaN      NaN      NaN
# ..  ...           ...    ...  ...                    ...      ...      ...
# 76  ...           NaN    NaN  NaN                    NaN      NaN      NaN
# 77  ...            無税     無税   無税                     無税       無税       無税
# 78  ...            無税     無税   無税                     無税       無税       無税
# 79  ...            無税     無税   無税                     無税       無税       無税
# 80  ...            無税     無税   無税                     無税       無税       無税
#
#    関税率Tariff rate 単位Unit               他法令Law
#        日米貿易協定US◆1      I   II          他法令Law
# 0             NaN    NaN  NaN             NaN
# 1             NaN    NaN  NaN             NaN
# 2             NaN    NaN  NaN             NaN
# 3             NaN    NaN   NO            PMAN
# 4             NaN    NaN  NaN             NaN
# ..            ...    ...  ...             ...
# 76            NaN    NaN  NaN             NaN
# 77            NaN     NO   KG  WAHUIAPMPLRAAN
# 78            NaN     NO   KG  WAHUIAPMPLRAAN
# 79            NaN     NO   KG  WAHUIAPMPLRAAN
# 80            NaN     NO   KG  WAHUIAPMPLRAAN
#
# [81 rows x 33 columns]

# %%
df[2]
# Out:
#    統計番号Statistical code                     \
#             番号H.S. code Unnamed: 1_level_1
# 0                  1.01                NaN
# 1                   NaN                NaN
# 2                101.21                NaN
# 3                   NaN              100.0
# 4                   NaN                NaN
# ..                  ...                ...
# 76                  NaN                NaN
# 77                  NaN               11.0
# 78                  NaN               12.0
# 79                  NaN               19.0
# 80                  NaN               90.0
#
#                                         品名Description 関税率Tariff rate  \
#                                         品名Description      基本General
# 0                           馬、ろ馬、ら馬及びヒニー（生きているものに限る。）            NaN
# 1                                                   馬            NaN
# 2                                          純粋種の繁殖用のもの            NaN
# 3   1 サラブレッド種、サラブレッド系種、アラブ種、アングロアラブ種又はアラブ系種の馬（以下この...             無税
# 4                                            2 その他のもの            NaN
# ..                                                ...            ...
# 76                                              － 両生類            NaN
# 77                                             －－ 無尾目            NaN
# 78                                             －－ 有尾目            NaN
# 79                                          －－ その他のもの            NaN
# 80                                           － その他のもの            NaN
#
#                                       関税率（経済連携協定）Tariff rate (EPA)             \
#    暫定Temporary WTO協定WTO 特恵GSP 特別特恵LDC              シンガポールSingapore メキシコMexico
# 0          NaN      NaN   NaN     NaN                          NaN        NaN
# 1          NaN      NaN   NaN     NaN                          NaN        NaN
# 2          NaN      NaN   NaN     NaN                          NaN        NaN
# 3          NaN     (無税)   NaN     NaN                           無税         無税
# 4          NaN      NaN   NaN     NaN                          NaN        NaN
# ..         ...      ...   ...     ...                          ...        ...
# 76         NaN      NaN   NaN     NaN                          NaN        NaN
# 77         NaN      NaN   NaN     NaN                           無税         無税
# 78         NaN      NaN   NaN     NaN                           無税         無税
# 79         NaN      NaN   NaN     NaN                           無税         無税
# 80         NaN      NaN   NaN     NaN                           無税         無税
#
#     ...                                                                     \
#     ... TPP11 (CPTPP) 欧州連合EU 英国UK RCEP(アセアン/豪州/ニュージーランド) RCEP(中国) RCEP(韓国)
# 0   ...           NaN    NaN  NaN                    NaN      NaN      NaN
# 1   ...           NaN    NaN  NaN                    NaN      NaN      NaN
# 2   ...           NaN    NaN  NaN                    NaN      NaN      NaN
# 3   ...            無税     無税   無税                     無税       無税       無税
# 4   ...           NaN    NaN  NaN                    NaN      NaN      NaN
# ..  ...           ...    ...  ...                    ...      ...      ...
# 76  ...           NaN    NaN  NaN                    NaN      NaN      NaN
# 77  ...            無税     無税   無税                     無税       無税       無税
# 78  ...            無税     無税   無税                     無税       無税       無税
# 79  ...            無税     無税   無税                     無税       無税       無税
# 80  ...            無税     無税   無税                     無税       無税       無税
#
#    関税率Tariff rate 単位Unit               他法令Law
#        日米貿易協定US◆1      I   II          他法令Law
# 0             NaN    NaN  NaN             NaN
# 1             NaN    NaN  NaN             NaN
# 2             NaN    NaN  NaN             NaN
# 3             NaN    NaN   NO            PMAN
# 4             NaN    NaN  NaN             NaN
# ..            ...    ...  ...             ...
# 76            NaN    NaN  NaN             NaN
# 77            NaN     NO   KG  WAHUIAPMPLRAAN
# 78            NaN     NO   KG  WAHUIAPMPLRAAN
# 79            NaN     NO   KG  WAHUIAPMPLRAAN
# 80            NaN     NO   KG  WAHUIAPMPLRAAN
#
# [81 rows x 33 columns]

# %%
df[2].to_csv('asdf.csv', encoding='utf-8-sig')
